# %%
import pyttsx3
import pickle
import numpy as np

#pickle.dump(spell, open("Words.pkl", "wb"))
spell = pickle.load(open("Words.pkl", "rb"))
engine = pyttsx3.init()

# %%
def rselect(dictionary, item):
    return np.random.choice(dictionary[item])

learning = {"learn" :    ["This is how you spell ",
                          "Alright, This is how you spell ",
                          "Casen, I want you to learn to spell ", 
                          "This is a new word for you, here is how you spell ", 
                          "Lets give this word a shot, spell", 
                          "I bet you can learn to spell", 
                          "This will be a fun one to spell", 
                          "It is tricky, but I bet you can learn to spell", 
                          "If you keep working hard, you can learn to spell"],

            "prompt" :   ["Oh, this is tricky, can you spell ",
                          "Try this, spell ",
                          "Do you think you can spell ", 
                          "Casen, I wonder if you can spell ",
                          "Want to try spelling ", 
                          "How do you spell ", 
                          "Can you spell ", 
                          "Spell ", 
                          "Maybe this is too hard, but can you spell "],

            "correct" :  ["Great", 
                          "Wow", 
                          "Fantastic", 
                          "Nice", 
                          "That is amazing", 
                          "Keep going!", 
                          "Impressive", 
                          "Stunning"],

            "incorrect":["Nope", 
                         "That is not right", 
                         "Maybe Next time", 
                         "Hmm...that is not right", 
                         "Better luck next time", 
                         "Buzz, wrong", 
                         "Well that is not correct", 
                         "Incorrect", 
                         "Good try, but that is not right"],
            
            "words" :   ['able',
                         'ace',
                         'acid',
                         'act',
                         'air',
                         'all',
                         'am',
                         'an',
                         'and',
                         'ant',
                         'any',
                         'ape',
                         'apple',
                         'are',
                         'army',
                         'as',
                         'ask',
                         'at',
                         'aunt',
                         'away',
                         'axe',
                         'back',
                         'bad',
                         'bag',
                         'ball',
                         'bang',
                         'bar',
                         'barn',
                         'bat',
                         'bean',
                         'bee',
                         'beg',
                         'bell',
                         'big',
                         'bike',
                         'bird',
                         'black',
                         'blue',
                         'bone',
                         'book',
                         'boot',
                         'bot',
                         'box',
                         'boy',
                         'brown',
                         'but',
                         'by',
                         'cab',
                         'cage',
                         'cake',
                         'call',
                         'camp',
                         'can',
                         'cape',
                         'car',
                         'card',
                         'cart',
                         'cat',
                         'cave',
                         'chin',
                         'clam',
                         'clap',
                         'claw',
                         'clay',
                         'clip',
                         'club',
                         'coat',
                         'code',
                         'coin',
                         'cold',
                         'come',
                         'cool',
                         'cord',
                         'cow',
                         'crab',
                         'crow',
                         'dad',
                         'dart',
                         'dash',
                         'dawn',
                         'day',
                         'den',
                         'dent',
                         'did',
                         'dim',
                         'dime',
                         'dish',
                         'do',
                         'dog',
                         'doom',
                         'down',
                         'drip',
                         'drop',
                         'drum',
                         'dude',
                         'each',
                         'easy',
                         'eat',
                         'egg',
                         'end',
                         'exit',
                         'eye',
                         'face',
                         'fair',
                         'fall',
                         'fan',
                         'far',
                         'farm',
                         'fast',
                         'fate',
                         'fear',
                         'feat',
                         'fin',
                         'fine',
                         'fir',
                         'fish',
                         'fit',
                         'fly',
                         'foam',
                         'fold',
                         'food',
                         'for',
                         'foul',
                         'fox',
                         'from',
                         'fun',
                         'gain',
                         'gem',
                         'get',
                         'give',
                         'glob',
                         'glow',
                         'go',
                         'goal',
                         'goat',
                         'gold',
                         'good',
                         'gray',
                         'green',
                         'grid',
                         'gut',
                         'gym',
                         'hack',
                         'had',
                         'hag',
                         'ham',
                         'hand',
                         'harm',
                         'hat',
                         'hate',
                         'hay',
                         'he',
                         'head',
                         'help',
                         'hem',
                         'hen',
                         'here',
                         'hero',
                         'high',
                         'hill',
                         'him',
                         'hip',
                         'home',
                         'hook',
                         'horn',
                         'host',
                         'howl',
                         'hub',
                         'hum',
                         'hunk',
                         'hunt',
                         'hut',
                         'ice',
                         'idea',
                         'imp',
                         'in',
                         'info',
                         'ink',
                         'inside',
                         'into',
                         'iris',
                         'is',
                         'it',
                         'itch',
                         'item',
                         'kelp',
                         'kink',
                         'kiss',
                         'kite',
                         'kitten',
                         'knee',
                         'knot',
                         'lab',
                         'lace',
                         'lad',
                         'lady',
                         'lag',
                         'lair',
                         'lake',
                         'lamb',
                         'lamp',
                         'land',
                         'lane',
                         'lap',
                         'lash',
                         'last',
                         'lava',
                         'lawn',
                         'lazy',
                         'lead',
                         'leaf',
                         'leak',
                         'lean',
                         'leap',
                         'left',
                         'leg',
                         'lend',
                         'lept',
                         'less',
                         'let',
                         'lice',
                         'lick',
                         'life',
                         'like',
                         'line',
                         'lion',
                         'lit',
                         'lite',
                         'little',
                         'live',
                         'loaf',
                         'loan',
                         'log',
                         'look',
                         'loop',
                         'loot',
                         'lord',
                         'lose',
                         'loss',
                         'loud',
                         'love',
                         'low',
                         'lump',
                         'lung',
                         'lure',
                         'mac',
                         'mad',
                         'made',
                         'maid',
                         'make',
                         'male',
                         'mama',
                         'man',
                         'mark',
                         'mash',
                         'mask',
                         'mat',
                         'math',
                         'me',
                         'meal',
                         'meek',
                         'meet',
                         'melt',
                         'men',
                         'mend',
                         'mess',
                         'mice',
                         'mile',
                         'milk',
                         'mind',
                         'mint',
                         'mist',
                         'moan',
                         'mode',
                         'mom',
                         'mope',
                         'moss',
                         'moth',
                         'move',
                         'mown',
                         'much',
                         'mud',
                         'must',
                         'mut',
                         'my',
                         'nail',
                         'name',
                         'neat',
                         'need',
                         'nest',
                         'net',
                         'next',
                         'nice',
                         'nine',
                         'no',
                         'node',
                         'noon',
                         'nope',
                         'nose',
                         'not',
                         'note',
                         'numb',
                         'nut',
                         'oak',
                         'oar',
                         'oat',
                         'oath',
                         'obey',
                         'odd',
                         'of',
                         'oil',
                         'old',
                         'on',
                         'one',
                         'ooze',
                         'open',
                         'orange',
                         'out',
                         'over',
                         'owl',
                         'own',
                         'oxen',
                         'pace',
                         'page',
                         'pail',
                         'pain',
                         'paint',
                         'pan',
                         'papa',
                         'park',
                         'pass',
                         'pat',
                         'paw',
                         'pay',
                         'pea',
                         'peak',
                         'peal',
                         'pear',
                         'peg',
                         'pest',
                         'pet',
                         'pier',
                         'pig',
                         'pike',
                         'pill',
                         'pin',
                         'pink',
                         'pipe',
                         'plan',
                         'play',
                         'plow',
                         'plus',
                         'pod',
                         'poem',
                         'poll',
                         'pony',
                         'pool',
                         'poor',
                         'port',
                         'pour',
                         'puma',
                         'push',
                         'put',
                         'race',
                         'rack',
                         'rag',
                         'rage',
                         'raid',
                         'rail',
                         'rain',
                         'rake',
                         'ram',
                         'ramp',
                         'ran',
                         'rant',
                         'rash',
                         'rat',
                         'ray',
                         'read',
                         'rear',
                         'red',
                         'reed',
                         'rent',
                         'rest',
                         'rib',
                         'rice',
                         'rich',
                         'ring',
                         'rip',
                         'ripe',
                         'rise',
                         'roam',
                         'roar',
                         'rob',
                         'robe',
                         'rock',
                         'root',
                         'rope',
                         'rose',
                         'row',
                         'rub',
                         'rug',
                         'run',
                         'rune',
                         'rush',
                         'rust',
                         'sack',
                         'sad',
                         'safe',
                         'sage',
                         'said',
                         'sail',
                         'salt',
                         'same',
                         'sang',
                         'sank',
                         'sat',
                         'save',
                         'saw',
                         'say',
                         'scam',
                         'scan',
                         'scar',
                         'scum',
                         'seal',
                         'seat',
                         'see',
                         'seed',
                         'self',
                         'sell',
                         'send',
                         'sent',
                         'set',
                         'she',
                         'shoe',
                         'shot',
                         'shy',
                         'sick',
                         'sign',
                         'silk',
                         'sing',
                         'sink',
                         'sit',
                         'size',
                         'skim',
                         'sky',
                         'slid',
                         'slip',
                         'slug',
                         'snag',
                         'snap',
                         'snot',
                         'snow',
                         'so',
                         'soap',
                         'soar',
                         'sock',
                         'soft',
                         'soil',
                         'song',
                         'soon',
                         'soul',
                         'soy',
                         'span',
                         'star',
                         'stay',
                         'stem',
                         'stop',
                         'story',
                         'stow',
                         'such',
                         'suck',
                         'suit',
                         'sun',
                         'swab',
                         'swam',
                         'swat',
                         'swim',
                         'tab',
                         'taco',
                         'take',
                         'talk',
                         'tame',
                         'tamp',
                         'tan',
                         'tank',
                         'tape',
                         'tart',
                         'tea',
                         'tear',
                         'tell',
                         'ten',
                         'term',
                         'that',
                         'thaw',
                         'the',
                         'them',
                         'then',
                         'there',
                         'they',
                         'thin',
                         'this',
                         'tick',
                         'tidy',
                         'tin',
                         'to',
                         'toad',
                         'toe',
                         'tofy',
                         'toll',
                         'tomb',
                         'too',
                         'tray',
                         'tree',
                         'trim',
                         'true',
                         'try',
                         'tug',
                         'tuna',
                         'twig',
                         'type',
                         'up',
                         'wag',
                         'wage',
                         'wait',
                         'wall',
                         'want',
                         'warm',
                         'warp',
                         'wasp',
                         'wavy',
                         'ways',
                         'we',
                         'wean',
                         'web',
                         'weed',
                         'weep',
                         'well',
                         'went',
                         'were',
                         'wet',
                         'wham',
                         'what',
                         'when',
                         'where',
                         'whip',
                         'white',
                         'who',
                         'wild',
                         'will',
                         'wilt',
                         'wind',
                         'wink',
                         'wipe',
                         'wisp',
                         'with',
                         'wool',
                         'word',
                         'work',
                         'worm',
                         'wrap',
                         'yak',
                         'yank',
                         'yellow',
                         'yes',
                         'yeti',
                         'yoga',
                         'you',
                         'yuck',
                         'zoo']}

# %%
pickle.dump(words, open("words.pkl", "wb"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-0ce3217f9cd2> in <module>
# ----> 1 pickle.dump(words, open("words.pkl", "wb"))
#
# NameError: name 'words' is not defined

# %%
pickle.load(open("save.p", "rb"))

# %%
words = []
a =  np.random.choice(list(spell.keys()))
words.append(a)
word = np.random.choice(words)

engine.say(
    """
    You spell the word {}, 
    """
)



engine.say(
    """
    ... {} ... {} ... Please spell the word .... {} ?
    """.format(np.random.choice(prompt),
               word, 
               word
              ))
engine.runAndWait()
response = input()

if response == word:
    engine.say("{}".format(np.random.choice(correct)))    
    engine.runAndWait()
    words.remove(a)
    spell[word] += 1

else:
    engine.say("{}. You spell ... {} ... {}".format(np.random.choice(incorrect),
                                                    word, 
                                                    "...".join(list(word))))

    spell[word] -= 1
# Out:
# th
# cata
# rhe
# like
# tel
# er
# wrap
# hat
# pas
# lkj
# move
# pair
# mvciuoyt
# mmmnvcadm,kjhpoiuytr
# wrap
# avg
# dfeerryghjjh
# fo:;lk
# @[-poiuytgcfdrdesaqwer
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-42-6ee2ce2e0341> in <module>
#      12                    word
#      13                   ))
# ---> 14     engine.runAndWait()
#      15     response = input()
#      16
#
# ~/anaconda3/envs/liveramp/lib/python3.6/site-packages/pyttsx3/engine.py in runAndWait(self)
#     178         self._inLoop = True
#     179         self._driverLoop = True
# --> 180         self.proxy.runAndWait()
#     181
#     182     def startLoop(self, useDriverLoop=True):
#
# ~/anaconda3/envs/liveramp/lib/python3.6/site-packages/pyttsx3/driver.py in runAndWait(self)
#     190         '''
#     191         self._push(self._engine.endLoop, tuple())
# ...

# %%
spell
# Out:
# {'I': 0,
#  'a': 0,
#  'able': 0,
#  'ace': 0,
#  'acid': 0,
#  'act': 0,
#  'air': 0,
#  'all': 0,
#  'am': 0,
#  'an': 0,
#  'and': 0,
#  'ant': 0,
#  'any': 0,
#  'ape': 0,
#  'apple': 0,
#  'are': 0,
#  'army': 0,
#  'as': 0,
#  'ask': 0,
#  'at': 0,
#  'aunt': 0,
#  'away': 0,
#  'axe': 0,
#  'back': 0,
#  'bad': 0,
#  'bag': 0,
#  'ball': 0,
#  'bang': 0,
#  'bar': 0,
#  'barn': 0,
#  'bat': 0,
#  'bean': 0,
#  'bee': 0,
#  'beg': 0,
#  'bell': 0,
#  'big': 0,
#  'bike': 0,
#  'bird': 0,
#  'black': -1,
#  'blue': 0,
#  'bone': 0,
#  'book': 0,
#  'boot': 0,
#  'bot': 0,
#  'box': 0,
#  'boy': 0,
#  'brown': 0,
#  'but': -1,
#  'by': 0,
#  'cab': 0,
#  'cage': 0,
#  'cake': 0,
#  'call': 0,
#  'camp': 0,
#  'can': 0,
#  'cape': 0,
#  'car': 0,
#  'card': 0,
#  'cart': 0,
#  'cat': 0,
#  'cave': 0,
#  'chin': 0,
#  'clam': 0,
#  'clap': 0,
#  'claw': 0,
#  'clay': 0,
#  'clip': 0,
#  'club': 0,
#  'coat': 0,
#  'code': 0,
#  'coin': 0,
#  'cold': 0,
#  'come': 0,
#  'cool': 0,
# ...

# %%
 np.random.choice(list(spell.keys()))
# Out:
# 'bee'

# %%
A = "{}" * 5

# %%
A.format(1,2,3)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-13-423d59ff7eb4> in <module>
# ----> 1 A.format(1,2,3)
#
# IndexError: tuple index out of range
