# %% [markdown]
# # Historical Tweets - from Twitter Search API using Tweepy Library <br>
#
# Heavily inspired by DSI-6's(Amy Taylor and Veronica Giannotta) work

# %%
import pandas as pd
import tweepy
import shutil
import jsonpickle
import json
import datetime
import config
from pandas.io.json import json_normalize

# %% [markdown]
# ## Creation of API object

# %%
# authenticate account with tweepy
auth = tweepy.OAuthHandler('1ZWD1JS7xivKADeOCV7zVXgI4', 'TgsgO0MaUYw2dccUVC7KtD8SYUX4QYaoxT52D4ye2146d0sLHo')
auth.set_access_token('3799487133-rGUwhJRC2pKZmx8UbureNKPxXSdZAgsWnOrjMQk', 'jOr0vlL0gzyRh1gOQTievE2ZAvuN1sD2FgYCGilFKmE60')

# create API object to pull data from twitter - and pass in authentication code
api = tweepy.API(auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True)

# %% [markdown]
# # City api.geo search

# %%
#  Determine the city, country, or location you want
# place_id for Medford is c8e7273a81fab7c0
# places = api.geo_search(query="malden, MA, USA", 
#                         granularity="city"
#                         )
# place_id = places[j].id

# %%
 #  Determine the city, country, or location you want

l=[ 'Medford', 
    'Arlington',
    'Somerville',
    'Malden',
    'Winchester',
    'Stoneham',
    'Everett'          
              ]
for i in l:
    places = api.geo_search(query=i, 
                            granularity="city")
# i edited code by adding for loop in order to find if there is any other city(here Medford for me) in other states
    for j in range(3):
        place_id = places[j].id
        if places[j].full_name==i+', MA':
            print(j,'th full name is:', places[j].full_name)
            print('place_id is: ',place_id)
# Out:
# Rate limit reached. Sleeping for: 682
# 1 th full name is: Medford, MA
# place_id is:  c8e7273a81fab7c0
# 2 th full name is: Arlington, MA
# place_id is:  47aff34722fae115
# 0 th full name is: Somerville, MA
# place_id is:  ae845a49091f2727
# 0 th full name is: Malden, MA
# place_id is:  75f5a403163f6f95
# 0 th full name is: Stoneham, MA
# place_id is:  8c16a23215a1b4b3
# 1 th full name is: Everett, MA
# place_id is:  fa48d6b6ccab7579

# %%
# query including placeID
searchQuery = 'place:c8e7273a81fab7c0 closed traffic' 

tweetCount = 0

#Open a text file to save the tweets to
with open('../json/medford.json', 'w') as f:

    # use Search API (api.search) with query
    for tweet in tweepy.Cursor(api.search,q=searchQuery
                              ).items() :         

        #Verify the tweet has place info before writing 
        if tweet.place is not None:
            
            #Write the JSON format to the text file, and add one to the number collected
            f.write(jsonpickle.encode(tweet._json, unpicklable=False) + '\n')
            tweetCount += 1

    #Display number of tweets collected
    print("Downloaded {0} tweets".format(tweetCount))
# Out:
# Downloaded 1 tweets

# %%
# query including placeID
searchQuery = 'place:c8e7273a81fab7c0 OR place:67b98f17fdcf20be\
                OR place:47aff34722fae115 \
                OR place:ae845a49091f2727 \
                OR place:75f5a403163f6f95 \
                OR place:8c16a23215a1b4b3 closed traffic' 

tweetCount = 0

#Open a text file to save the tweets to
with open('../json/medford.json', 'w') as f:

    # use Search API (api.search) with query
    for tweet in tweepy.Cursor(api.search,q=searchQuery
                              ).items() :         

        #Verify the tweet has place info before writing 
        if tweet.place is not None:
            
            #Write the JSON format to the text file, and add one to the number collected
            f.write(jsonpickle.encode(tweet._json, unpicklable=False) + '\n')
            tweetCount += 1

    #Display number of tweets collected
    print("Downloaded {0} tweets".format(tweetCount))
# Out:
# Downloaded 13 tweets

# %% [markdown]
# **Create a timestamp to the json file name**

# %%
def file_conversion():
    #create a timestamp
    now = datetime.datetime.now()
    month = '0'+str(now.month)
    day = str(now.day)
    hour = str(now.hour)
    minute = str(now.minute)
    now_str = str(now.year)+month+day+'_'+hour+'_'+minute
    
    
    # Dali: I did not get this part of the code
    #replace the name of the file with a new timestamped filename
    
    dest = '../json/medford_' + now_str + ".json"
    shutil.move('../json/medford.json', dest)
    
    with open(dest, "r") as f:
        status = f.readlines()
        jsons = []
        for ind in status:
            jsons.append(json.loads(ind))
    return jsons

# Uncomment out the file_conversion function to activate the file name change
file_conversion()
# Out:
# [{'contributors': None,
#   'coordinates': {'coordinates': [-71.07923, 42.34756], 'type': 'Point'},
#   'created_at': 'Mon Apr 15 19:03:54 +0000 2019',
#   'entities': {'hashtags': [{'indices': [19, 26], 'text': 'Boston'},
#     {'indices': [81, 89], 'text': 'traffic'}],
#    'symbols': [],
#    'urls': [{'display_url': 'bit.ly/YAC1Ic',
#      'expanded_url': 'http://bit.ly/YAC1Ic',
#      'indices': [90, 113],
#      'url': 'https://t.co/AoTr5OsSgQ'}],
#    'user_mentions': []},
#   'favorite_count': 1,
#   'favorited': False,
#   'geo': {'coordinates': [42.34756, -71.07923], 'type': 'Point'},
#   'id': 1117866152829448192,
#   'id_str': '1117866152829448192',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': {'attributes': {},
#    'bounding_box': {'coordinates': [[[-71.191421, 42.227797],
#       [-70.986004, 42.227797],
#       [-70.986004, 42.399542],
#       [-71.191421, 42.399542]]],
#     'type': 'Polygon'},
#    'contained_within': [],
#    'country': 'United States',
#    'country_code': 'US',
#    'full_name': 'Boston, MA',
#    'id': '67b98f17fdcf20be',
#    'name': 'Boston',
#    'place_type': 'city',
#    'url': 'https://api.twitter.com/1.1/geo/id/67b98f17fdcf20be.json'},
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://www.sigalert.com/Map.asp?region=Boston" rel="nofollow">TTN BOS traffic</a>',
#   'text': 'Off-ramp closed in #Boston on Mass Pike EB at IC 22 - Copley Sq, delay of 5 mins #traffic https://t.co/AoTr5OsSgQ',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Tue Feb 08 23:36:19 +0000 2011',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': '',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 0,
#    'follow_request_sent': False,
#    'followers_count': 3261,
#    'following': False,
#    'friends_count': 1,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 249393984,
#    'id_str': '249393984',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 138,
#    'location': 'Boston, MA',
#    'name': 'TTWN Boston',
#    'notifications': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/439089134884253696/iOThgitH_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/439089134884253696/iOThgitH_normal.png',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'TotalTrafficBOS',
#    'statuses_count': 62084,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': {'coordinates': [-71.07923, 42.34756], 'type': 'Point'},
#   'created_at': 'Mon Apr 15 13:41:53 +0000 2019',
#   'entities': {'hashtags': [{'indices': [19, 26], 'text': 'Boston'},
#     {'indices': [115, 123], 'text': 'traffic'}],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': []},
#   'favorite_count': 2,
#   'favorited': False,
#   'geo': {'coordinates': [42.34756, -71.07923], 'type': 'Point'},
#   'id': 1117785115378241538,
#   'id_str': '1117785115378241538',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': {'attributes': {},
#    'bounding_box': {'coordinates': [[[-71.191421, 42.227797],
#       [-70.986004, 42.227797],
#       [-70.986004, 42.399542],
#       [-71.191421, 42.399542]]],
#     'type': 'Polygon'},
#    'contained_within': [],
#    'country': 'United States',
#    'country_code': 'US',
#    'full_name': 'Boston, MA',
#    'id': '67b98f17fdcf20be',
#    'name': 'Boston',
#    'place_type': 'city',
#    'url': 'https://api.twitter.com/1.1/geo/id/67b98f17fdcf20be.json'},
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://www.sigalert.com/Map.asp?region=Boston" rel="nofollow">TTN BOS traffic</a>',
#   'text': 'Off-ramp closed in #Boston on Mass Pike EB at IC 22 - Copley Sq, stopped traffic back to Mass Ave, delay of 5 mins #traffic',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Tue Feb 08 23:36:19 +0000 2011',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': '',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 0,
#    'follow_request_sent': False,
#    'followers_count': 3261,
#    'following': False,
#    'friends_count': 1,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 249393984,
#    'id_str': '249393984',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 138,
#    'location': 'Boston, MA',
#    'name': 'TTWN Boston',
#    'notifications': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/439089134884253696/iOThgitH_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/439089134884253696/iOThgitH_normal.png',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'TotalTrafficBOS',
#    'statuses_count': 62084,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': {'coordinates': [-71.07923, 42.34756], 'type': 'Point'},
#   'created_at': 'Mon Apr 15 13:09:16 +0000 2019',
#   'entities': {'hashtags': [{'indices': [19, 26], 'text': 'Boston'},
#     {'indices': [81, 89], 'text': 'traffic'}],
#    'symbols': [],
#    'urls': [{'display_url': 'bit.ly/YAC1Ic',
#      'expanded_url': 'http://bit.ly/YAC1Ic',
#      'indices': [90, 113],
#      'url': 'https://t.co/AoTr5OKtFq'}],
#    'user_mentions': []},
#   'favorite_count': 1,
#   'favorited': False,
#   'geo': {'coordinates': [42.34756, -71.07923], 'type': 'Point'},
#   'id': 1117776906160627712,
#   'id_str': '1117776906160627712',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': {'attributes': {},
#    'bounding_box': {'coordinates': [[[-71.191421, 42.227797],
#       [-70.986004, 42.227797],
#       [-70.986004, 42.399542],
#       [-71.191421, 42.399542]]],
#     'type': 'Polygon'},
#    'contained_within': [],
#    'country': 'United States',
#    'country_code': 'US',
#    'full_name': 'Boston, MA',
#    'id': '67b98f17fdcf20be',
#    'name': 'Boston',
#    'place_type': 'city',
#    'url': 'https://api.twitter.com/1.1/geo/id/67b98f17fdcf20be.json'},
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://www.sigalert.com/Map.asp?region=Boston" rel="nofollow">TTN BOS traffic</a>',
#   'text': 'Off-ramp closed in #Boston on Mass Pike EB at IC 22 - Copley Sq, delay of 5 mins #traffic https://t.co/AoTr5OKtFq',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Tue Feb 08 23:36:19 +0000 2011',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': '',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 0,
#    'follow_request_sent': False,
#    'followers_count': 3261,
#    'following': False,
#    'friends_count': 1,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 249393984,
#    'id_str': '249393984',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 138,
#    'location': 'Boston, MA',
#    'name': 'TTWN Boston',
#    'notifications': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/439089134884253696/iOThgitH_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/439089134884253696/iOThgitH_normal.png',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'TotalTrafficBOS',
#    'statuses_count': 62084,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': {'coordinates': [-71.07923, 42.34756], 'type': 'Point'},
#   'created_at': 'Thu Apr 11 04:45:33 +0000 2019',
#   'entities': {'hashtags': [{'indices': [10, 17], 'text': 'Boston'},
#     {'indices': [55, 63], 'text': 'traffic'}],
#    'symbols': [],
#    'urls': [{'display_url': 'bit.ly/YAC1Ic',
#      'expanded_url': 'http://bit.ly/YAC1Ic',
#      'indices': [64, 87],
#      'url': 'https://t.co/AoTr5OKtFq'}],
#    'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': {'coordinates': [42.34756, -71.07923], 'type': 'Point'},
#   'id': 1116200589908750336,
#   'id_str': '1116200589908750336',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': {'attributes': {},
#    'bounding_box': {'coordinates': [[[-71.191421, 42.227797],
#       [-70.986004, 42.227797],
#       [-70.986004, 42.399542],
#       [-71.191421, 42.399542]]],
#     'type': 'Polygon'},
#    'contained_within': [],
#    'country': 'United States',
#    'country_code': 'US',
#    'full_name': 'Boston, MA',
#    'id': '67b98f17fdcf20be',
#    'name': 'Boston',
#    'place_type': 'city',
#    'url': 'https://api.twitter.com/1.1/geo/id/67b98f17fdcf20be.json'},
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://www.sigalert.com/Map.asp?region=Boston" rel="nofollow">TTN BOS traffic</a>',
#   'text': 'Closed in #Boston on Mass Pike EB at IC 22 - Copley Sq #traffic https://t.co/AoTr5OKtFq',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Tue Feb 08 23:36:19 +0000 2011',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': '',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 0,
#    'follow_request_sent': False,
#    'followers_count': 3261,
#    'following': False,
#    'friends_count': 1,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 249393984,
#    'id_str': '249393984',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 138,
#    'location': 'Boston, MA',
#    'name': 'TTWN Boston',
#    'notifications': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/439089134884253696/iOThgitH_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/439089134884253696/iOThgitH_normal.png',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'TotalTrafficBOS',
#    'statuses_count': 62084,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': {'coordinates': [-71.06112, 42.33037], 'type': 'Point'},
#   'created_at': 'Thu Apr 11 04:30:41 +0000 2019',
#   'entities': {'hashtags': [{'indices': [10, 17], 'text': 'Boston'},
#     {'indices': [78, 86], 'text': 'traffic'}],
#    'symbols': [],
#    'urls': [{'display_url': 'bit.ly/YAC1Ic',
#      'expanded_url': 'http://bit.ly/YAC1Ic',
#      'indices': [87, 110],
#      'url': 'https://t.co/AoTr5OKtFq'}],
#    'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': {'coordinates': [42.33037, -71.06112], 'type': 'Point'},
#   'id': 1116196849520730112,
#   'id_str': '1116196849520730112',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': {'attributes': {},
#    'bounding_box': {'coordinates': [[[-71.191421, 42.227797],
#       [-70.986004, 42.227797],
#       [-70.986004, 42.399542],
#       [-71.191421, 42.399542]]],
#     'type': 'Polygon'},
#    'contained_within': [],
#    'country': 'United States',
#    'country_code': 'US',
#    'full_name': 'Boston, MA',
#    'id': '67b98f17fdcf20be',
#    'name': 'Boston',
#    'place_type': 'city',
#    'url': 'https://api.twitter.com/1.1/geo/id/67b98f17fdcf20be.json'},
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://www.sigalert.com/Map.asp?region=Boston" rel="nofollow">TTN BOS traffic</a>',
#   'text': 'Closed in #Boston on Rt 93 NB from EX 16 - Southampton St to EX 18 - Mass Ave #traffic https://t.co/AoTr5OKtFq',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Tue Feb 08 23:36:19 +0000 2011',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': '',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 0,
#    'follow_request_sent': False,
#    'followers_count': 3261,
#    'following': False,
#    'friends_count': 1,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 249393984,
#    'id_str': '249393984',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 138,
#    'location': 'Boston, MA',
#    'name': 'TTWN Boston',
#    'notifications': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/439089134884253696/iOThgitH_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/439089134884253696/iOThgitH_normal.png',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'TotalTrafficBOS',
#    'statuses_count': 62084,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': {'coordinates': [-71.06112, 42.33037], 'type': 'Point'},
#   'created_at': 'Thu Apr 11 04:27:06 +0000 2019',
#   'entities': {'hashtags': [{'indices': [10, 17], 'text': 'Boston'},
#     {'indices': [79, 87], 'text': 'traffic'}],
#    'symbols': [],
#    'urls': [{'display_url': 'bit.ly/YAC1Ic',
#      'expanded_url': 'http://bit.ly/YAC1Ic',
#      'indices': [88, 111],
#      'url': 'https://t.co/AoTr5OKtFq'}],
#    'user_mentions': []},
#   'favorite_count': 1,
#   'favorited': False,
#   'geo': {'coordinates': [42.33037, -71.06112], 'type': 'Point'},
#   'id': 1116195947204304896,
#   'id_str': '1116195947204304896',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': {'attributes': {},
#    'bounding_box': {'coordinates': [[[-71.191421, 42.227797],
#       [-70.986004, 42.227797],
#       [-70.986004, 42.399542],
#       [-71.191421, 42.399542]]],
#     'type': 'Polygon'},
#    'contained_within': [],
#    'country': 'United States',
#    'country_code': 'US',
#    'full_name': 'Boston, MA',
#    'id': '67b98f17fdcf20be',
#    'name': 'Boston',
#    'place_type': 'city',
#    'url': 'https://api.twitter.com/1.1/geo/id/67b98f17fdcf20be.json'},
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://www.sigalert.com/Map.asp?region=Boston" rel="nofollow">TTN BOS traffic</a>',
#   'text': 'Closed in #Boston on Rt 93 NB from EX 16 - Southampton St to EX 20 - Mass Pike #traffic https://t.co/AoTr5OKtFq',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Tue Feb 08 23:36:19 +0000 2011',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': '',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 0,
#    'follow_request_sent': False,
#    'followers_count': 3261,
#    'following': False,
#    'friends_count': 1,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 249393984,
#    'id_str': '249393984',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 138,
#    'location': 'Boston, MA',
#    'name': 'TTWN Boston',
#    'notifications': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/439089134884253696/iOThgitH_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/439089134884253696/iOThgitH_normal.png',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'TotalTrafficBOS',
#    'statuses_count': 62084,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': {'coordinates': [-71.06112, 42.33037], 'type': 'Point'},
#   'created_at': 'Thu Apr 11 04:15:19 +0000 2019',
#   'entities': {'hashtags': [{'indices': [10, 17], 'text': 'Boston'},
#     {'indices': [83, 91], 'text': 'traffic'}],
#    'symbols': [],
#    'urls': [{'display_url': 'bit.ly/YAC1Ic',
#      'expanded_url': 'http://bit.ly/YAC1Ic',
#      'indices': [92, 115],
#      'url': 'https://t.co/AoTr5OKtFq'}],
#    'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': {'coordinates': [42.33037, -71.06112], 'type': 'Point'},
#   'id': 1116192982426845185,
#   'id_str': '1116192982426845185',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': {'attributes': {},
#    'bounding_box': {'coordinates': [[[-71.191421, 42.227797],
#       [-70.986004, 42.227797],
#       [-70.986004, 42.399542],
#       [-71.191421, 42.399542]]],
#     'type': 'Polygon'},
#    'contained_within': [],
#    'country': 'United States',
#    'country_code': 'US',
#    'full_name': 'Boston, MA',
#    'id': '67b98f17fdcf20be',
#    'name': 'Boston',
#    'place_type': 'city',
#    'url': 'https://api.twitter.com/1.1/geo/id/67b98f17fdcf20be.json'},
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://www.sigalert.com/Map.asp?region=Boston" rel="nofollow">TTN BOS traffic</a>',
#   'text': 'Closed in #Boston on Rt 93 NB from EX 16 - Southampton St and to EX 20 - Mass Pike #traffic https://t.co/AoTr5OKtFq',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Tue Feb 08 23:36:19 +0000 2011',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': '',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 0,
#    'follow_request_sent': False,
#    'followers_count': 3261,
#    'following': False,
#    'friends_count': 1,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 249393984,
#    'id_str': '249393984',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 138,
#    'location': 'Boston, MA',
#    'name': 'TTWN Boston',
#    'notifications': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/439089134884253696/iOThgitH_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/439089134884253696/iOThgitH_normal.png',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'TotalTrafficBOS',
#    'statuses_count': 62084,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': {'coordinates': [-71.05365, 42.36284], 'type': 'Point'},
#   'created_at': 'Wed Apr 10 03:37:11 +0000 2019',
#   'entities': {'hashtags': [{'indices': [10, 17], 'text': 'Boston'},
#     {'indices': [45, 53], 'text': 'traffic'}],
#    'symbols': [],
#    'urls': [{'display_url': 'bit.ly/YAC1Ic',
#      'expanded_url': 'http://bit.ly/YAC1Ic',
#      'indices': [54, 77],
#      'url': 'https://t.co/AoTr5OKtFq'}],
#    'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': {'coordinates': [42.36284, -71.05365], 'type': 'Point'},
#   'id': 1115820996542509058,
#   'id_str': '1115820996542509058',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': {'attributes': {},
#    'bounding_box': {'coordinates': [[[-71.191421, 42.227797],
#       [-70.986004, 42.227797],
#       [-70.986004, 42.399542],
#       [-71.191421, 42.399542]]],
#     'type': 'Polygon'},
#    'contained_within': [],
#    'country': 'United States',
#    'country_code': 'US',
#    'full_name': 'Boston, MA',
#    'id': '67b98f17fdcf20be',
#    'name': 'Boston',
#    'place_type': 'city',
#    'url': 'https://api.twitter.com/1.1/geo/id/67b98f17fdcf20be.json'},
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://www.sigalert.com/Map.asp?region=Boston" rel="nofollow">TTN BOS traffic</a>',
#   'text': 'Closed in #Boston on Rt 1A SB at Sumner Tunl #traffic https://t.co/AoTr5OKtFq',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Tue Feb 08 23:36:19 +0000 2011',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': '',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 0,
#    'follow_request_sent': False,
#    'followers_count': 3261,
#    'following': False,
#    'friends_count': 1,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 249393984,
#    'id_str': '249393984',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 138,
#    'location': 'Boston, MA',
#    'name': 'TTWN Boston',
#    'notifications': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/439089134884253696/iOThgitH_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/439089134884253696/iOThgitH_normal.png',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'TotalTrafficBOS',
#    'statuses_count': 62084,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': {'coordinates': [-71.03821, 42.37323], 'type': 'Point'},
#   'created_at': 'Tue Apr 09 06:08:51 +0000 2019',
#   'entities': {'hashtags': [{'indices': [10, 17], 'text': 'Boston'},
#     {'indices': [47, 55], 'text': 'traffic'}],
#    'symbols': [],
#    'urls': [{'display_url': 'bit.ly/YAC1Ic',
#      'expanded_url': 'http://bit.ly/YAC1Ic',
#      'indices': [56, 79],
#      'url': 'https://t.co/AoTr5OKtFq'}],
#    'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': {'coordinates': [42.37323, -71.03821], 'type': 'Point'},
#   'id': 1115496776637853697,
#   'id_str': '1115496776637853697',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': {'attributes': {},
#    'bounding_box': {'coordinates': [[[-71.191421, 42.227797],
#       [-70.986004, 42.227797],
#       [-70.986004, 42.399542],
#       [-71.191421, 42.399542]]],
#     'type': 'Polygon'},
#    'contained_within': [],
#    'country': 'United States',
#    'country_code': 'US',
#    'full_name': 'Boston, MA',
#    'id': '67b98f17fdcf20be',
#    'name': 'Boston',
#    'place_type': 'city',
#    'url': 'https://api.twitter.com/1.1/geo/id/67b98f17fdcf20be.json'},
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://www.sigalert.com/Map.asp?region=Boston" rel="nofollow">TTN BOS traffic</a>',
#   'text': 'Closed in #Boston on Rt 1A NB at Callahan Tunl #traffic https://t.co/AoTr5OKtFq',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Tue Feb 08 23:36:19 +0000 2011',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': '',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 0,
#    'follow_request_sent': False,
#    'followers_count': 3261,
#    'following': False,
#    'friends_count': 1,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 249393984,
#    'id_str': '249393984',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 138,
#    'location': 'Boston, MA',
#    'name': 'TTWN Boston',
#    'notifications': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/439089134884253696/iOThgitH_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/439089134884253696/iOThgitH_normal.png',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'TotalTrafficBOS',
#    'statuses_count': 62084,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Apr 08 23:44:33 +0000 2019',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#      'expanded_url': 'https://twitter.com/i/web/status/1115400064724295685',
#      'indices': [117, 140],
#      'url': 'https://t.co/0dzrJi47C9'}],
#    'user_mentions': [{'id': 31841271,
#      'id_str': '31841271',
#      'indices': [0, 13],
#      'name': 'Shaleen Title',
#      'screen_name': 'shaleentitle'}]},
#   'favorite_count': 8,
#   'favorited': False,
#   'geo': None,
#   'id': 1115400064724295685,
#   'id_str': '1115400064724295685',
#   'in_reply_to_screen_name': 'shaleentitle',
#   'in_reply_to_status_id': 1115378164828602368,
#   'in_reply_to_status_id_str': '1115378164828602368',
#   'in_reply_to_user_id': 31841271,
#   'in_reply_to_user_id_str': '31841271',
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': {'attributes': {},
#    'bounding_box': {'coordinates': [[[-71.191421, 42.227797],
#       [-70.986004, 42.227797],
#       [-70.986004, 42.399542],
#       [-71.191421, 42.399542]]],
#     'type': 'Polygon'},
#    'contained_within': [],
#    'country': 'United States',
#    'country_code': 'US',
#    'full_name': 'Boston, MA',
#    'id': '67b98f17fdcf20be',
#    'name': 'Boston',
#    'place_type': 'city',
#    'url': 'https://api.twitter.com/1.1/geo/id/67b98f17fdcf20be.json'},
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': '@shaleentitle Also pretty misleading photos on the cover. NETA closed the parking lot to keep the opening weekend l… https://t.co/0dzrJi47C9',
#   'truncated': True,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Thu Apr 02 02:20:31 +0000 2009',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'At the intersection of real estate, community and tech to realize the full potential of overlooked spaces. Director @Patronicity. #proptech #civictech #startup',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'buildingBOS.com',
#        'expanded_url': 'http://buildingBOS.com',
#        'indices': [0, 23],
#        'url': 'https://t.co/SGUfz1Tsw6'}]}},
#    'favourites_count': 43216,
#    'follow_request_sent': False,
#    'followers_count': 3857,
#    'following': False,
#    'friends_count': 2964,
#    'geo_enabled': True,
#    'has_extended_profile': True,
#    'id': 28259514,
#    'id_str': '28259514',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 130,
#    'location': 'Boston, MA',
#    'name': 'Jonathan Berk',
#    'notifications': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/28259514/1532364952',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1050414115653672961/PPJo69FI_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1050414115653672961/PPJo69FI_normal.jpg',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'berkie1',
#    'statuses_count': 10869,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': 'https://t.co/SGUfz1Tsw6',
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': {'coordinates': [-71.12368, 42.36838], 'type': 'Point'},
#   'created_at': 'Mon Apr 08 06:48:56 +0000 2019',
#   'entities': {'hashtags': [{'indices': [10, 18], 'text': 'Allston'},
#     {'indices': [59, 67], 'text': 'traffic'}],
#    'symbols': [],
#    'urls': [{'display_url': 'bit.ly/YAC1Ic',
#      'expanded_url': 'http://bit.ly/YAC1Ic',
#      'indices': [68, 91],
#      'url': 'https://t.co/AoTr5OKtFq'}],
#    'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': {'coordinates': [42.36838, -71.12368], 'type': 'Point'},
#   'id': 1115144478036254720,
#   'id_str': '1115144478036254720',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': {'attributes': {},
#    'bounding_box': {'coordinates': [[[-71.191421, 42.227797],
#       [-70.986004, 42.227797],
#       [-70.986004, 42.399542],
#       [-71.191421, 42.399542]]],
#     'type': 'Polygon'},
#    'contained_within': [],
#    'country': 'United States',
#    'country_code': 'US',
#    'full_name': 'Boston, MA',
#    'id': '67b98f17fdcf20be',
#    'name': 'Boston',
#    'place_type': 'city',
#    'url': 'https://api.twitter.com/1.1/geo/id/67b98f17fdcf20be.json'},
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://www.sigalert.com/Map.asp?region=Boston" rel="nofollow">TTN BOS traffic</a>',
#   'text': 'Closed in #Allston on Soldiers Field Rd EB at N Harvard St #traffic https://t.co/AoTr5OKtFq',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Tue Feb 08 23:36:19 +0000 2011',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': '',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 0,
#    'follow_request_sent': False,
#    'followers_count': 3261,
#    'following': False,
#    'friends_count': 1,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 249393984,
#    'id_str': '249393984',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 138,
#    'location': 'Boston, MA',
#    'name': 'TTWN Boston',
#    'notifications': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/439089134884253696/iOThgitH_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/439089134884253696/iOThgitH_normal.png',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'TotalTrafficBOS',
#    'statuses_count': 62084,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': {'coordinates': [-71.08259, 42.40478], 'type': 'Point'},
#   'created_at': 'Sun Apr 07 15:45:31 +0000 2019',
#   'entities': {'hashtags': [{'indices': [30, 38], 'text': 'Medford'},
#     {'indices': [83, 91], 'text': 'traffic'}],
#    'symbols': [],
#    'urls': [{'display_url': 'bit.ly/YAC1Ic',
#      'expanded_url': 'http://bit.ly/YAC1Ic',
#      'indices': [92, 115],
#      'url': 'https://t.co/AoTr5OKtFq'}],
#    'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': {'coordinates': [42.40478, -71.08259], 'type': 'Point'},
#   'id': 1114917126802948097,
#   'id_str': '1114917126802948097',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': {'attributes': {},
#    'bounding_box': {'coordinates': [[[-71.149807, 42.396145],
#       [-71.071833, 42.396145],
#       [-71.071833, 42.453759],
#       [-71.149807, 42.453759]]],
#     'type': 'Polygon'},
#    'contained_within': [],
#    'country': 'United States',
#    'country_code': 'US',
#    'full_name': 'Medford, MA',
#    'id': 'c8e7273a81fab7c0',
#    'name': 'Medford',
#    'place_type': 'city',
#    'url': 'https://api.twitter.com/1.1/geo/id/c8e7273a81fab7c0.json'},
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://www.sigalert.com/Map.asp?region=Boston" rel="nofollow">TTN BOS traffic</a>',
#   'text': 'Road closed intermittently in #Medford on Rt-16 Both EB/WB between Rt-28 and Rt-99 #traffic https://t.co/AoTr5OKtFq',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Tue Feb 08 23:36:19 +0000 2011',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': '',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 0,
#    'follow_request_sent': False,
#    'followers_count': 3261,
#    'following': False,
#    'friends_count': 1,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 249393984,
#    'id_str': '249393984',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 138,
#    'location': 'Boston, MA',
#    'name': 'TTWN Boston',
#    'notifications': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/439089134884253696/iOThgitH_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/439089134884253696/iOThgitH_normal.png',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'TotalTrafficBOS',
#    'statuses_count': 62084,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Sun Apr 07 15:20:09 +0000 2019',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#      'expanded_url': 'https://twitter.com/i/web/status/1114910740417323010',
#      'indices': [120, 143],
#      'url': 'https://t.co/QlRanZRJcG'}],
#    'user_mentions': [{'id': 23595586,
#      'id_str': '23595586',
#      'indices': [22, 30],
#      'name': 'Mass. Transportation',
#      'screen_name': 'MassDOT'}]},
#   'favorite_count': 4,
#   'favorited': False,
#   'geo': None,
#   'id': 1114910740417323010,
#   'id_str': '1114910740417323010',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': {'attributes': {},
#    'bounding_box': {'coordinates': [[[-71.191421, 42.227797],
#       [-70.986004, 42.227797],
#       [-70.986004, 42.399542],
#       [-71.191421, 42.399542]]],
#     'type': 'Polygon'},
#    'contained_within': [],
#    'country': 'United States',
#    'country_code': 'US',
#    'full_name': 'Boston, MA',
#    'id': '67b98f17fdcf20be',
#    'name': 'Boston',
#    'place_type': 'city',
#    'url': 'https://api.twitter.com/1.1/geo/id/67b98f17fdcf20be.json'},
#   'retweet_count': 1,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': 'Traffic advisory from @MassDOT —&gt; Route 16 westbound in Everett at Sweetser Circle is CLOSED due to police and firs… https://t.co/QlRanZRJcG',
#   'truncated': True,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Thu May 22 23:21:12 +0000 2014',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': '@MassDOT Communications. @UofNH alum. Email: Patrick.Marvin@state.ma.us.',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'massdot.state.ma.us',
#        'expanded_url': 'http://www.massdot.state.ma.us',
#        'indices': [0, 23],
#        'url': 'https://t.co/lN7LbRAC5y'}]}},
#    'favourites_count': 1567,
#    'follow_request_sent': False,
#    'followers_count': 2067,
#    'following': False,
#    'friends_count': 1926,
#    'geo_enabled': True,
#    'has_extended_profile': True,
#    'id': 2516570035,
#    'id_str': '2516570035',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 55,
#    'location': 'Boston, MA',
#    'name': 'Patrick Marvin',
#    'notifications': False,
#    'profile_background_color': 'FAFAFA',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2516570035/1504098815',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1087900204219711489/19PoMfrz_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1087900204219711489/19PoMfrz_normal.jpg',
#    'profile_link_color': '1B95E0',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'pmarvin123',
#    'statuses_count': 4207,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': 'https://t.co/lN7LbRAC5y',
#    'utc_offset': None,
#    'verified': False}}]

# %% [markdown]
# **Add the newly created json file to the list below for easy access later**

# %%
# Previously created json files can be accessed from this list
#json_df = pd.read_json("./medford_20190415_17_41.json", lines = True)
#json_df = pd.read_json("./medford_20190415_21_24.json", lines = True)
json_df = pd.read_json("../json/medford_20190415_23_25.json", lines = True)

# %% [markdown]
# **Explore the Tweets from json file**

# %%
json_df.shape
# Out:
# (1, 25)

# %%
json_df.head(2)
# Out:
#    contributors                                        coordinates  \
# 0           NaN  {'coordinates': [-71.08259, 42.40478], 'type':...
#
#            created_at                                           entities  \
# 0 2019-04-07 15:45:31  {'hashtags': [{'indices': [30, 38], 'text': 'M...
#
#    favorite_count  favorited  \
# 0               0      False
#
#                                                  geo                   id  \
# 0  {'coordinates': [42.40478, -71.08259], 'type':...  1114917126802948097
#
#                 id_str  in_reply_to_screen_name  ...  lang  \
# 0  1114917126802948096                      NaN  ...    en
#
#                                             metadata  \
# 0  {'iso_language_code': 'en', 'result_type': 're...
#
#                                                place  possibly_sensitive  \
# 0  {'attributes': {}, 'bounding_box': {'coordinat...               False
#
#    retweet_count retweeted                                             source  \
# 0              0     False  <a href="http://www.sigalert.com/Map.asp?regio...
#
#                                                 text  truncated  \
# 0  Road closed intermittently in #Medford on Rt-1...      False
#
#                                                 user
# 0  {'contributors_enabled': False, 'created_at': ...
#
# [1 rows x 25 columns]

# %%
# feature names
json_df.columns
# Out:
# Index(['contributors', 'coordinates', 'created_at', 'entities',
#        'favorite_count', 'favorited', 'geo', 'id', 'id_str',
#        'in_reply_to_screen_name', 'in_reply_to_status_id',
#        'in_reply_to_status_id_str', 'in_reply_to_user_id',
#        'in_reply_to_user_id_str', 'is_quote_status', 'lang', 'metadata',
#        'place', 'possibly_sensitive', 'retweet_count', 'retweeted', 'source',
#        'text', 'truncated', 'user'],
#       dtype='object')

# %% [markdown]
# **View all tweets from the `text` column** (for the first 7 tweets)

# %% [markdown]
# **reduce down to only the useful columns**

# %%
medford = json_df[['coordinates', 'created_at', 'geo', 'place','text']]

# %%
medford['text'][0]
# Out:
# 'Road closed intermittently in #Medford on Rt-16 Both EB/WB between Rt-28 and Rt-99 #traffic https://t.co/AoTr5OKtFq'

# %% [markdown]
# ### Explore some features of the df

# %%
# see all the nested information within place (for the first two tweets)
list = medford.loc[:1, 'place']
for i in range(len(list)):
    print(i, list[i])
    print("--------")
# Out:
# 0 {'attributes': {}, 'bounding_box': {'coordinates': [[[-71.149807, 42.396145], [-71.071833, 42.396145], [-71.071833, 42.453759], [-71.149807, 42.453759]]], 'type': 'Polygon'}, 'contained_within': [], 'country': 'United States', 'country_code': 'US', 'full_name': 'Medford, MA', 'id': 'c8e7273a81fab7c0', 'name': 'Medford', 'place_type': 'city', 'url': 'https://api.twitter.com/1.1/geo/id/c8e7273a81fab7c0.json'}
# --------

# %% [markdown]
# > The dataframe that we have now has many attributes nested within other attributes. If we want to access the corrdinates nested within `coordinates` or the city nested within `place` we will need to unpack these variables using a different method. Use the next section to convert nested values into their own columns.

# %% [markdown]
# ## Option B. Tweets --> json --> parsed --> nested dataframe

# %%
# Read in json file
medford = pd.read_json("../json/medford_20190415_23_25.json", lines = True)

# convert json file to list of dictionaries
tweets_data = []
notParsed = []
tweets_file = open("../json/medford_20190415_23_25.json","r")
for line in tweets_file:    
    if line.strip():    
        try:
            tweet=json.loads(line)
            tweets_data.append(tweet)
        except:
            notParsed.append(line)
            continue
print(len(tweets_data))
print('Could not parse: ', len(notParsed))
# Out:
# 1
# Could not parse:  0

# %% [markdown]
# **Unpack the nested columns**

# %%
tweet_cols = ['coordinates', 'created_at', 
              'text','geo', 'id', 'place', 'user']

sample_tweets_dict = [{col:tweet[col] for col in tweet_cols } for tweet in tweets_data]

# This method looks for any instances of nested dictionaries (DOES NOT FLATTEN LISTS)
sample_tweets_df = pd.io.json.json_normalize(sample_tweets_dict)

sample_tweets_df.head(2)
# Out:
#   coordinates.coordinates coordinates.type                      created_at  \
# 0   [-71.08259, 42.40478]            Point  Sun Apr 07 15:45:31 +0000 2019
#
#          geo.coordinates geo.type                   id  \
# 0  [42.40478, -71.08259]    Point  1114917126802948097
#
#                       place.bounding_box.coordinates place.bounding_box.type  \
# 0  [[[-71.149807, 42.396145], [-71.071833, 42.396...                 Polygon
#
#   place.contained_within  place.country  ... user.profile_text_color  \
# 0                     []  United States  ...                  333333
#
#   user.profile_use_background_image user.protected user.screen_name  \
# 0                              True          False  TotalTrafficBOS
#
#   user.statuses_count user.time_zone user.translator_type  user.url  \
# 0               62032           None                 none      None
#
#   user.utc_offset  user.verified
# 0            None          False
#
# [1 rows x 58 columns]

# %%
sample_tweets_df.columns
# Out:
# Index(['coordinates.coordinates', 'coordinates.type', 'created_at',
#        'geo.coordinates', 'geo.type', 'id', 'place.bounding_box.coordinates',
#        'place.bounding_box.type', 'place.contained_within', 'place.country',
#        'place.country_code', 'place.full_name', 'place.id', 'place.name',
#        'place.place_type', 'place.url', 'text', 'user.contributors_enabled',
#        'user.created_at', 'user.default_profile', 'user.default_profile_image',
#        'user.description', 'user.entities.description.urls',
#        'user.favourites_count', 'user.follow_request_sent',
#        'user.followers_count', 'user.following', 'user.friends_count',
#        'user.geo_enabled', 'user.has_extended_profile', 'user.id',
#        'user.id_str', 'user.is_translation_enabled', 'user.is_translator',
#        'user.lang', 'user.listed_count', 'user.location', 'user.name',
#        'user.notifications', 'user.profile_background_color',
#        'user.profile_background_image_url',
#        'user.profile_background_image_url_https',
#        'user.profile_background_tile', 'user.profile_image_url',
#        'user.profile_image_url_https', 'user.profile_link_color',
#        'user.profile_sidebar_border_color', 'user.profile_sidebar_fill_color',
#        'user.profile_text_color', 'user.profile_use_background_image',
#        'user.protected', 'user.screen_name', 'user.statuses_count',
#        'user.time_zone', 'user.translator_type', 'user.url', 'user.utc_offset',
#        'user.verified'],
#       dtype='object')

# %%
# save the USA (or Houston) historical json file as df, COMMENT OUT
df = sample_tweets_df
df.to_csv("../csv/medford.csv", index = False)

# %% [markdown]
# Examine who the most common tweets are coming from

# %%
sample_tweets_df['user.screen_name'].value_counts().head()
# Out:
# TotalTrafficBOS    1
# Name: user.screen_name, dtype: int64
