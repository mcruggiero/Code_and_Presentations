# %% [markdown]
# # "Historical" Tweets - from Twitter Search API using Tweepy Library <br>
#
# _Authors: Amy Taylor and Veronica Giannotta_ <br> <br>
# Preliminary steps before using Twitter's API:
# 1. Sign-up for a twitter account
# 2. Register a twitter developer account (requires email or phone number)
# 3. Create a developer app (I went with the name BlockedRoads)
# 4. Obtain your 'Access token' and 'access token secret' in the developer dashboard

# %% [markdown]
# Load Imports

# %%
import pandas as pd
import tweepy
import shutil
import jsonpickle
import json
import datetime
import config

from pandas.io.json import json_normalize

# %% [markdown]
# ## Part 1: Prepare API credentials
# **Step 1: Authenticate account and tokens through tweepy**
# <br>Required credentials:
# <br>`config.consumer_key` = 'your_consumer_key'
# <br>`config.consumer_secret` = 'your_consumer_secret'
# <br>`config.access_token` = 'your_access_token'
# <br>`config.access_token_secret` = 'your_access_token_secret'

# %%
# authenticate account with tweepy
auth = tweepy.OAuthHandler('1ZWD1JS7xivKADeOCV7zVXgI4', 'TgsgO0MaUYw2dccUVC7KtD8SYUX4QYaoxT52D4ye2146d0sLHo')
auth.set_access_token('3799487133-rGUwhJRC2pKZmx8UbureNKPxXSdZAgsWnOrjMQk', 'jOr0vlL0gzyRh1gOQTievE2ZAvuN1sD2FgYCGilFKmE60')

# create API object to pull data from twitter - and pass in authentication code
api = tweepy.API(auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True)

# %% [markdown]
# Now we are free to make Twitter API calls

# %% [markdown]
# **Step 2: Verify API is working with your account**
# - Run this cell to check if program is working. Output is your twitter name

# %%
user = api.me()
print (user.name)
# Out:
# Dali Souayah

# %% [markdown]
# **Step 3: Use geo_search API to get the `place_id` for a particular location**
# - `place_id` is a unique id created by Twitter that is assigned to different neighborhoods/cities/countries
# - In the query parameter, type the name of the city or country you want the place_id for
# - granularity = neighborhood (default) , city , admin or country
#     - EX: when query = 'Boston', the place_id generated is the same for neighborhood or city ( but empty for country)

# %%
#  Determine the city, country, or location you want
places = api.geo_search(query="Medford, MA", 
                        granularity="city"
                                          )
place_id = places[0].id
print('place_id is: 988257060feb2e4b',place_id)
# Out:
# place_id is: 988257060feb2e4b 7520fc0be21c62bf

# %% [markdown]
# ***List of search queries made:***
# <br>NOTE: there must be no space between place and place_ID
#
#
# |searchQuery| place ID |granularity| file | # of tweets| extended tweet? |
# |---|---|---|---|---|---|
# |'place:96683cc9126741d1 road closed' | USA |country| ./PoGo_USA_Tutorial.json20190114_7_1_36.json | 142 | - |
# | 'place:1c69a67ad480e1b1 road closed' | Houston | city/neigh | ./historical_20190114_11_59.json| 15|- |
# | 'Houston road closed' | NA | NA | ./historical_20190114_12_2.json | 9|- |
# |'place:96683cc9126741d1 road closed' | USA |city| ./historical_20190115_14_57.json | 210 | yes |
# |'place:1c69a67ad480e1b1 road closed' | Houston |city| ./historical_20190117_11_49.json | 13 | no |

# %% [markdown]
# ## Part 2: Download Archived Tweets with the Search API
# **Step 1: Use tweepy library to download tweets from Search API based on our query search terms, and save tweets as a json file**
#  - Include a place ID in the query if necessary
#  - Other search params that are optional: since='2019-01-03',until='2019-01-11'
#
# useful resource: http://www.dealingdata.net/2016/07/23/PoGo-Series-Tweepy/

# %%
searchQuery = 'place:988257060feb2e4b closed traffic'

tweetCount = 0

#Open a text file to save the tweets to
with open('./medford.json', 'w') as f:

    #Tell the Cursor method: we want to use Search API (api.search), and our query
    for tweet in tweepy.Cursor(api.search,q=searchQuery,
#                                tweet_mode='extended'    #comment out extended tweet if desired
                              ).items() :         

        #Verify the tweet has place info before writing 
        if tweet.place is not None:
            
            #Write the JSON format to the text file, and add one to the number of tweets we've collected
            f.write(jsonpickle.encode(tweet._json, unpicklable=False) + '\n')
            tweetCount += 1

    #Display how many tweets we have collected
    print("Downloaded {0} tweets".format(tweetCount))
# Out:
# Downloaded 40 tweets

# %% [markdown]
# **Step 2: Append a timestamp to the end of the json file name**

# %%
def file_conversion():
    #create a timestamp
    now = datetime.datetime.now()
    month = '0'+str(now.month)
    day = str(now.day)
    hour = str(now.hour)
    minute = str(now.minute)
    now_str = str(now.year)+month+day+'_'+hour+'_'+minute
    
    
    #replace the name of our file with a new timestamped filename
    
    dest = './medford_' + now_str + ".json"
    shutil.move('./medford.json', dest)
    
    with open(dest, "r") as f:
        status = f.readlines()
        jsons = []
        for ind in status:
            jsons.append(json.loads(ind))
    return jsons

# Uncomment out the file_conversion function to activate the file name change
file_conversion()
# Out:
# [{'contributors': None,
#   'coordinates': {'coordinates': [-71.07923, 42.34756], 'type': 'Point'},
#   'created_at': 'Mon Apr 15 19:03:54 +0000 2019',
#   'entities': {'hashtags': [{'indices': [19, 26], 'text': 'Boston'},
#     {'indices': [81, 89], 'text': 'traffic'}],
#    'symbols': [],
#    'urls': [{'display_url': 'bit.ly/YAC1Ic',
#      'expanded_url': 'http://bit.ly/YAC1Ic',
#      'indices': [90, 113],
#      'url': 'https://t.co/AoTr5OsSgQ'}],
#    'user_mentions': []},
#   'favorite_count': 2,
#   'favorited': False,
#   'geo': {'coordinates': [42.34756, -71.07923], 'type': 'Point'},
#   'id': 1117866152829448192,
#   'id_str': '1117866152829448192',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': {'attributes': {},
#    'bounding_box': {'coordinates': [[[-71.191421, 42.227797],
#       [-70.986004, 42.227797],
#       [-70.986004, 42.399542],
#       [-71.191421, 42.399542]]],
#     'type': 'Polygon'},
#    'contained_within': [],
#    'country': 'United States',
#    'country_code': 'US',
#    'full_name': 'Boston, MA',
#    'id': '67b98f17fdcf20be',
#    'name': 'Boston',
#    'place_type': 'city',
#    'url': 'https://api.twitter.com/1.1/geo/id/67b98f17fdcf20be.json'},
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://www.sigalert.com/Map.asp?region=Boston" rel="nofollow">TTN BOS traffic</a>',
#   'text': 'Off-ramp closed in #Boston on Mass Pike EB at IC 22 - Copley Sq, delay of 5 mins #traffic https://t.co/AoTr5OsSgQ',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Tue Feb 08 23:36:19 +0000 2011',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': '',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 0,
#    'follow_request_sent': False,
#    'followers_count': 3260,
#    'following': False,
#    'friends_count': 1,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 249393984,
#    'id_str': '249393984',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 138,
#    'location': 'Boston, MA',
#    'name': 'TTWN Boston',
#    'notifications': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/439089134884253696/iOThgitH_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/439089134884253696/iOThgitH_normal.png',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'TotalTrafficBOS',
#    'statuses_count': 62030,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': {'coordinates': [-71.54642, 42.21384], 'type': 'Point'},
#   'created_at': 'Mon Apr 15 13:57:21 +0000 2019',
#   'entities': {'hashtags': [{'indices': [19, 29], 'text': 'Hopkinton'},
#     {'indices': [64, 72], 'text': 'traffic'}],
#    'symbols': [],
#    'urls': [{'display_url': 'bit.ly/YAC1Ic',
#      'expanded_url': 'http://bit.ly/YAC1Ic',
#      'indices': [73, 96],
#      'url': 'https://t.co/AoTr5OKtFq'}],
#    'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': {'coordinates': [42.21384, -71.54642], 'type': 'Point'},
#   'id': 1117789008589983744,
#   'id_str': '1117789008589983744',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': {'attributes': {},
#    'bounding_box': {'coordinates': [[[-71.596679, 42.184354],
#       [-71.460478, 42.184354],
#       [-71.460478, 42.267443],
#       [-71.596679, 42.267443]]],
#     'type': 'Polygon'},
#    'contained_within': [],
#    'country': 'United States',
#    'country_code': 'US',
#    'full_name': 'Hopkinton, MA',
#    'id': '7f22ddc6360b50e3',
#    'name': 'Hopkinton',
#    'place_type': 'city',
#    'url': 'https://api.twitter.com/1.1/geo/id/7f22ddc6360b50e3.json'},
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://www.sigalert.com/Map.asp?region=Boston" rel="nofollow">TTN BOS traffic</a>',
#   'text': 'Off-ramp closed in #Hopkinton on Rt 495 SB at EX 21 - W Main St #traffic https://t.co/AoTr5OKtFq',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Tue Feb 08 23:36:19 +0000 2011',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': '',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 0,
#    'follow_request_sent': False,
#    'followers_count': 3260,
#    'following': False,
#    'friends_count': 1,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 249393984,
#    'id_str': '249393984',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 138,
#    'location': 'Boston, MA',
#    'name': 'TTWN Boston',
#    'notifications': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/439089134884253696/iOThgitH_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/439089134884253696/iOThgitH_normal.png',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'TotalTrafficBOS',
#    'statuses_count': 62030,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': {'coordinates': [-71.54642, 42.21384], 'type': 'Point'},
#   'created_at': 'Mon Apr 15 13:56:46 +0000 2019',
#   'entities': {'hashtags': [{'indices': [19, 29], 'text': 'Hopkinton'},
#     {'indices': [81, 89], 'text': 'traffic'}],
#    'symbols': [],
#    'urls': [{'display_url': 'bit.ly/YAC1Ic',
#      'expanded_url': 'http://bit.ly/YAC1Ic',
#      'indices': [90, 113],
#      'url': 'https://t.co/AoTr5OKtFq'}],
#    'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': {'coordinates': [42.21384, -71.54642], 'type': 'Point'},
#   'id': 1117788861583826944,
#   'id_str': '1117788861583826944',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': {'attributes': {},
#    'bounding_box': {'coordinates': [[[-71.596679, 42.184354],
#       [-71.460478, 42.184354],
#       [-71.460478, 42.267443],
#       [-71.596679, 42.267443]]],
#     'type': 'Polygon'},
#    'contained_within': [],
#    'country': 'United States',
#    'country_code': 'US',
#    'full_name': 'Hopkinton, MA',
#    'id': '7f22ddc6360b50e3',
#    'name': 'Hopkinton',
#    'place_type': 'city',
#    'url': 'https://api.twitter.com/1.1/geo/id/7f22ddc6360b50e3.json'},
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://www.sigalert.com/Map.asp?region=Boston" rel="nofollow">TTN BOS traffic</a>',
#   'text': 'Off-ramp closed in #Hopkinton on Rt 495 SB at EX 21 - W Main St, delay of 5 mins #traffic https://t.co/AoTr5OKtFq',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Tue Feb 08 23:36:19 +0000 2011',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': '',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 0,
#    'follow_request_sent': False,
#    'followers_count': 3260,
#    'following': False,
#    'friends_count': 1,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 249393984,
#    'id_str': '249393984',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 138,
#    'location': 'Boston, MA',
#    'name': 'TTWN Boston',
#    'notifications': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/439089134884253696/iOThgitH_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/439089134884253696/iOThgitH_normal.png',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'TotalTrafficBOS',
#    'statuses_count': 62030,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Apr 15 13:52:43 +0000 2019',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#      'expanded_url': 'https://twitter.com/i/web/status/1117787841629687810',
#      'indices': [121, 144],
#      'url': 'https://t.co/Ey48WuYUk4'}],
#    'user_mentions': []},
#   'favorite_count': 5,
#   'favorited': False,
#   'geo': None,
#   'id': 1117787841629687810,
#   'id_str': '1117787841629687810',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': {'attributes': {},
#    'bounding_box': {'coordinates': [[[-70.467597, 41.5997971],
#       [-70.259465, 41.5997971],
#       [-70.259465, 41.735676],
#       [-70.467597, 41.735676]]],
#     'type': 'Polygon'},
#    'contained_within': [],
#    'country': 'United States',
#    'country_code': 'US',
#    'full_name': 'Barnstable Town, MA',
#    'id': '072afef2aa2f1bf5',
#    'name': 'Barnstable Town',
#    'place_type': 'city',
#    'url': 'https://api.twitter.com/1.1/geo/id/072afef2aa2f1bf5.json'},
#   'possibly_sensitive': False,
#   'retweet_count': 4,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'text': 'Due to high winds, two large trees have fallen at the intersection of Main St. &amp; West Bay Rd. in Osterville.  Barns… https://t.co/Ey48WuYUk4',
#   'truncated': True,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Fri Oct 28 17:00:11 +0000 2011',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': '',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'barnstablepolice.com',
#        'expanded_url': 'http://www.barnstablepolice.com',
#        'indices': [0, 22],
#        'url': 'http://t.co/l8PzbjeFYI'}]}},
#    'favourites_count': 0,
#    'follow_request_sent': False,
#    'followers_count': 5856,
#    'following': False,
#    'friends_count': 6,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 400194194,
#    'id_str': '400194194',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 122,
#    'location': 'Barnstable, MA',
#    'name': 'Barnstable Police',
#    'notifications': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/998297865997844481/UUxsENm1_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/998297865997844481/UUxsENm1_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'BarnstablePDMa',
#    'statuses_count': 983,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': 'http://t.co/l8PzbjeFYI',
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': {'coordinates': [-71.2518, 42.32836], 'type': 'Point'},
#   'created_at': 'Mon Apr 15 13:49:35 +0000 2019',
#   'entities': {'hashtags': [{'indices': [18, 25], 'text': 'Newton'},
#     {'indices': [55, 63], 'text': 'traffic'}],
#    'symbols': [],
#    'urls': [{'display_url': 'bit.ly/YAC1Ic',
#      'expanded_url': 'http://bit.ly/YAC1Ic',
#      'indices': [64, 87],
#      'url': 'https://t.co/AoTr5OsSgQ'}],
#    'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': {'coordinates': [42.32836, -71.2518], 'type': 'Point'},
#   'id': 1117787053469528064,
#   'id_str': '1117787053469528064',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': {'attributes': {},
#    'bounding_box': {'coordinates': [[[-71.270426, 42.283041],
#       [-71.156939, 42.283041],
#       [-71.156939, 42.367744],
#       [-71.270426, 42.367744]]],
#     'type': 'Polygon'},
#    'contained_within': [],
#    'country': 'United States',
#    'country_code': 'US',
#    'full_name': 'Newton, MA',
#    'id': 'b76630ca2b2c4158',
#    'name': 'Newton',
#    'place_type': 'city',
#    'url': 'https://api.twitter.com/1.1/geo/id/b76630ca2b2c4158.json'},
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://www.sigalert.com/Map.asp?region=Boston" rel="nofollow">TTN BOS traffic</a>',
#   'text': 'On-ramp closed in #Newton on Rt 95 NB at EX 21 - Rt-16 #traffic https://t.co/AoTr5OsSgQ',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Tue Feb 08 23:36:19 +0000 2011',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': '',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 0,
#    'follow_request_sent': False,
#    'followers_count': 3260,
#    'following': False,
#    'friends_count': 1,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 249393984,
#    'id_str': '249393984',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 138,
#    'location': 'Boston, MA',
#    'name': 'TTWN Boston',
#    'notifications': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/439089134884253696/iOThgitH_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/439089134884253696/iOThgitH_normal.png',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'TotalTrafficBOS',
#    'statuses_count': 62030,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': {'coordinates': [-71.07923, 42.34756], 'type': 'Point'},
#   'created_at': 'Mon Apr 15 13:41:53 +0000 2019',
#   'entities': {'hashtags': [{'indices': [19, 26], 'text': 'Boston'},
#     {'indices': [115, 123], 'text': 'traffic'}],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': []},
#   'favorite_count': 2,
#   'favorited': False,
#   'geo': {'coordinates': [42.34756, -71.07923], 'type': 'Point'},
#   'id': 1117785115378241538,
#   'id_str': '1117785115378241538',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': {'attributes': {},
#    'bounding_box': {'coordinates': [[[-71.191421, 42.227797],
#       [-70.986004, 42.227797],
#       [-70.986004, 42.399542],
#       [-71.191421, 42.399542]]],
#     'type': 'Polygon'},
#    'contained_within': [],
#    'country': 'United States',
#    'country_code': 'US',
#    'full_name': 'Boston, MA',
#    'id': '67b98f17fdcf20be',
#    'name': 'Boston',
#    'place_type': 'city',
#    'url': 'https://api.twitter.com/1.1/geo/id/67b98f17fdcf20be.json'},
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://www.sigalert.com/Map.asp?region=Boston" rel="nofollow">TTN BOS traffic</a>',
#   'text': 'Off-ramp closed in #Boston on Mass Pike EB at IC 22 - Copley Sq, stopped traffic back to Mass Ave, delay of 5 mins #traffic',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Tue Feb 08 23:36:19 +0000 2011',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': '',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 0,
#    'follow_request_sent': False,
#    'followers_count': 3260,
#    'following': False,
#    'friends_count': 1,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 249393984,
#    'id_str': '249393984',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 138,
#    'location': 'Boston, MA',
#    'name': 'TTWN Boston',
#    'notifications': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/439089134884253696/iOThgitH_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/439089134884253696/iOThgitH_normal.png',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'TotalTrafficBOS',
#    'statuses_count': 62030,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': {'coordinates': [-71.07923, 42.34756], 'type': 'Point'},
#   'created_at': 'Mon Apr 15 13:09:16 +0000 2019',
#   'entities': {'hashtags': [{'indices': [19, 26], 'text': 'Boston'},
#     {'indices': [81, 89], 'text': 'traffic'}],
#    'symbols': [],
#    'urls': [{'display_url': 'bit.ly/YAC1Ic',
#      'expanded_url': 'http://bit.ly/YAC1Ic',
#      'indices': [90, 113],
#      'url': 'https://t.co/AoTr5OKtFq'}],
#    'user_mentions': []},
#   'favorite_count': 1,
#   'favorited': False,
#   'geo': {'coordinates': [42.34756, -71.07923], 'type': 'Point'},
#   'id': 1117776906160627712,
#   'id_str': '1117776906160627712',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': {'attributes': {},
#    'bounding_box': {'coordinates': [[[-71.191421, 42.227797],
#       [-70.986004, 42.227797],
#       [-70.986004, 42.399542],
#       [-71.191421, 42.399542]]],
#     'type': 'Polygon'},
#    'contained_within': [],
#    'country': 'United States',
#    'country_code': 'US',
#    'full_name': 'Boston, MA',
#    'id': '67b98f17fdcf20be',
#    'name': 'Boston',
#    'place_type': 'city',
#    'url': 'https://api.twitter.com/1.1/geo/id/67b98f17fdcf20be.json'},
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://www.sigalert.com/Map.asp?region=Boston" rel="nofollow">TTN BOS traffic</a>',
#   'text': 'Off-ramp closed in #Boston on Mass Pike EB at IC 22 - Copley Sq, delay of 5 mins #traffic https://t.co/AoTr5OKtFq',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Tue Feb 08 23:36:19 +0000 2011',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': '',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 0,
#    'follow_request_sent': False,
#    'followers_count': 3260,
#    'following': False,
#    'friends_count': 1,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 249393984,
#    'id_str': '249393984',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 138,
#    'location': 'Boston, MA',
#    'name': 'TTWN Boston',
#    'notifications': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/439089134884253696/iOThgitH_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/439089134884253696/iOThgitH_normal.png',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'TotalTrafficBOS',
#    'statuses_count': 62030,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': {'coordinates': [-71.2518, 42.32836], 'type': 'Point'},
#   'created_at': 'Mon Apr 15 12:47:32 +0000 2019',
#   'entities': {'hashtags': [{'indices': [18, 25], 'text': 'Newton'},
#     {'indices': [55, 63], 'text': 'traffic'}],
#    'symbols': [],
#    'urls': [{'display_url': 'bit.ly/YAC1Ic',
#      'expanded_url': 'http://bit.ly/YAC1Ic',
#      'indices': [64, 87],
#      'url': 'https://t.co/AoTr5OKtFq'}],
#    'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': {'coordinates': [42.32836, -71.2518], 'type': 'Point'},
#   'id': 1117771436645654528,
#   'id_str': '1117771436645654528',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': {'attributes': {},
#    'bounding_box': {'coordinates': [[[-71.270426, 42.283041],
#       [-71.156939, 42.283041],
#       [-71.156939, 42.367744],
#       [-71.270426, 42.367744]]],
#     'type': 'Polygon'},
#    'contained_within': [],
#    'country': 'United States',
#    'country_code': 'US',
#    'full_name': 'Newton, MA',
#    'id': 'b76630ca2b2c4158',
#    'name': 'Newton',
#    'place_type': 'city',
#    'url': 'https://api.twitter.com/1.1/geo/id/b76630ca2b2c4158.json'},
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://www.sigalert.com/Map.asp?region=Boston" rel="nofollow">TTN BOS traffic</a>',
#   'text': 'On-ramp closed in #Newton on Rt 95 NB at EX 21 - Rt-16 #traffic https://t.co/AoTr5OKtFq',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Tue Feb 08 23:36:19 +0000 2011',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': '',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 0,
#    'follow_request_sent': False,
#    'followers_count': 3260,
#    'following': False,
#    'friends_count': 1,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 249393984,
#    'id_str': '249393984',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 138,
#    'location': 'Boston, MA',
#    'name': 'TTWN Boston',
#    'notifications': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/439089134884253696/iOThgitH_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/439089134884253696/iOThgitH_normal.png',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'TotalTrafficBOS',
#    'statuses_count': 62030,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': {'coordinates': [-71.2518, 42.32836], 'type': 'Point'},
#   'created_at': 'Mon Apr 15 12:46:17 +0000 2019',
#   'entities': {'hashtags': [{'indices': [18, 25], 'text': 'Newton'},
#     {'indices': [72, 80], 'text': 'traffic'}],
#    'symbols': [],
#    'urls': [{'display_url': 'bit.ly/YAC1Ic',
#      'expanded_url': 'http://bit.ly/YAC1Ic',
#      'indices': [81, 104],
#      'url': 'https://t.co/AoTr5OKtFq'}],
#    'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': {'coordinates': [42.32836, -71.2518], 'type': 'Point'},
#   'id': 1117771121217232896,
#   'id_str': '1117771121217232896',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': {'attributes': {},
#    'bounding_box': {'coordinates': [[[-71.270426, 42.283041],
#       [-71.156939, 42.283041],
#       [-71.156939, 42.367744],
#       [-71.270426, 42.367744]]],
#     'type': 'Polygon'},
#    'contained_within': [],
#    'country': 'United States',
#    'country_code': 'US',
#    'full_name': 'Newton, MA',
#    'id': 'b76630ca2b2c4158',
#    'name': 'Newton',
#    'place_type': 'city',
#    'url': 'https://api.twitter.com/1.1/geo/id/b76630ca2b2c4158.json'},
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://www.sigalert.com/Map.asp?region=Boston" rel="nofollow">TTN BOS traffic</a>',
#   'text': 'On-ramp closed in #Newton on Rt 95 NB at EX 21 - Rt-16, delay of 4 mins #traffic https://t.co/AoTr5OKtFq',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Tue Feb 08 23:36:19 +0000 2011',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': '',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 0,
#    'follow_request_sent': False,
#    'followers_count': 3260,
#    'following': False,
#    'friends_count': 1,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 249393984,
#    'id_str': '249393984',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 138,
#    'location': 'Boston, MA',
#    'name': 'TTWN Boston',
#    'notifications': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/439089134884253696/iOThgitH_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/439089134884253696/iOThgitH_normal.png',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'TotalTrafficBOS',
#    'statuses_count': 62030,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': {'coordinates': [-71.54642, 42.21384], 'type': 'Point'},
#   'created_at': 'Mon Apr 15 11:29:49 +0000 2019',
#   'entities': {'hashtags': [{'indices': [19, 29], 'text': 'Hopkinton'},
#     {'indices': [121, 129], 'text': 'traffic'}],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': {'coordinates': [42.21384, -71.54642], 'type': 'Point'},
#   'id': 1117751879293911040,
#   'id_str': '1117751879293911040',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': {'attributes': {},
#    'bounding_box': {'coordinates': [[[-71.596679, 42.184354],
#       [-71.460478, 42.184354],
#       [-71.460478, 42.267443],
#       [-71.596679, 42.267443]]],
#     'type': 'Polygon'},
#    'contained_within': [],
#    'country': 'United States',
#    'country_code': 'US',
#    'full_name': 'Hopkinton, MA',
#    'id': '7f22ddc6360b50e3',
#    'name': 'Hopkinton',
#    'place_type': 'city',
#    'url': 'https://api.twitter.com/1.1/geo/id/7f22ddc6360b50e3.json'},
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://www.sigalert.com/Map.asp?region=Boston" rel="nofollow">TTN BOS traffic</a>',
#   'text': 'Off-ramp closed in #Hopkinton on Rt 495 NB at EX 21 - W Main St, stopped traffic back to EX 20 - Rt-85, delay of 10 mins #traffic',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Tue Feb 08 23:36:19 +0000 2011',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': '',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 0,
#    'follow_request_sent': False,
#    'followers_count': 3260,
#    'following': False,
#    'friends_count': 1,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 249393984,
#    'id_str': '249393984',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 138,
#    'location': 'Boston, MA',
#    'name': 'TTWN Boston',
#    'notifications': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/439089134884253696/iOThgitH_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/439089134884253696/iOThgitH_normal.png',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'TotalTrafficBOS',
#    'statuses_count': 62030,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': {'coordinates': [-71.54642, 42.21384], 'type': 'Point'},
#   'created_at': 'Mon Apr 15 11:01:33 +0000 2019',
#   'entities': {'hashtags': [{'indices': [19, 29], 'text': 'Hopkinton'},
#     {'indices': [81, 89], 'text': 'traffic'}],
#    'symbols': [],
#    'urls': [{'display_url': 'bit.ly/YAC1Ic',
#      'expanded_url': 'http://bit.ly/YAC1Ic',
#      'indices': [90, 113],
#      'url': 'https://t.co/AoTr5OKtFq'}],
#    'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': {'coordinates': [42.21384, -71.54642], 'type': 'Point'},
#   'id': 1117744765171314688,
#   'id_str': '1117744765171314688',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': {'attributes': {},
#    'bounding_box': {'coordinates': [[[-71.596679, 42.184354],
#       [-71.460478, 42.184354],
#       [-71.460478, 42.267443],
#       [-71.596679, 42.267443]]],
#     'type': 'Polygon'},
#    'contained_within': [],
#    'country': 'United States',
#    'country_code': 'US',
#    'full_name': 'Hopkinton, MA',
#    'id': '7f22ddc6360b50e3',
#    'name': 'Hopkinton',
#    'place_type': 'city',
#    'url': 'https://api.twitter.com/1.1/geo/id/7f22ddc6360b50e3.json'},
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://www.sigalert.com/Map.asp?region=Boston" rel="nofollow">TTN BOS traffic</a>',
#   'text': 'Off-ramp closed in #Hopkinton on Rt 495 NB at EX 21 - W Main St, delay of 4 mins #traffic https://t.co/AoTr5OKtFq',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Tue Feb 08 23:36:19 +0000 2011',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': '',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 0,
#    'follow_request_sent': False,
#    'followers_count': 3260,
#    'following': False,
#    'friends_count': 1,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 249393984,
#    'id_str': '249393984',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 138,
#    'location': 'Boston, MA',
#    'name': 'TTWN Boston',
#    'notifications': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/439089134884253696/iOThgitH_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/439089134884253696/iOThgitH_normal.png',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'TotalTrafficBOS',
#    'statuses_count': 62030,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': {'coordinates': [-71.17135, 42.17115], 'type': 'Point'},
#   'created_at': 'Sat Apr 13 15:20:17 +0000 2019',
#   'entities': {'hashtags': [{'indices': [10, 17], 'text': 'Canton'},
#     {'indices': [56, 64], 'text': 'traffic'}],
#    'symbols': [],
#    'urls': [{'display_url': 'bit.ly/YAC1Ic',
#      'expanded_url': 'http://bit.ly/YAC1Ic',
#      'indices': [65, 88],
#      'url': 'https://t.co/AoTr5OKtFq'}],
#    'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': {'coordinates': [42.17115, -71.17135], 'type': 'Point'},
#   'id': 1117085103845531653,
#   'id_str': '1117085103845531653',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': {'attributes': {},
#    'bounding_box': {'coordinates': [[[-71.238551, 42.149887],
#       [-71.153926, 42.149887],
#       [-71.153926, 42.213847],
#       [-71.238551, 42.213847]]],
#     'type': 'Polygon'},
#    'contained_within': [],
#    'country': 'United States',
#    'country_code': 'US',
#    'full_name': 'Norwood, MA',
#    'id': 'b7d826f55dca45e9',
#    'name': 'Norwood',
#    'place_type': 'city',
#    'url': 'https://api.twitter.com/1.1/geo/id/b7d826f55dca45e9.json'},
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://www.sigalert.com/Map.asp?region=Boston" rel="nofollow">TTN BOS traffic</a>',
#   'text': 'Closed in #Canton on Rt 95 NB after EX 11 - Neponset St #traffic https://t.co/AoTr5OKtFq',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Tue Feb 08 23:36:19 +0000 2011',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': '',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 0,
#    'follow_request_sent': False,
#    'followers_count': 3260,
#    'following': False,
#    'friends_count': 1,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 249393984,
#    'id_str': '249393984',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 138,
#    'location': 'Boston, MA',
#    'name': 'TTWN Boston',
#    'notifications': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/439089134884253696/iOThgitH_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/439089134884253696/iOThgitH_normal.png',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'TotalTrafficBOS',
#    'statuses_count': 62030,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': {'coordinates': [-71.57101, 42.32146], 'type': 'Point'},
#   'created_at': 'Sat Apr 13 04:52:17 +0000 2019',
#   'entities': {'hashtags': [{'indices': [26, 38], 'text': 'Marlborough'},
#     {'indices': [93, 101], 'text': 'traffic'}],
#    'symbols': [],
#    'urls': [{'display_url': 'bit.ly/YAC1Ic',
#      'expanded_url': 'http://bit.ly/YAC1Ic',
#      'indices': [102, 125],
#      'url': 'https://t.co/AoTr5OKtFq'}],
#    'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': {'coordinates': [42.32146, -71.57101], 'type': 'Point'},
#   'id': 1116927061581619200,
#   'id_str': '1116927061581619200',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': {'attributes': {},
#    'bounding_box': {'coordinates': [[[-71.625705, 42.3109818],
#       [-71.475702, 42.3109818],
#       [-71.475702, 42.380659],
#       [-71.625705, 42.380659]]],
#     'type': 'Polygon'},
#    'contained_within': [],
#    'country': 'United States',
#    'country_code': 'US',
#    'full_name': 'Marlborough, MA',
#    'id': 'fbe7a12a76a49216',
#    'name': 'Marlborough',
#    'place_type': 'city',
#    'url': 'https://api.twitter.com/1.1/geo/id/fbe7a12a76a49216.json'},
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://www.sigalert.com/Map.asp?region=Boston" rel="nofollow">TTN BOS traffic</a>',
#   'text': 'Closed due to accident in #Marlborough on Rt 495 SB at EX 23C - Simarano Dr and EX 23 - Rt-9 #traffic https://t.co/AoTr5OKtFq',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Tue Feb 08 23:36:19 +0000 2011',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': '',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 0,
#    'follow_request_sent': False,
#    'followers_count': 3260,
#    'following': False,
#    'friends_count': 1,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 249393984,
#    'id_str': '249393984',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 138,
#    'location': 'Boston, MA',
#    'name': 'TTWN Boston',
#    'notifications': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/439089134884253696/iOThgitH_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/439089134884253696/iOThgitH_normal.png',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'TotalTrafficBOS',
#    'statuses_count': 62030,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': {'coordinates': [-71.61552, 42.84527], 'type': 'Point'},
#   'created_at': 'Fri Apr 12 22:05:12 +0000 2019',
#   'entities': {'hashtags': [{'indices': [26, 34], 'text': 'Amherst'},
#     {'indices': [82, 90], 'text': 'traffic'}],
#    'symbols': [],
#    'urls': [{'display_url': 'bit.ly/16C5bZf',
#      'expanded_url': 'http://bit.ly/16C5bZf',
#      'indices': [91, 114],
#      'url': 'https://t.co/GjQNQFw5W4'}],
#    'user_mentions': []},
#   'favorite_count': 1,
#   'favorited': False,
#   'geo': {'coordinates': [42.84527, -71.61552], 'type': 'Point'},
#   'id': 1116824613902790656,
#   'id_str': '1116824613902790656',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': {'attributes': {},
#    'bounding_box': {'coordinates': [[[-71.6386148, 42.7899799],
#       [-71.558659, 42.7899799],
#       [-71.558659, 42.886588],
#       [-71.6386148, 42.886588]]],
#     'type': 'Polygon'},
#    'contained_within': [],
#    'country': 'United States',
#    'country_code': 'US',
#    'full_name': 'Amherst, NH',
#    'id': '0179b77b631f2eed',
#    'name': 'Amherst',
#    'place_type': 'city',
#    'url': 'https://api.twitter.com/1.1/geo/id/0179b77b631f2eed.json'},
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://www.sigalert.com/Map.asp?region=Manchester" rel="nofollow">TTN MHT traffic</a>',
#   'text': 'Closed due to accident in #Amherst on NH-101 Both EB/WB between NH-122 and NH-101 #traffic https://t.co/GjQNQFw5W4',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Wed Feb 09 21:34:46 +0000 2011',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': '',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 0,
#    'follow_request_sent': False,
#    'followers_count': 161,
#    'following': False,
#    'friends_count': 1,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 249828592,
#    'id_str': '249828592',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 25,
#    'location': 'Manchester, NH',
#    'name': 'TTN Manchester',
#    'notifications': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/439096804756299776/2jh91kCt_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/439096804756299776/2jh91kCt_normal.png',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'TotalTrafficMHT',
#    'statuses_count': 15885,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': {'coordinates': [-71.10814, 42.3535], 'type': 'Point'},
#   'created_at': 'Fri Apr 12 10:17:27 +0000 2019',
#   'entities': {'hashtags': [{'indices': [26, 36], 'text': 'Cambridge'},
#     {'indices': [84, 92], 'text': 'traffic'}],
#    'symbols': [],
#    'urls': [{'display_url': 'bit.ly/YAC1Ic',
#      'expanded_url': 'http://bit.ly/YAC1Ic',
#      'indices': [93, 116],
#      'url': 'https://t.co/AoTr5OKtFq'}],
#    'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': {'coordinates': [42.3535, -71.10814], 'type': 'Point'},
#   'id': 1116646503416774656,
#   'id_str': '1116646503416774656',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': {'attributes': {},
#    'bounding_box': {'coordinates': [[[-71.160356, 42.352429],
#       [-71.064398, 42.352429],
#       [-71.064398, 42.4039663],
#       [-71.160356, 42.4039663]]],
#     'type': 'Polygon'},
#    'contained_within': [],
#    'country': 'United States',
#    'country_code': 'US',
#    'full_name': 'Cambridge, MA',
#    'id': '8193d87541f11dfb',
#    'name': 'Cambridge',
#    'place_type': 'city',
#    'url': 'https://api.twitter.com/1.1/geo/id/8193d87541f11dfb.json'},
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://www.sigalert.com/Map.asp?region=Boston" rel="nofollow">TTN BOS traffic</a>',
#   'text': 'Closed due to accident in #Cambridge on Memorial Dr EB between BU Brg and Vassar St #traffic https://t.co/AoTr5OKtFq',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Tue Feb 08 23:36:19 +0000 2011',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': '',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 0,
#    'follow_request_sent': False,
#    'followers_count': 3260,
#    'following': False,
#    'friends_count': 1,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 249393984,
#    'id_str': '249393984',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 138,
#    'location': 'Boston, MA',
#    'name': 'TTWN Boston',
#    'notifications': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/439089134884253696/iOThgitH_normal.png',
# ...
#   'geo': {'coordinates': [42.40478, -71.08259], 'type': 'Point'},
#   'id': 1114917126802948097,
#   'id_str': '1114917126802948097',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': {'attributes': {},
#    'bounding_box': {'coordinates': [[[-71.149807, 42.396145],
#       [-71.071833, 42.396145],
#       [-71.071833, 42.453759],
#       [-71.149807, 42.453759]]],
#     'type': 'Polygon'},
#    'contained_within': [],
#    'country': 'United States',
#    'country_code': 'US',
#    'full_name': 'Medford, MA',
#    'id': 'c8e7273a81fab7c0',
#    'name': 'Medford',
#    'place_type': 'city',
#    'url': 'https://api.twitter.com/1.1/geo/id/c8e7273a81fab7c0.json'},
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://www.sigalert.com/Map.asp?region=Boston" rel="nofollow">TTN BOS traffic</a>',
#   'text': 'Road closed intermittently in #Medford on Rt-16 Both EB/WB between Rt-28 and Rt-99 #traffic https://t.co/AoTr5OKtFq',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Tue Feb 08 23:36:19 +0000 2011',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': '',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 0,
#    'follow_request_sent': False,
#    'followers_count': 3260,
#    'following': False,
#    'friends_count': 1,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 249393984,
#    'id_str': '249393984',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 138,
#    'location': 'Boston, MA',
#    'name': 'TTWN Boston',
#    'notifications': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/439089134884253696/iOThgitH_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/439089134884253696/iOThgitH_normal.png',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'TotalTrafficBOS',
#    'statuses_count': 62030,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Sun Apr 07 15:20:09 +0000 2019',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#      'expanded_url': 'https://twitter.com/i/web/status/1114910740417323010',
#      'indices': [120, 143],
#      'url': 'https://t.co/QlRanZRJcG'}],
#    'user_mentions': [{'id': 23595586,
#      'id_str': '23595586',
#      'indices': [22, 30],
#      'name': 'Mass. Transportation',
#      'screen_name': 'MassDOT'}]},
#   'favorite_count': 4,
#   'favorited': False,
#   'geo': None,
#   'id': 1114910740417323010,
#   'id_str': '1114910740417323010',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': {'attributes': {},
#    'bounding_box': {'coordinates': [[[-71.191421, 42.227797],
#       [-70.986004, 42.227797],
#       [-70.986004, 42.399542],
#       [-71.191421, 42.399542]]],
#     'type': 'Polygon'},
#    'contained_within': [],
#    'country': 'United States',
#    'country_code': 'US',
#    'full_name': 'Boston, MA',
#    'id': '67b98f17fdcf20be',
#    'name': 'Boston',
#    'place_type': 'city',
#    'url': 'https://api.twitter.com/1.1/geo/id/67b98f17fdcf20be.json'},
#   'retweet_count': 1,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': 'Traffic advisory from @MassDOT —&gt; Route 16 westbound in Everett at Sweetser Circle is CLOSED due to police and firs… https://t.co/QlRanZRJcG',
#   'truncated': True,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Thu May 22 23:21:12 +0000 2014',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': '@MassDOT Communications. @UofNH alum. Email: Patrick.Marvin@state.ma.us.',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'massdot.state.ma.us',
#        'expanded_url': 'http://www.massdot.state.ma.us',
#        'indices': [0, 23],
#        'url': 'https://t.co/lN7LbRAC5y'}]}},
#    'favourites_count': 1567,
#    'follow_request_sent': False,
#    'followers_count': 2067,
#    'following': False,
#    'friends_count': 1923,
#    'geo_enabled': True,
#    'has_extended_profile': True,
#    'id': 2516570035,
#    'id_str': '2516570035',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 55,
#    'location': 'Boston, MA',
#    'name': 'Patrick Marvin',
#    'notifications': False,
#    'profile_background_color': 'FAFAFA',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2516570035/1504098815',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1087900204219711489/19PoMfrz_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1087900204219711489/19PoMfrz_normal.jpg',
#    'profile_link_color': '1B95E0',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'pmarvin123',
#    'statuses_count': 4207,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': 'https://t.co/lN7LbRAC5y',
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': {'coordinates': [-71.36062, 42.31435], 'type': 'Point'},
#   'created_at': 'Sat Apr 06 20:14:22 +0000 2019',
#   'entities': {'hashtags': [{'indices': [10, 17], 'text': 'Natick'},
#     {'indices': [56, 64], 'text': 'traffic'}],
#    'symbols': [],
#    'urls': [{'display_url': 'bit.ly/YAC1Ic',
#      'expanded_url': 'http://bit.ly/YAC1Ic',
#      'indices': [65, 88],
#      'url': 'https://t.co/AoTr5OKtFq'}],
#    'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': {'coordinates': [42.31435, -71.36062], 'type': 'Point'},
#   'id': 1114622395204165633,
#   'id_str': '1114622395204165633',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': {'attributes': {},
#    'bounding_box': {'coordinates': [[[-71.403412, 42.24214],
#       [-71.305249, 42.24214],
#       [-71.305249, 42.329027],
#       [-71.403412, 42.329027]]],
#     'type': 'Polygon'},
#    'contained_within': [],
#    'country': 'United States',
#    'country_code': 'US',
#    'full_name': 'Natick, MA',
#    'id': '003a365b39428a40',
#    'name': 'Natick',
#    'place_type': 'city',
#    'url': 'https://api.twitter.com/1.1/geo/id/003a365b39428a40.json'},
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://www.sigalert.com/Map.asp?region=Boston" rel="nofollow">TTN BOS traffic</a>',
#   'text': 'Closed in #Natick on Mass Pike WB at Natick Service Plz #traffic https://t.co/AoTr5OKtFq',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Tue Feb 08 23:36:19 +0000 2011',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': '',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 0,
#    'follow_request_sent': False,
#    'followers_count': 3260,
#    'following': False,
#    'friends_count': 1,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 249393984,
#    'id_str': '249393984',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 138,
#    'location': 'Boston, MA',
#    'name': 'TTWN Boston',
#    'notifications': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/439089134884253696/iOThgitH_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/439089134884253696/iOThgitH_normal.png',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'TotalTrafficBOS',
#    'statuses_count': 62030,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': {'coordinates': [-71.36062, 42.31435], 'type': 'Point'},
#   'created_at': 'Sat Apr 06 20:14:22 +0000 2019',
#   'entities': {'hashtags': [{'indices': [10, 17], 'text': 'Natick'},
#     {'indices': [56, 64], 'text': 'traffic'}],
#    'symbols': [],
#    'urls': [{'display_url': 'bit.ly/YAC1Ic',
#      'expanded_url': 'http://bit.ly/YAC1Ic',
#      'indices': [65, 88],
#      'url': 'https://t.co/AoTr5OKtFq'}],
#    'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': {'coordinates': [42.31435, -71.36062], 'type': 'Point'},
#   'id': 1114622394025558017,
#   'id_str': '1114622394025558017',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': {'attributes': {},
#    'bounding_box': {'coordinates': [[[-71.403412, 42.24214],
#       [-71.305249, 42.24214],
#       [-71.305249, 42.329027],
#       [-71.403412, 42.329027]]],
#     'type': 'Polygon'},
#    'contained_within': [],
#    'country': 'United States',
#    'country_code': 'US',
#    'full_name': 'Natick, MA',
#    'id': '003a365b39428a40',
#    'name': 'Natick',
#    'place_type': 'city',
#    'url': 'https://api.twitter.com/1.1/geo/id/003a365b39428a40.json'},
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://www.sigalert.com/Map.asp?region=Boston" rel="nofollow">TTN BOS traffic</a>',
#   'text': 'Closed in #Natick on Mass Pike EB at Natick Service Plz #traffic https://t.co/AoTr5OKtFq',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Tue Feb 08 23:36:19 +0000 2011',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': '',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 0,
#    'follow_request_sent': False,
#    'followers_count': 3260,
#    'following': False,
#    'friends_count': 1,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 249393984,
#    'id_str': '249393984',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 138,
#    'location': 'Boston, MA',
#    'name': 'TTWN Boston',
#    'notifications': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/439089134884253696/iOThgitH_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/439089134884253696/iOThgitH_normal.png',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'TotalTrafficBOS',
#    'statuses_count': 62030,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': {'coordinates': [-71.38795, 42.31324], 'type': 'Point'},
#   'created_at': 'Sat Apr 06 20:02:24 +0000 2019',
#   'entities': {'hashtags': [{'indices': [10, 17], 'text': 'Natick'},
#     {'indices': [51, 59], 'text': 'traffic'}],
#    'symbols': [],
#    'urls': [{'display_url': 'bit.ly/YAC1Ic',
#      'expanded_url': 'http://bit.ly/YAC1Ic',
#      'indices': [60, 83],
#      'url': 'https://t.co/AoTr5OKtFq'}],
#    'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': {'coordinates': [42.31324, -71.38795], 'type': 'Point'},
#   'id': 1114619383609999360,
#   'id_str': '1114619383609999360',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': {'attributes': {},
#    'bounding_box': {'coordinates': [[[-71.4971703, 42.257263],
#       [-71.374193, 42.257263],
#       [-71.374193, 42.352931],
#       [-71.4971703, 42.352931]]],
#     'type': 'Polygon'},
#    'contained_within': [],
#    'country': 'United States',
#    'country_code': 'US',
#    'full_name': 'Framingham, MA',
#    'id': 'dbd1411661903bb0',
#    'name': 'Framingham',
#    'place_type': 'city',
#    'url': 'https://api.twitter.com/1.1/geo/id/dbd1411661903bb0.json'},
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://www.sigalert.com/Map.asp?region=Boston" rel="nofollow">TTN BOS traffic</a>',
#   'text': 'Closed in #Natick on Mass Pike WB at IC 13 - Rt-30 #traffic https://t.co/AoTr5OKtFq',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Tue Feb 08 23:36:19 +0000 2011',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': '',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 0,
#    'follow_request_sent': False,
#    'followers_count': 3260,
#    'following': False,
#    'friends_count': 1,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 249393984,
#    'id_str': '249393984',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 138,
#    'location': 'Boston, MA',
#    'name': 'TTWN Boston',
#    'notifications': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/439089134884253696/iOThgitH_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/439089134884253696/iOThgitH_normal.png',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'TotalTrafficBOS',
#    'statuses_count': 62030,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}}]

# %% [markdown]
# **Step 3: Add the newly created json file to the list below for easy access later**

# %%
# Previously created json files can be accessed from this list
json_df = pd.read_json("./medford_20190415_17_41.json", lines = True)

# %% [markdown]
# # Part 3: Explore Tweets from json file
# ### Option A: Tweets --> json file --> dataframe

# %%
# list of columns currently available in our dataframe
json_df.columns
# Out:
# Index(['contributors', 'coordinates', 'created_at', 'entities',
#        'favorite_count', 'favorited', 'geo', 'id', 'id_str',
#        'in_reply_to_screen_name', 'in_reply_to_status_id',
#        'in_reply_to_status_id_str', 'in_reply_to_user_id',
#        'in_reply_to_user_id_str', 'is_quote_status', 'lang', 'metadata',
#        'place', 'possibly_sensitive', 'retweet_count', 'retweeted', 'source',
#        'text', 'truncated', 'user'],
#       dtype='object')

# %% [markdown]
# **View all tweets from the `text` column** (for the first 7 tweets)

# %%
json_df
# Out:
#    contributors                                        coordinates  \
# 0           NaN                                               None
# 1           NaN                                               None
# 2           NaN  {'coordinates': [-71.08259, 42.40478], 'type':...
#
#            created_at                                           entities  \
# 0 2019-04-11 12:55:40  {'hashtags': [], 'symbols': [], 'urls': [], 'u...
# 1 2019-04-11 12:39:00  {'hashtags': [], 'symbols': [], 'urls': [], 'u...
# 2 2019-04-07 15:45:31  {'hashtags': [{'indices': [30, 38], 'text': 'M...
#
#    favorite_count  favorited  \
# 0               0      False
# 1               0      False
# 2               0      False
#
#                                                  geo                   id  \
# 0                                               None  1116323934675320833
# 1                                               None  1116319736999157762
# 2  {'coordinates': [42.40478, -71.08259], 'type':...  1114917126802948097
#
#                 id_str  in_reply_to_screen_name  ...  lang  \
# 0  1116323934675320832                      NaN  ...    en
# 1  1116319736999157760                      NaN  ...    en
# 2  1114917126802948096                      NaN  ...    en
#
#                                             metadata  \
# 0  {'iso_language_code': 'en', 'result_type': 're...
# 1  {'iso_language_code': 'en', 'result_type': 're...
# 2  {'iso_language_code': 'en', 'result_type': 're...
#
#                                                place  possibly_sensitive  \
# 0  {'attributes': {}, 'bounding_box': {'coordinat...                 NaN
# 1  {'attributes': {}, 'bounding_box': {'coordinat...                 NaN
# 2  {'attributes': {}, 'bounding_box': {'coordinat...                 0.0
#
#    retweet_count retweeted                                             source  \
# 0              0     False  <a href="http://twitter.com/download/android" ...
# 1              0     False  <a href="http://twitter.com/download/android" ...
# 2              0     False  <a href="http://www.sigalert.com/Map.asp?regio...
#
#                                                 text  truncated  \
# 0  Centennial Avenue from Campbell Ave to Northsh...      False
# 1  Wave Ave from Atlantic Ave to Dolphin Ave is c...      False
# 2  Road closed intermittently in #Medford on Rt-1...      False
#
#                                                 user
# 0  {'contributors_enabled': False, 'created_at': ...
# 1  {'contributors_enabled': False, 'created_at': ...
# 2  {'contributors_enabled': False, 'created_at': ...
#
# [3 rows x 25 columns]

# %%
json_df['text']
# Out:
# 0    Centennial Avenue from Campbell Ave to Northsh...
# 1    Wave Ave from Atlantic Ave to Dolphin Ave is c...
# 2    Road closed intermittently in #Medford on Rt-1...
# Name: text, dtype: object

# %% [markdown]
# Explore attributes of the json file

# %%
def PrintMembers(obj):
    for attribute in dir(obj):
        #We don't want to show built in methods of the class
        if not attribute.startswith('__'):
            print(attribute)
PrintMembers(tweet)
# Out:
# _api
# _json
# author
# contributors
# coordinates
# created_at
# destroy
# entities
# favorite
# favorite_count
# favorited
# geo
# id
# id_str
# in_reply_to_screen_name
# in_reply_to_status_id
# in_reply_to_status_id_str
# in_reply_to_user_id
# in_reply_to_user_id_str
# is_quote_status
# lang
# metadata
# parse
# parse_list
# place
# possibly_sensitive
# retweet
# retweet_count
# retweeted
# retweets
# source
# source_url
# text
# truncated
# user

# %% [markdown]
# **Shrink dataframe down to only the useful columns**

# %%
columns = ['coordinates', 'created_at', 'geo', 'place', 'text', 'user']
df = json_df.loc[:, columns]
df.head()
# Out:
#                                          coordinates          created_at  \
# 0  {'coordinates': [-106.65, 35.08653], 'type': '... 2019-01-14 14:56:55
# 1  {'coordinates': [-111.0295, 32.29418], 'type':... 2019-01-14 14:31:30
# 2  {'coordinates': [-106.52, 31.79295], 'type': '... 2019-01-14 14:28:12
# 3                                               None 2019-01-14 14:08:05
# 4  {'coordinates': [-111.0295, 32.29418], 'type':... 2019-01-14 13:49:35
#
#                                                  geo  \
# 0  {'coordinates': [35.08653, -106.65], 'type': '...
# 1  {'coordinates': [32.29418, -111.0295], 'type':...
# 2  {'coordinates': [31.79295, -106.52], 'type': '...
# 3                                               None
# 4  {'coordinates': [32.29418, -111.0295], 'type':...
#
#                                                place  \
# 0  {'bounding_box': {'coordinates': [[[-106.79169...
# 1  {'bounding_box': {'coordinates': [[[-111.08321...
# 2  {'bounding_box': {'coordinates': [[[-106.63487...
# 3  {'bounding_box': {'coordinates': [[[-86.044756...
# 4  {'bounding_box': {'coordinates': [[[-111.08321...
#
#                                                 text  \
# 0  Road construction, left lane closed in #Albuqu...
# 1  Road construction. right lanes closed in #Pima...
# 2  Road construction, shoulder closed in #ElPaso ...
# 3  Ughhh at the dentist for a cleaning and the si...
# 4  Road constructions. two right lanes closed in ...
#
#                                                 user
# 0  {'listed_count': 73, 'friends_count': 226, 'pr...
# 1  {'listed_count': 82, 'friends_count': 303, 'pr...
# 2  {'listed_count': 47, 'friends_count': 455, 'pr...
# 3  {'listed_count': 37, 'friends_count': 1991, 'p...
# 4  {'listed_count': 82, 'friends_count': 303, 'pr...

# %% [markdown]
# ### Explore some features of the df

# %%
# see all the nested information within place (for the first two tweets)
list = json_df.loc[:1, 'place']
for i in range(len(list)):
    print(i, list[i])
    print("--------")
# Out:
# 0 {'bounding_box': {'coordinates': [[[-106.7916912, 35.0158912], [-106.473745, 35.0158912], [-106.473745, 35.218114], [-106.7916912, 35.218114]]], 'type': 'Polygon'}, 'id': '813a485b26b8dae2', 'country_code': 'US', 'place_type': 'city', 'url': 'https://api.twitter.com/1.1/geo/id/813a485b26b8dae2.json', 'contained_within': [], 'name': 'Albuquerque', 'attributes': {}, 'full_name': 'Albuquerque, NM', 'country': 'United States'}
# --------
# 1 {'bounding_box': {'coordinates': [[[-111.083219, 32.057802], [-110.747928, 32.057802], [-110.747928, 32.320979], [-111.083219, 32.320979]]], 'type': 'Polygon'}, 'id': '013379ee5729a5e6', 'country_code': 'US', 'place_type': 'city', 'url': 'https://api.twitter.com/1.1/geo/id/013379ee5729a5e6.json', 'contained_within': [], 'name': 'Tucson', 'attributes': {}, 'full_name': 'Tucson, AZ', 'country': 'United States'}
# --------

# %% [markdown]
# > The dataframe that we have now has many attributes nested within other attributes. If we want to access the corrdinates nested within `coordinates` or the city nested within `place` we will need to unpack these variables using a different method. Use the next section to convert nested values into their own columns.

# %% [markdown]
# ## Option B. Tweets --> json --> parsed --> nested dataframe

# %%
# Read in json file
json_df = pd.read_json("../data/AT_historical/PoGo_USA_Tutorial.json20190114_7_1_36.json", lines = True)

# convert json file to list of dictionaries
tweets_data = []
notParsed = []
tweets_file = open("../data/AT_historical/PoGo_USA_Tutorial.json20190114_7_1_36.json","r")
for line in tweets_file:    
    if line.strip():    
        try:
            tweet=json.loads(line)
            tweets_data.append(tweet)
        except:
            notParsed.append(line)
            continue
print(len(tweets_data))
print('Could not parse: ', len(notParsed))
# Out:
# 143
# Could not parse:  0

# %% [markdown]
# **Unpack the nested columns**

# %%
tweet_cols = ['coordinates', 'created_at', 
#                'full_text',
              'text','geo', 'id', 'place', 'user']

sample_tweets_dict = [{col:tweet[col] for col in tweet_cols } for tweet in tweets_data]

# This method looks for any instances of nested dictionaries (DOES NOT FLATTEN LISTS)
sample_tweets_df = pd.io.json.json_normalize(sample_tweets_dict)

sample_tweets_df.head(2)
# Out:
#    coordinates coordinates.coordinates coordinates.type  \
# 0          NaN     [-106.65, 35.08653]            Point
# 1          NaN   [-111.0295, 32.29418]            Point
#
#                        created_at  geo        geo.coordinates geo.type  \
# 0  Mon Jan 14 14:56:55 +0000 2019  NaN    [35.08653, -106.65]    Point
# 1  Mon Jan 14 14:31:30 +0000 2019  NaN  [32.29418, -111.0295]    Point
#
#                     id                     place.bounding_box.coordinates  \
# 0  1084826703724249089  [[[-106.7916912, 35.0158912], [-106.473745, 35...
# 1  1084820307217731584  [[[-111.083219, 32.057802], [-110.747928, 32.0...
#
#   place.bounding_box.type      ...       user.profile_text_color  \
# 0                 Polygon      ...                        333333
# 1                 Polygon      ...                        333333
#
#   user.profile_use_background_image user.protected user.screen_name  \
# 0                              True          False  TotalTrafficABQ
# 1                              True          False  TotalTrafficTUC
#
#   user.statuses_count user.time_zone user.translator_type  \
# 0               22351           None                 none
# 1               44176           None                 none
#
#                   user.url user.utc_offset  user.verified
# 0  https://t.co/0ksDF2WEvB            None          False
# 1                     None            None          False
#
# [2 rows x 62 columns]

# %%
sample_tweets_df.columns
# Out:
# Index(['coordinates', 'coordinates.coordinates', 'coordinates.type',
#        'created_at', 'geo', 'geo.coordinates', 'geo.type', 'id',
#        'place.bounding_box.coordinates', 'place.bounding_box.type',
#        'place.contained_within', 'place.country', 'place.country_code',
#        'place.full_name', 'place.id', 'place.name', 'place.place_type',
#        'place.url', 'text', 'user.contributors_enabled', 'user.created_at',
#        'user.default_profile', 'user.default_profile_image',
#        'user.description', 'user.entities.description.urls',
#        'user.entities.url.urls', 'user.favourites_count',
#        'user.follow_request_sent', 'user.followers_count', 'user.following',
#        'user.friends_count', 'user.geo_enabled', 'user.has_extended_profile',
#        'user.id', 'user.id_str', 'user.is_translation_enabled',
#        'user.is_translator', 'user.lang', 'user.listed_count', 'user.location',
#        'user.name', 'user.notifications', 'user.profile_background_color',
#        'user.profile_background_image_url',
#        'user.profile_background_image_url_https',
#        'user.profile_background_tile', 'user.profile_banner_url',
#        'user.profile_image_url', 'user.profile_image_url_https',
#        'user.profile_link_color', 'user.profile_sidebar_border_color',
#        'user.profile_sidebar_fill_color', 'user.profile_text_color',
#        'user.profile_use_background_image', 'user.protected',
#        'user.screen_name', 'user.statuses_count', 'user.time_zone',
#        'user.translator_type', 'user.url', 'user.utc_offset', 'user.verified'],
#       dtype='object')

# %%
# save the USA (or Houston) historical json file as df, COMMENT OUT
# df = sample_tweets_df
# df.to_csv("../data/AT_historical/USA_142tweets.csv", index = False)

# %% [markdown]
# Examine who the most common tweets are coming from

# %%
sample_tweets_df['user.screen_name'].value_counts().head()
# Out:
# TotalTrafficDFW    16
# TotalTrafficABQ    13
# TotalTrafficMIA    10
# TotalTrafficPHX     8
# AlgoTraffic         7
# Name: user.screen_name, dtype: int64

# %% [markdown]
# So the Twitter user "TotalTraffic", specific to a certain city, is contributing the most tweets to situations with "road closed", and providing location place data for each tweet
