# %%
# Author: Aric Hagberg (hagberg@lanl.gov)
import matplotlib.pyplot as plt
import networkx as nx

# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

G = nx.Graph()

G.add_edge('a', 'b', weight=0.6)
G.add_edge('a', 'c', weight=1.2)
G.add_edge('c', 'd', weight=0.1)
G.add_edge('c', 'e', weight=0.7)
G.add_edge('c', 'f', weight=1.3)
G.add_edge('a', 'd', weight=0.3)
G.add_edge('b', 'e', weight=0.5)

elarge = [(u, v) for (u, v, d) in G.edges(data=True) if d['weight'] > 0.5]
esmall = [(u, v) for (u, v, d) in G.edges(data=True) if d['weight'] <= 0.5]

pos = nx.spring_layout(G)  # positions for all nodes

# nodes
nx.draw_networkx_nodes(G, pos, node_size=700)

# edges
nx.draw_networkx_edges(G, pos, edgelist=elarge,
                       width=6)
nx.draw_networkx_edges(G, pos, edgelist=esmall,
                       width=6, alpha=0.5, edge_color='b', style='dashed')

# labels
nx.draw_networkx_labels(G, pos, font_size=20, font_family='sans-serif')

plt.axis('off')
plt.show()

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np

import lxml.html

# %%
# Target web page:
url = "https://mass511.com/list/events/traffic?start=0&length=500&order%5Bi%5D=2&order%5Bdir%5D=asc"
html = requests.get(url)
doc = lxml.html.fromstring(html.content)

# %%
url = "http://google.com/maps/dir/18+Pembroke+St,+Medford,+MA+02155/Medford+City+Hall,+85+George+P+Hassett+Dr,+Medford,+MA+02155/am=t/"
res = requests.get(url)
soup =  BeautifulSoup(res.content, 'lxml')

# %%
new_releases = doc.xpath('//div[@id="directions-mode-step-summary"]')[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-88-9937baadb89e> in <module>
# ----> 1 new_releases = doc.xpath('//div[@id="directions-mode-step-summary"]')[0]
#
# IndexError: list index out of range

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html itemscope="" itemtype="http://schema.org/Place" lang="en">
#  <head>
#   <link href="/maps/preview/opensearch.xml?hl=en" rel="search" title="Google Maps" type="application/opensearchdescription+xml"/>
#   <title>
#    Google Maps
#   </title>
#   <meta content=" Find local businesses, view maps and get driving directions in Google Maps. " name="Description"/>
#   <meta content="initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no" name="viewport"/>
#   <meta content="chrome=1" http-equiv="X-UA-Compatible"/>
#   <meta content="notranslate" name="google"/>
#   <meta content="origin" name="referrer"/>
#   <meta content="18 Pembroke St to Medford City Hall" itemprop="name"/>
#   <meta content="18 Pembroke St to Medford City Hall" property="og:title"/>
# ...

# %%
print(soup.title)
print(soup.title.text)
# Out:
# <title>  Google Maps  </title>
#   Google Maps

# %%
a = soup.find("div", {"id": "directions-mode-step-summary"})

# %%
print(a)
# Out:
# None

# %%
soup.find_all("div")
# Out:
# [<div class="topBanner" role="banner">
#  <noscript>
#  <span class="label label-warning">Javascript is disabled on your browser and this site won't work properly without Javascript enabled!</span>
#  </noscript>
#  <a class="sr-only sr-only-focusable" href="#content" title="Content">Skip to main content</a>
#  <div class="printSiteHeader">Mass511</div>
#  <nav class="navbar navbar-inverse" role="navigation">
#  <div class="container-fluid">
#  <div class="row navBar">
#  <div class="navbar-header">
#  <button class="navbar-toggle collapsed" data-target="#navbar-collapse" data-toggle="collapse" type="button">
#  <span class="sr-only">Toggle navigation</span>
#  <span class="icon-bar"></span>
#  <span class="icon-bar"></span>
#  <span class="icon-bar"></span>
#  </button>
#  <a class="navbar-brand" href="/" target="_self">
#  <span class="navbar-logo"><span class="hideForAccessibility">Massachusetts 511 Website in new tab</span></span>
#  </a>
#  </div>
# ...
