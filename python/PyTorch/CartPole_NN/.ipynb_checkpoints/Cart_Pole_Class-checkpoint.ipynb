# %% [markdown]
# # Comparison of DQL Networks in Pytorch
# <strong>Michael Ruggiero<br>
# Tuesday, August 6th, 2019<br>
# michael@mcruggiero.com</strong>

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Introduction" data-toc-modified-id="Introduction-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Introduction</a></span></li><li><span><a href="#Setup" data-toc-modified-id="Setup-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Setup</a></span><ul class="toc-item"><li><span><a href="#Library-Imports" data-toc-modified-id="Library-Imports-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Library Imports</a></span></li><li><span><a href="#Cuda-Support" data-toc-modified-id="Cuda-Support-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Cuda Support</a></span></li></ul></li><li><span><a href="#CartPole-v1-Environment" data-toc-modified-id="CartPole-v1-Environment-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>CartPole v1 Environment</a></span><ul class="toc-item"><li><span><a href="#CartPole-Introduction" data-toc-modified-id="CartPole-Introduction-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>CartPole Introduction</a></span></li><li><span><a href="#Action/Input-Space" data-toc-modified-id="Action/Input-Space-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Action/Input Space</a></span></li><li><span><a href="#Observation/Output-Space" data-toc-modified-id="Observation/Output-Space-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Observation/Output Space</a></span></li><li><span><a href="#Human-Demonstration" data-toc-modified-id="Human-Demonstration-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Human Demonstration</a></span></li><li><span><a href="#Report-Function" data-toc-modified-id="Report-Function-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Report Function</a></span></li></ul></li><li><span><a href="#Agent-Factory" data-toc-modified-id="Agent-Factory-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Agent Factory</a></span><ul class="toc-item"><li><span><a href="#Simulation-Function" data-toc-modified-id="Simulation-Function-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Simulation Function</a></span></li><li><span><a href="#Ploting-Function" data-toc-modified-id="Ploting-Function-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Ploting Function</a></span></li></ul></li><li><span><a href="#Random-Agent" data-toc-modified-id="Random-Agent-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Random Agent</a></span><ul class="toc-item"><li><span><a href="#Random-Agent-Demonstration" data-toc-modified-id="Random-Agent-Demonstration-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Random Agent Demonstration</a></span></li><li><span><a href="#Random-Agent-Simulation" data-toc-modified-id="Random-Agent-Simulation-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Random Agent Simulation</a></span></li></ul></li><li><span><a href="#Reinforcement-Learning-Introduction" data-toc-modified-id="Reinforcement-Learning-Introduction-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Reinforcement Learning Introduction</a></span><ul class="toc-item"><li><span><a href="#Human-Learning:-Work-Piece-Indicator" data-toc-modified-id="Human-Learning:-Work-Piece-Indicator-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Human Learning: Work Piece Indicator</a></span></li><li><span><a href="#Reinforcement-Learning-in-Cartpole" data-toc-modified-id="Reinforcement-Learning-in-Cartpole-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Reinforcement Learning in Cartpole</a></span></li><li><span><a href="#Markov-Decision-Process" data-toc-modified-id="Markov-Decision-Process-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Markov Decision Process</a></span></li><li><span><a href="#Deterministic-vs-Stochastic" data-toc-modified-id="Deterministic-vs-Stochastic-6.4"><span class="toc-item-num">6.4&nbsp;&nbsp;</span>Deterministic vs Stochastic</a></span></li><li><span><a href="#Q-Learning" data-toc-modified-id="Q-Learning-6.5"><span class="toc-item-num">6.5&nbsp;&nbsp;</span>Q Learning</a></span></li></ul></li><li><span><a href="#Q-Learning-Functions-and-Methods" data-toc-modified-id="Q-Learning-Functions-and-Methods-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Q Learning Functions and Methods</a></span><ul class="toc-item"><li><span><a href="#Calculate-Epsilon" data-toc-modified-id="Calculate-Epsilon-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Calculate Epsilon</a></span></li><li><span><a href="#Select-Action" data-toc-modified-id="Select-Action-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>Select Action</a></span></li><li><span><a href="#Optimize" data-toc-modified-id="Optimize-7.3"><span class="toc-item-num">7.3&nbsp;&nbsp;</span>Optimize</a></span></li></ul></li><li><span><a href="#HyperTunning-Function" data-toc-modified-id="HyperTunning-Function-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>HyperTunning Function</a></span></li><li><span><a href="#One-Layer-Neural-Nets" data-toc-modified-id="One-Layer-Neural-Nets-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>One Layer Neural Nets</a></span><ul class="toc-item"><li><span><a href="#One-Layer-Neural-Net-Definition" data-toc-modified-id="One-Layer-Neural-Net-Definition-9.1"><span class="toc-item-num">9.1&nbsp;&nbsp;</span>One Layer Neural Net Definition</a></span></li><li><span><a href="#BNN-Class" data-toc-modified-id="BNN-Class-9.2"><span class="toc-item-num">9.2&nbsp;&nbsp;</span>BNN Class</a></span></li><li><span><a href="#BNN-Parameters" data-toc-modified-id="BNN-Parameters-9.3"><span class="toc-item-num">9.3&nbsp;&nbsp;</span>BNN Parameters</a></span></li><li><span><a href="#BNN-Simulation" data-toc-modified-id="BNN-Simulation-9.4"><span class="toc-item-num">9.4&nbsp;&nbsp;</span>BNN Simulation</a></span></li><li><span><a href="#BNN-Notes" data-toc-modified-id="BNN-Notes-9.5"><span class="toc-item-num">9.5&nbsp;&nbsp;</span>BNN Notes</a></span></li><li><span><a href="#Hypertunning-BNN" data-toc-modified-id="Hypertunning-BNN-9.6"><span class="toc-item-num">9.6&nbsp;&nbsp;</span>Hypertunning BNN</a></span></li></ul></li><li><span><a href="#Two-Layer-Neural-Nets" data-toc-modified-id="Two-Layer-Neural-Nets-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>Two Layer Neural Nets</a></span><ul class="toc-item"><li><span><a href="#BNN---TLN-Differences" data-toc-modified-id="BNN---TLN-Differences-10.1"><span class="toc-item-num">10.1&nbsp;&nbsp;</span>BNN - TLN Differences</a></span></li><li><span><a href="#Two-Layer-Neural-Net-Definition" data-toc-modified-id="Two-Layer-Neural-Net-Definition-10.2"><span class="toc-item-num">10.2&nbsp;&nbsp;</span>Two Layer Neural Net Definition</a></span></li><li><span><a href="#TLN-Class" data-toc-modified-id="TLN-Class-10.3"><span class="toc-item-num">10.3&nbsp;&nbsp;</span>TLN Class</a></span></li><li><span><a href="#TLN-Parameters" data-toc-modified-id="TLN-Parameters-10.4"><span class="toc-item-num">10.4&nbsp;&nbsp;</span>TLN Parameters</a></span></li><li><span><a href="#TLN-Simulation" data-toc-modified-id="TLN-Simulation-10.5"><span class="toc-item-num">10.5&nbsp;&nbsp;</span>TLN Simulation</a></span></li><li><span><a href="#TLN-Notes" data-toc-modified-id="TLN-Notes-10.6"><span class="toc-item-num">10.6&nbsp;&nbsp;</span>TLN Notes</a></span></li><li><span><a href="#HyperTunning-TLN" data-toc-modified-id="HyperTunning-TLN-10.7"><span class="toc-item-num">10.7&nbsp;&nbsp;</span>HyperTunning TLN</a></span></li></ul></li><li><span><a href="#Experience-Replay-Network" data-toc-modified-id="Experience-Replay-Network-11"><span class="toc-item-num">11&nbsp;&nbsp;</span>Experience Replay Network</a></span><ul class="toc-item"><li><span><a href="#TLN---ERN-Differences" data-toc-modified-id="TLN---ERN-Differences-11.1"><span class="toc-item-num">11.1&nbsp;&nbsp;</span>TLN - ERN Differences</a></span></li><li><span><a href="#Experience-Replay-Class" data-toc-modified-id="Experience-Replay-Class-11.2"><span class="toc-item-num">11.2&nbsp;&nbsp;</span>Experience Replay Class</a></span></li><li><span><a href="#New-Optimize-Function" data-toc-modified-id="New-Optimize-Function-11.3"><span class="toc-item-num">11.3&nbsp;&nbsp;</span>New Optimize Function</a></span></li><li><span><a href="#ERN-Class" data-toc-modified-id="ERN-Class-11.4"><span class="toc-item-num">11.4&nbsp;&nbsp;</span>ERN Class</a></span></li><li><span><a href="#ERN-Parameters" data-toc-modified-id="ERN-Parameters-11.5"><span class="toc-item-num">11.5&nbsp;&nbsp;</span>ERN Parameters</a></span></li><li><span><a href="#Simulating-ERN" data-toc-modified-id="Simulating-ERN-11.6"><span class="toc-item-num">11.6&nbsp;&nbsp;</span>Simulating ERN</a></span></li><li><span><a href="#HyperTunning-ERN" data-toc-modified-id="HyperTunning-ERN-11.7"><span class="toc-item-num">11.7&nbsp;&nbsp;</span>HyperTunning ERN</a></span></li><li><span><a href="#ERN-Demonstration" data-toc-modified-id="ERN-Demonstration-11.8"><span class="toc-item-num">11.8&nbsp;&nbsp;</span>ERN Demonstration</a></span></li></ul></li><li><span><a href="#Deep-Q-Network" data-toc-modified-id="Deep-Q-Network-12"><span class="toc-item-num">12&nbsp;&nbsp;</span>Deep Q-Network</a></span><ul class="toc-item"><li><span><a href="#ERN---DQN-Differences" data-toc-modified-id="ERN---DQN-Differences-12.1"><span class="toc-item-num">12.1&nbsp;&nbsp;</span>ERN - DQN Differences</a></span></li><li><span><a href="#New-DQN-Optimize-Class" data-toc-modified-id="New-DQN-Optimize-Class-12.2"><span class="toc-item-num">12.2&nbsp;&nbsp;</span>New DQN Optimize Class</a></span></li><li><span><a href="#DQN-Class" data-toc-modified-id="DQN-Class-12.3"><span class="toc-item-num">12.3&nbsp;&nbsp;</span>DQN Class</a></span></li><li><span><a href="#DQN-Parameters" data-toc-modified-id="DQN-Parameters-12.4"><span class="toc-item-num">12.4&nbsp;&nbsp;</span>DQN Parameters</a></span></li><li><span><a href="#Simulating-DQN" data-toc-modified-id="Simulating-DQN-12.5"><span class="toc-item-num">12.5&nbsp;&nbsp;</span>Simulating DQN</a></span></li><li><span><a href="#Hypertunning-DQN" data-toc-modified-id="Hypertunning-DQN-12.6"><span class="toc-item-num">12.6&nbsp;&nbsp;</span>Hypertunning DQN</a></span></li></ul></li><li><span><a href="#Double-DQN-Network" data-toc-modified-id="Double-DQN-Network-13"><span class="toc-item-num">13&nbsp;&nbsp;</span>Double DQN Network</a></span><ul class="toc-item"><li><span><a href="#Double-DQN-Optimize" data-toc-modified-id="Double-DQN-Optimize-13.1"><span class="toc-item-num">13.1&nbsp;&nbsp;</span>Double DQN Optimize</a></span></li><li><span><a href="#Double-DQN-Class" data-toc-modified-id="Double-DQN-Class-13.2"><span class="toc-item-num">13.2&nbsp;&nbsp;</span>Double DQN Class</a></span></li><li><span><a href="#Double-DQN-Parameters" data-toc-modified-id="Double-DQN-Parameters-13.3"><span class="toc-item-num">13.3&nbsp;&nbsp;</span>Double DQN Parameters</a></span></li><li><span><a href="#DoubleDQN-Simulation" data-toc-modified-id="DoubleDQN-Simulation-13.4"><span class="toc-item-num">13.4&nbsp;&nbsp;</span>DoubleDQN Simulation</a></span></li><li><span><a href="#DoubleDQN-Hypertunning" data-toc-modified-id="DoubleDQN-Hypertunning-13.5"><span class="toc-item-num">13.5&nbsp;&nbsp;</span>DoubleDQN Hypertunning</a></span></li></ul></li><li><span><a href="#Exploration-of-Different-Environments" data-toc-modified-id="Exploration-of-Different-Environments-14"><span class="toc-item-num">14&nbsp;&nbsp;</span>Exploration of Different Environments</a></span></li><li><span><a href="#Sources" data-toc-modified-id="Sources-15"><span class="toc-item-num">15&nbsp;&nbsp;</span>Sources</a></span></li></ul></div>

# %% [markdown]
# ## Introduction

# %% [markdown]
# <strong>The purpose of this notebook is to compare the performance of different learning agent architectures, building each of the networks inside of a modular class structure using similar neural networks. Episodic performance will be accumulated. This presentation will focus on the code and the algorithmic architecture of various models, rather than the mathematics used in the analysis.</strong>

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Library Imports

# %%
import pandas as pd
import numpy as np
import random

import torch
import torch.nn as nn
import torch.optim as optim
from torch.autograd import Variable

from time import time
from time import sleep
import gym
import math

from matplotlib import animation
import matplotlib.pyplot as plt
from IPython.display import display

import seaborn as sns

import itertools as it

# %matplotlib inline

# %% [markdown]
# ### Cuda Support

# %%
# if gpu is to be used
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
Tensor = torch.Tensor
LongTensor = torch.LongTensor

# %% [markdown]
# ## CartPole v1 Environment

# %% [markdown]
# <img src="./800px-Cart-pendulum.svg.png">

# %% [markdown]
# ### CartPole Introduction

# %% [markdown]
# <strong>A pole is attached by an un-actuated joint to a cart, which moves along a frictionless track. The system is controlled by applying a force of +1 or -1 to the cart. The pendulum starts upright, and the goal is to prevent it from falling over. A reward of +1 is provided for every timestep that the pole remains upright. The episode ends when the pole is more than 15 degrees from vertical, or the cart moves more than 2.4 units from the center.</strong><br>
# <div style="text-align: right">Source: OpenAI </div>

# %%
env = gym.make('CartPole-v1')
inputs = env.observation_space.shape[0]
outputs = env.action_space.n

print("Input Space:\t{}\nOutput Space:\t{}".format(inputs, outputs))
score_to_solve = 450
# Out:
# Input Space:	4
# Output Space:	2

# %% [markdown]
# ### Action/Input Space
#
# |Num|Action|
# |-|-|
# |0|Push cart to the left|
# |1|Push cart to the right|

# %% [markdown]
# ### Observation/Output Space
#
#
# |Num|Observation|Min|Max|
# |-|---------------------|-|-|
# |0|Cart Position|-4.8|4.8|
# |1|Cart Velocity|-Inf|Inf|
# |2|Pole Angle|-15 deg|15 deg|
# |3|Pole Velocity At Tip|-Inf|Inf|

# %% [markdown]
# ### Human Demonstration

# %%
import sys

env = gym.make('CartPole-v1')

if not hasattr(env.action_space, 'n'):
    raise Exception('Keyboard agent only supports discrete action spaces')
ACTIONS = env.action_space.n
SKIP_CONTROL = 0    # Use previous control decision SKIP_CONTROL times, that's how you
                    # can test what skip is still usable.

human_agent_action = 0
human_wants_restart = False
human_sets_pause = False

def key_press(key, mod):
    global human_agent_action, human_wants_restart, human_sets_pause
    if key==0xff0d: human_wants_restart = True
    
    111#Key 32 is the space key
    if key==32: human_sets_pause = not human_sets_pause
    a = int( key - ord('0') )
    if a <= 0 or a >= ACTIONS: return
    human_agent_action = a

def key_release(key, mod):
    global human_agent_action
    a = int( key - ord('0') )
    if a <= 0 or a >= ACTIONS: return
    if human_agent_action == a:
        human_agent_action = 0

env.render()
env.unwrapped.viewer.window.on_key_press = key_press
env.unwrapped.viewer.window.on_key_release = key_release

def rollout(env):
    global human_agent_action, human_wants_restart, human_sets_pause
    human_wants_restart = False
    obser = env.reset()
    skip = 0
    total_reward = 0
    total_timesteps = 0
    while 1:
        if not skip:
            print("taking action {}".format(human_agent_action))
            print(obser)
            a = human_agent_action
            total_timesteps += 1
            skip = SKIP_CONTROL
        else:
            skip -= 1

        obser, r, done, info = env.step(a)
        #if r != 0:
            #print("reward %0.3f" % r)
        total_reward += r
        window_still_open = env.render()
        if window_still_open==False: return False
        if done: break
        if human_wants_restart: break
        while human_sets_pause:
            env.render()
            sleep(0.1)
        sleep(0.1)
    print("timesteps %i reward %0.2f" % (total_timesteps, total_reward))

rollout(env)
env.close()
env.env.close()
# Out:
# taking action 0
# [-0.00283685 -0.03770985 -0.02387482  0.01672338]
# taking action 0
# [-0.00359105 -0.23248142 -0.02354035  0.30177894]
# taking action 0
# [-0.00824068 -0.42726009 -0.01750477  0.58694577]
# timesteps 3 reward 3.00

# %% [markdown]
# # Functions and Classes

# %% [markdown]
# ### Report Function

# %%
def report(report_interval,
           episode,
           start_time,
           steps_total,
           epsilon,
           frames_total,
           solved):
    
    if episode % report_interval == 0 and episode != 0:
        print("""\t\t\t *** Episode {} at Total Seconds {:2f}***
                 Average Reward for last {} steps: {:2f}
                 Average Reward for all steps: {:2f}
                 Epsilon: {}, Frames Total :{}
                 Solved {} Times
              """.format(episode,
                   (time() - start_time),
                   str(report_interval),
                   sum(steps_total[-report_interval:])/report_interval,
                   sum(steps_total)/len(steps_total),
                   epsilon,
                   frames_total,
                   solved))

# %% [markdown]
# ## Agent Factory

# %%
class Agent(object):
  
    def factory(type, object):
        if type == "Random":
            return Random_Agent(type, object)
        elif type == "BNN":
            return BNN(type, object)
        elif type == "TLN":
            return TLN(type, object)
        elif type == "ERN":
            return ERN(type, object)
        elif type == "DQN":
            return DQN(type, object)
        elif type == "DoubleDQN":
            return DoubleDQN(type, object)
        elif type == "DuelingDQN":
            return DuelingDQN(type, object)
        
    factory = staticmethod(factory)

# %% [markdown]
# ### Simulation Function

# %%
mem = False
def simulation(num_episodes,
               agent,
               label,
               record,
               report_interval,
               extra_name  = "",
               show = False,
               cart = True):
    
    #Simulation Initialization
    actor = Agent.factory(agent, label)
    start_time = time()
    solved, frames_total = 0, 0
    steps_total = []
    
    #if extra_name != "": extra_name = "_" + extra_name
    
    #The recorded dictionary for the simulation
    shadow_run = {}
    
    #Loop through different episodes
    for episode in range(num_episodes):

        # Episode Initializations
        state = env.reset()
        epi_name = actor.name + extra_name + "_"+ str(episode).zfill(4)
        shadow_run[epi_name] = {} 
        
        #A fancy way to make lists
        blanks = [-1 for i in range(500)]
        
        #Input for episode
        actions, steps = [blanks for i in range(2)] 
        
        #Outputs for episodes
        cart_position, cart_velocity = [blanks for i in range(2)]
        pole_angle, pole_velocity  = [blanks for i in range(2)]
        
        step = 0
                
        while True:
            #This allows us to watch the model in action
            if show == True: rendered = env.render(mode = 'rgb_array')

            
            #Calculate E-greedy Rate for Exploration vs. Exploitation tradeoff
            epsilon = actor.calculate_epsilon(frames_total)

            #Actor acts
            action = actor.select_action(state, epsilon)

            #Record States
            new_state, reward, done, info = env.step(action)

            #Optimize
            #Memory Push check
            
            if mem != False:
                memory.push(state, action, new_state, reward, done)
                actor.optimize()
            else:
                actor.optimize(state, action, new_state, reward, done)

            #Store Inputs for step
            actions[step] = action
            
            ###
            #**DO THIS**
            #On update, make a class called Information to clean syntax
            ###
            
            if cart == True:
                #Unpack Output for step
                cart_position[step] = new_state[0]
                cart_velocity[step] = new_state[1]
                pole_angle[step]    = new_state[2]
                pole_velocity[step] = new_state[3]         

            if done:
                steps_total.append(step)
                
                ###
                #**DO THIS**
                #On update, clean up the following syntax
                #Also, consider adding number values to the information
                ###
                
                #Below is an overpacked syntax to add a column for each part
                #.zfill pads zeros in the front of the string
                
                for i in range(500):
                    D = shadow_run[epi_name]
                    if cart == True:
                        D["steps_total"] = step
                        D["action_{}".format(str(i).zfill(3))]        = actions[i]
                        D["cart_position_{}".format(str(i).zfill(3))] = cart_position[i]
                        D["cart_velocity_{}".format(str(i).zfill(3))] = cart_velocity[i]
                        D["pole_angle_{}".format(str(i).zfill(3))]    = pole_angle[i]
                        D["pole_velocity_{}".format(str(i).zfill(3))] = pole_velocity[i]                                     
                
                shadow_run[epi_name] = D
                #Not needed for this environment
                #shadow_run[episode]["information"] = information

                if step >= score_to_solve: solved += 1

                report(report_interval, episode, start_time, steps_total, epsilon, frames_total, solved)

                break

            step += 1
            frames_total += 1
            state = new_state
        
    #Clean up after Episodes
    record[actor.name + extra_name] = shadow_run    
    env.close()
    env.env.close()

    return record

# %% [markdown]
# ### Ploting Function

# %%
def plot_agent(record, agent_name):
    steps_total = []
    performance_list = [0,0,0,0,0]
    best = 0
    best_epi = ""
    
    #Counts agent episodes in list
    num_episodes = len(record[agent_name].keys())
    
    #Collect all of the steps into a list
    for epi in record[agent_name].keys():
        n_steps = record[agent_name][epi]["steps_total"]
        steps_total.append(n_steps)
        
        if best < n_steps:
            best = n_steps
            best_epi = epi
        
        if record[agent_name][epi]["steps_total"] < 50:
            performance_list[0] += 1 / num_episodes
        if record[agent_name][epi]["steps_total"] < 150:
            performance_list[1] += 1 / num_episodes
        if record[agent_name][epi]["steps_total"] < 250:
            performance_list[2] += 1 / num_episodes
        if record[agent_name][epi]["steps_total"] < 350:
            performance_list[3] += 1 / num_episodes
        if record[agent_name][epi]["steps_total"] < 400:
            performance_list[4] += 1 / num_episodes
     
    performance_list = [round(x,3) for x in performance_list]
    plot_x = np.linspace(0,num_episodes,num = num_episodes)
    
    def moving_average(x, w):
        return np.convolve(x, np.ones(w), 'valid') / w
    
    moving_100 = np.append(99*[0], moving_average(np.array(steps_total), 100))
    
    
    fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(12, 12));
    
    fig.suptitle("{} Performance Information".format(agent_name), fontsize=16);
    plt.subplots_adjust(hspace=0.35)
    
    ax[0,0].set_title('Performance Plot');
    ax[0,0].scatter(plot_x,
                  steps_total,
                  c='b',
                  #s = 5,
                  marker = "x",
                  label = "Performance Values");
#     ax[0].plot(plot_x,
#                steps_total,
#                label = "Performance Values",
#                linewidth = .5)
    ax[0,0].plot(plot_x, 
               moving_100,
               c = "orange",
               label = "100 Session Moving Average",
               linewidth=3.0)
    ax[0,0].legend(loc="lower right", bbox_to_anchor=(.55, -.225))
    
    
    ax[0,1].set_title("Kernel Density Estimation of Performance");
    sns.kdeplot(np.array(steps_total), shade = True, bw=0.5, ax = ax[0,1])
    
    ax[1,0].set_title("Episode Performance");
    
    objects = ('Below 50', 'Below 150', 'Below 250', 'Below 350', 'Percent Unsolved')
    y_pos = np.arange(len(objects))

    ax[1,0].barh(y_pos, performance_list, align='center', alpha=0.5)
    ax[1,0].set_yticks(y_pos)
    ax[1,0].set_yticklabels(objects)
    ax[1,0].set_xticklabels('{}%'.format(x) for x in [0,20,40,60,80,100])
    ax[1,0].set_xticks(np.linspace(0,1,6))
    ax[1,0].grid(which='major', axis='x', ls = "--")

    ax[1,1].set_title("Steps Boxplot");
    ax[1,1].boxplot(steps_total, vert=False)
    ax[1,1].set_yticks([])
    
    #print(best, best_epi)

# %% [markdown]
# ## Random Agent

# %%
class Random_Agent(Agent):
    def __init__(self, Agent, label):
        self.name = label
        
    #Randomly chooses an action
    def select_action(self,state,epsilon):
        action = env.action_space.sample()
        return action
    
    #No epsilon decision is needed
    def calculate_epsilon(self,steps_done):
        return 0    
    
    #No optimization
    def optimize(self, state, action, new_state, reward, done):
        return 0

# %% [markdown]
# ### Random Agent Demonstration

# %%
#record = simulation(100, "Random", "Random_Agent", {}, 100, show = True)
#plot_agent(record, "Random_Agent")

# %% [markdown]
# ### Random Agent Simulation

# %%
record = simulation(1000, "Random", "Random_Agent", {}, 333)
plot_agent(record, "Random_Agent")
# Out:
# 			 *** Episode 333 at Total Seconds 0.434829***
#                  Average Reward for last 333 steps: 21.714715
#                  Average Reward for all steps: 21.724551
#                  Epsilon: 0, Frames Total :7256
#                  Solved 0 Times
#
# 			 *** Episode 666 at Total Seconds 0.847282***
#                  Average Reward for last 333 steps: 20.624625
#                  Average Reward for all steps: 21.175412
#                  Epsilon: 0, Frames Total :14124
#                  Solved 0 Times
#
# 			 *** Episode 999 at Total Seconds 1.268102***
#                  Average Reward for last 333 steps: 22.336336
#                  Average Reward for all steps: 21.562000
#                  Epsilon: 0, Frames Total :21562
#                  Solved 0 Times

# %% [markdown]
# ## Reinforcement Learning Introduction

# %% [markdown]
# ### Human Learning: Work Piece Indicator

# %%
# %%HTML
# <video width="640" height="480" controls>
#   <source src="./WPI.mp4" type="video/mp4">
# </video>
# Out:
# <video width="640" height="480" controls>
#   <source src="./WPI.mp4" type="video/mp4">
# </video>

# %% [markdown]
# ### Reinforcement Learning in Cartpole
# <br><br>
# <img src="./WPI.png">

# %% [markdown]
# ### Markov Decision Process
# <br><br>
# <img src="./MDP.png">
# <div style="text-align: right">Source: Wikipedia </div>

# %% [markdown]
# ### Deterministic vs Stochastic
# <br><br>
# Some environments have fixed, finite set of states. These environments are called <strong>Deterministic</strong>. Since the combination of states is along a continuous interval, the following analysis will assume CartPole as a <strong>Stochastic</strong> environment, meaning that it is virtually impossible to know everything about the environment.

# %% [markdown]
# ### Q Learning
# <br>
# While the mathematics of Q learning equations are outside of the scope of this presentation, for completeness, they are presented here. <br><br>
# $${\displaystyle Q^{new}(s_{t},a_{t})\leftarrow (1-\alpha )\cdot \underbrace {Q(s_{t},a_{t})} _{\text{old value}}+\underbrace {\alpha } _{\text{learning rate}}\cdot \overbrace {{\bigg (}\underbrace {r_{t}} _{\text{reward}}+\underbrace {\gamma } _{\text{discount factor}}\cdot \underbrace {\max _{a}Q(s_{t+1},a)} _{\text{estimate of optimal future value}}{\bigg )}} ^{\text{learned value}}}$$
# <br>
# For more information, please check out http://cs231n.stanford.edu

# %% [markdown]
# ## Q Learning Functions and Methods

# %% [markdown]
# ### Calculate Epsilon

# %% [markdown]
# <strong>The following is part of fundamental algorithm used throughout this notebook. Ultimately, our agents need to manage the Exploitation vs Exploration problem. The following solution uses an <i>E-greedy</i> algorithm that makes short term sacrifices to gather information, and then, once the training phase has ended, exploits its previous experience, deviating from the optimal strategy only rarely. <br><br><i>calculate_epsilon</i> makes the exploration threshold and <i>select_action<i> decides whether to apply the found strategy or choose randomly.</strong>

# %%
#We have to add self since these will become methods
def calculate_epsilon(self, steps_done):
    #http://home.deib.polimi.it/restelli/MyWebSite/pdf/rl5.pdf
    #Exploitation vs Exploration algorithm
    epsilon = egreedy_final + (egreedy - egreedy_final) * \
              math.exp(-1. * steps_done / egreedy_decay )
    return epsilon

# %% [markdown]
# ### Select Action

# %%
def select_action(self,state,epsilon):

    random_for_egreedy = torch.rand(1)[0]

    #If random > epsilon, then will not attempt random action
    if random_for_egreedy > epsilon:      
        with torch.no_grad():
            state = Tensor(state).to(device)
            action_from_nn = self.nn(state)
            action = torch.max(action_from_nn,0)[1]
            action = action.item()

    #Otherwise random action is attempted and recorded
    else:
        action = env.action_space.sample()

    return action

# %% [markdown]
# ### Optimize

# %% [markdown]
# <strong>The <i>optimize</i> function is the most changed throughout this notebook. Updates often include running experience through a Tensor, avoiding the batching problem (discussed later) and using a learning network and action network.</strong><br><br>
#
# $$Q(s,a)=r+\gamma*\max_{a^{\prime}}Q\left(s^{\prime}, a^{\prime}\right)$$
# <br><br>
# <strong>The basic point here is that r is our reward, s is our state, and gamma is our discount rate from past actions</strong>

# %%
def optimize(self, state, action, new_state, reward, done):
    #Train network
    state = Tensor(state).to(device)
    
    #The reason for the detach values here is that, while we need to calculate
    #The state values, we don't want to calculate the gradient for the new
    #State when we back propigate
    new_state = Tensor(new_state).to(device)

    reward = Tensor([reward]).to(device)

    if done:
        #Prevents Divergence
        target_value = reward
    else:
        #Using detach so we don't update the network
        new_state_values = self.nn(new_state).detach()
        
        #The best max state
        max_new_state_values = torch.max(new_state_values)
        
        #The Bellman Equation
        target_value = reward + gamma * max_new_state_values

    #The is where the network calculates the predictions
    predicted_value = self.nn(state)[action]

    #The learing between the loss and actual
    loss = self.loss_func(predicted_value, target_value)

    #Backwards propigate through the netowork
    self.optimizer.zero_grad()
    
    #We are only calculating this inside the function, we don't need self
    loss.backward()
    
    #Agent Learns
    self.optimizer.step()

# %% [markdown]
# ## HyperTunning Function

# %%
hyper = {
    "learning_rate" :          [0.1, .05, .01],
    "gamma":                   [.85, .9, 0.95],
    "egreedy_final":           [.02, 0.02], 
    "hidden_layer":            [0],
    "batch_size":              [0],
    "update_target_frequency": [0],}

knobs = ["learning_rate",
         "gamma", 
         "egreedy_final", 
         "hidden_layer",
         "batch_size",
         "update_target_frequency"]

def hyper_and_beyond(hyper, record, agent, knobs = knobs):
    
    combinations = it.product(*(hyper[knob] for knob in knobs))
    best_combo = 0
    for possible in combinations:
        learning_rate           = possible[0]
        gamma                   = possible[1]
        egreedy_final           = possible[2]
        hidden_layer            = possible[3]
        batch_size              = possible[4]
        update_target_frequency = possible[5]
        
        test =            [agent,
                           learning_rate,
                           gamma,
                           egreedy_final,
                           hidden_layer,
                           batch_size,
                           update_target_frequency]
                
        print("""
        ***Testing Agent {}***
        learning_rate = {},
        gamma = {},
        egreedy_final = {},
        hidden_layer = {},
        batch_size = {},
        update_target_frequency = {}
        """.format(*test))
        
        testing_name = "{}_{}_{}_{}_{}_{}_{}".format(*test)
        
        record = simulation(1000,
                            agent,
                            testing_name,
                            record, 
                            333)
        
        steps_total = []
        for i in record[testing_name].keys():
            steps_total.append(record[testing_name][i]["steps_total"])
    
        last_200_ave = sum(steps_total[-200:])/200
        print("""
              Last 200 Episode Average for Agent {}: {}""".format(testing_name,
                                                                  last_200_ave))
        
        if last_200_ave > best_combo:
            best_combo = last_200_ave
            best_test = testing_name
    
    print("/n/n{} is the best of the test".format(best_test))
    plot_agent(record,best_test)
    return record

# %% [markdown]
# ## One Layer Neural Nets

# %% [markdown]
# <strong>Neural nets are complicated, and the topic is outside the scope of this presentation. However, we will basic nets to test the different agent algorithms, assuming the reader has a foundational understanding of the topic.</strong>

# %% [markdown]
# ### One Layer Neural Net Definition

# %%
#Basic One Layer Network
class NeuralNetwork_1(nn.Module):
    
    def __init__(self):
        #super () Allows us to avoid calling base class
        super().__init__()
        self.linear1 = nn.Linear(number_of_inputs,number_of_outputs)
        
    def forward(self, x):
        output = self.linear1(x)
        return output

# %% [markdown]
# ### BNN Class

# %%
class BNN(object):
    
    def __init__(self, Agent, label):
        #Calling Network to Cuda, if available
        self.nn = NeuralNetwork_1().to(device)
        self.name = label

        self.loss_func = nn.MSELoss()
        #self.loss_func = nn.SmoothL1Loss()
        
        self.optimizer = optim.Adam(params=self.nn.parameters(), lr=learning_rate)
        #self.optimizer = optim.RMSprop(params=mynn.parameters(), lr=learning_rate)

setattr(BNN, "calculate_epsilon", calculate_epsilon)
setattr(BNN, "select_action", select_action)
setattr(BNN, "optimize", optimize)

# %% [markdown]
# ### BNN Parameters

# %%
#Step Size
learning_rate = 0.01

#Discount Factor
gamma = 0.995

#Exploration vs Explotation trade off
egreedy = 0.9
egreedy_final = 0.02
egreedy_decay = 1000

#These lines are useful if I decide to change environments
number_of_inputs = env.observation_space.shape[0]
number_of_outputs = env.action_space.n

# %% [markdown]
# ### BNN Simulation

# %%
record = simulation(1000, "BNN", "BNN_1",record, 333)
plot_agent(record, "BNN_1")
# Out:
# 			 *** Episode 333 at Total Seconds 3.066770***
#                  Average Reward for last 333 steps: 10.021021
#                  Average Reward for all steps: 10.107784
#                  Epsilon: 0.05008184722110651, Frames Total :3376
#                  Solved 0 Times
#
# 			 *** Episode 666 at Total Seconds 6.251870***
#                  Average Reward for last 333 steps: 10.327327
#                  Average Reward for all steps: 10.217391
#                  Epsilon: 0.02096553001263407, Frames Total :6815
#                  Solved 0 Times
#
# 			 *** Episode 999 at Total Seconds 12.688879***
#                  Average Reward for last 333 steps: 23.201201
#                  Average Reward for all steps: 14.541000
#                  Epsilon: 0.020000425997068777, Frames Total :14541
#                  Solved 0 Times
#
# [0.981, 0.999, 1.0, 1.0, 1.0]

# %% [markdown]
# ### BNN Notes
# <br><br>
# <strong>It is obvious that the one layer net is just not muscular enough to drive the learning for the choosing of actions. However it is clear that some learning is occurring</strong>

# %% [markdown]
# ### Hypertunning BNN

# %%
mem = False
hyper = {
    "learning_rate" :          [0.1, .05, .01],
    "gamma":                   [.85, .9, 0.95, .995],
    "egreedy_final":           [.02, 0.02], 
    "hidden_layer":            [0],
    "batch_size":              [0],
    "update_target_frequency": [0],}

record = hyper_and_beyond(hyper, record, "BNN", knobs = knobs)
# Out:
#         ***Testing Agent BNN***
#         learning_rate = 0.1,
#         gamma = 0.85,
#         egreedy_final = 0.02,
#         hidden_layer = 0,
#         batch_size = 0,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 6.944111***
#                  Average Reward for last 333 steps: 18.936937
#                  Average Reward for all steps: 18.934132
#                  Epsilon: 0.021577627139064685, Frames Total :6324
#                  Solved 0 Times
#
# 			 *** Episode 666 at Total Seconds 15.700300***
#                  Average Reward for last 333 steps: 26.987988
#                  Average Reward for all steps: 22.955022
#                  Epsilon: 0.020000197242209906, Frames Total :15311
#                  Solved 0 Times
#
# 			 *** Episode 999 at Total Seconds 24.621831***
#                  Average Reward for last 333 steps: 30.102102
#                  Average Reward for all steps: 25.335000
#                  Epsilon: 0.020000000008742427, Frames Total :25335
#                  Solved 0 Times
#
#
#               Last 200 Episode Average for Agent BNN_0.1_0.85_0.02_0_0_0: 27.715
#
#         ***Testing Agent BNN***
#         learning_rate = 0.1,
#         gamma = 0.85,
#         egreedy_final = 0.02,
#         hidden_layer = 0,
#         batch_size = 0,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 6.014636***
#                  Average Reward for last 333 steps: 20.357357
#                  Average Reward for all steps: 20.395210
#                  Epsilon: 0.020968430951905176, Frames Total :6812
#                  Solved 0 Times
#
# 			 *** Episode 666 at Total Seconds 13.186775***
#                  Average Reward for last 333 steps: 25.891892
#                  Average Reward for all steps: 23.139430
#                  Epsilon: 0.020000174414118943, Frames Total :15434
#                  Solved 0 Times
#
# 			 *** Episode 999 at Total Seconds 21.030884***
#                  Average Reward for last 333 steps: 27.357357
#                  Average Reward for all steps: 24.544000
#                  Epsilon: 0.020000000019282305, Frames Total :24544
#                  Solved 0 Times
#
#
#               Last 200 Episode Average for Agent BNN_0.1_0.85_0.02_0_0_0: 32.055
#
#         ***Testing Agent BNN***
#         learning_rate = 0.1,
#         gamma = 0.9,
#         egreedy_final = 0.02,
#         hidden_layer = 0,
#         batch_size = 0,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 5.562338***
#                  Average Reward for last 333 steps: 18.363363
#                  Average Reward for all steps: 18.410180
#                  Epsilon: 0.021879342360635785, Frames Total :6149
#                  Solved 0 Times
#
# 			 *** Episode 666 at Total Seconds 13.677571***
#                  Average Reward for last 333 steps: 27.381381
#                  Average Reward for all steps: 22.889055
#                  Epsilon: 0.02000020611462899, Frames Total :15267
#                  Solved 0 Times
#
# 			 *** Episode 999 at Total Seconds 21.847095***
#                  Average Reward for last 333 steps: 28.030030
#                  Average Reward for all steps: 24.601000
#                  Epsilon: 0.020000000018213948, Frames Total :24601
#                  Solved 0 Times
#
#
#               Last 200 Episode Average for Agent BNN_0.1_0.9_0.02_0_0_0: 27.51
#
#         ***Testing Agent BNN***
#         learning_rate = 0.1,
#         gamma = 0.9,
#         egreedy_final = 0.02,
#         hidden_layer = 0,
#         batch_size = 0,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 5.967036***
#                  Average Reward for last 333 steps: 19.507508
#                  Average Reward for all steps: 19.491018
#                  Epsilon: 0.021309862156292297, Frames Total :6510
#                  Solved 0 Times
#
# 			 *** Episode 666 at Total Seconds 13.255170***
#                  Average Reward for last 333 steps: 25.570571
#                  Average Reward for all steps: 22.526237
#                  Epsilon: 0.020000262547617463, Frames Total :15025
#                  Solved 0 Times
#
# 			 *** Episode 999 at Total Seconds 20.737467***
#                  Average Reward for last 333 steps: 25.861862
#                  Average Reward for all steps: 23.637000
#                  Epsilon: 0.020000000047759967, Frames Total :23637
#                  Solved 0 Times
#
#
#               Last 200 Episode Average for Agent BNN_0.1_0.9_0.02_0_0_0: 26.135
#
#         ***Testing Agent BNN***
#         learning_rate = 0.1,
#         gamma = 0.95,
#         egreedy_final = 0.02,
#         hidden_layer = 0,
#         batch_size = 0,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 5.513784***
#                  Average Reward for last 333 steps: 18.384384
#                  Average Reward for all steps: 18.353293
#                  Epsilon: 0.02191539124542931, Frames Total :6130
#                  Solved 0 Times
#
# 			 *** Episode 666 at Total Seconds 13.205329***
#                  Average Reward for last 333 steps: 25.942943
#                  Average Reward for all steps: 22.142429
#                  Epsilon: 0.02000033914660107, Frames Total :14769
#                  Solved 0 Times
#
# 			 *** Episode 999 at Total Seconds 21.232971***
#                  Average Reward for last 333 steps: 26.537538
#                  Average Reward for all steps: 23.606000
#                  Epsilon: 0.02000000004926371, Frames Total :23606
#                  Solved 0 Times
#
#
#               Last 200 Episode Average for Agent BNN_0.1_0.95_0.02_0_0_0: 28.195
#
#         ***Testing Agent BNN***
#         learning_rate = 0.1,
#         gamma = 0.95,
#         egreedy_final = 0.02,
#         hidden_layer = 0,
#         batch_size = 0,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 5.642228***
#                  Average Reward for last 333 steps: 19.276276
#                  Average Reward for all steps: 19.275449
#                  Epsilon: 0.021407650366246467, Frames Total :6438
#                  Solved 0 Times
#
# 			 *** Episode 666 at Total Seconds 13.279058***
#                  Average Reward for last 333 steps: 26.870871
#                  Average Reward for all steps: 23.067466
#                  Epsilon: 0.020000182990175468, Frames Total :15386
#                  Solved 0 Times
#
# 			 *** Episode 999 at Total Seconds 21.675164***
#                  Average Reward for last 333 steps: 28.522523
#                  Average Reward for all steps: 24.884000
#                  Epsilon: 0.02000000001372457, Frames Total :24884
#                  Solved 0 Times
#
#
#               Last 200 Episode Average for Agent BNN_0.1_0.95_0.02_0_0_0: 29.265
#
#         ***Testing Agent BNN***
#         learning_rate = 0.1,
#         gamma = 0.995,
#         egreedy_final = 0.02,
#         hidden_layer = 0,
#         batch_size = 0,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 6.886485***
#                  Average Reward for last 333 steps: 23.285285
#                  Average Reward for all steps: 23.278443
#                  Epsilon: 0.020369694573033045, Frames Total :7775
#                  Solved 0 Times
#
# 			 *** Episode 666 at Total Seconds 13.912469***
#                  Average Reward for last 333 steps: 23.411411
#                  Average Reward for all steps: 23.344828
#                  Epsilon: 0.020000152083918737, Frames Total :15571
#                  Solved 0 Times
#
# 			 *** Episode 999 at Total Seconds 21.503736***
#                  Average Reward for last 333 steps: 26.708709
#                  Average Reward for all steps: 24.465000
#                  Epsilon: 0.02000000002086739, Frames Total :24465
#                  Solved 0 Times
#
#
#               Last 200 Episode Average for Agent BNN_0.1_0.995_0.02_0_0_0: 30.075
#
#         ***Testing Agent BNN***
#         learning_rate = 0.1,
#         gamma = 0.995,
#         egreedy_final = 0.02,
#         hidden_layer = 0,
#         batch_size = 0,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 7.361157***
#                  Average Reward for last 333 steps: 26.096096
#                  Average Reward for all steps: 26.068862
#                  Epsilon: 0.020145572928297786, Frames Total :8707
#                  Solved 0 Times
# 			 *** Episode 666 at Total Seconds 15.579360***
#                  Average Reward for last 333 steps: 27.831832
#                  Average Reward for all steps: 26.949025
#                  Epsilon: 0.020000013741665094, Frames Total :17975
#                  Solved 0 Times
#
# 			 *** Episode 999 at Total Seconds 22.840107***
#                  Average Reward for last 333 steps: 24.342342
#                  Average Reward for all steps: 26.081000
#                  Epsilon: 0.02000000000414618, Frames Total :26081
#                  Solved 0 Times
#
#
#               Last 200 Episode Average for Agent BNN_0.1_0.995_0.02_0_0_0: 26.095
#
#         ***Testing Agent BNN***
#         learning_rate = 0.05,
#         gamma = 0.85,
#         egreedy_final = 0.02,
#         hidden_layer = 0,
#         batch_size = 0,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 5.539655***
#                  Average Reward for last 333 steps: 17.924925
#                  Average Reward for all steps: 17.910180
#                  Epsilon: 0.022220920850656023, Frames Total :5982
#                  Solved 0 Times
#
# 			 *** Episode 666 at Total Seconds 12.555316***
#                  Average Reward for last 333 steps: 23.711712
#                  Average Reward for all steps: 20.806597
#                  Epsilon: 0.020000826692223417, Frames Total :13878
#                  Solved 0 Times
#
# 			 *** Episode 999 at Total Seconds 19.814207***
#                  Average Reward for last 333 steps: 24.177177
#                  Average Reward for all steps: 21.929000
#                  Epsilon: 0.020000000263535413, Frames Total :21929
#                  Solved 0 Times
#
#
#               Last 200 Episode Average for Agent BNN_0.05_0.85_0.02_0_0_0: 24.885
#
#         ***Testing Agent BNN***
#         learning_rate = 0.05,
#         gamma = 0.85,
#         egreedy_final = 0.02,
#         hidden_layer = 0,
#         batch_size = 0,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 6.059365***
#                  Average Reward for last 333 steps: 19.486486
#                  Average Reward for all steps: 19.458084
#                  Epsilon: 0.02132435017804389, Frames Total :6499
#                  Solved 0 Times
#
# 			 *** Episode 666 at Total Seconds 13.946252***
#                  Average Reward for last 333 steps: 26.234234
#                  Average Reward for all steps: 22.841079
#                  Epsilon: 0.020000212816962532, Frames Total :15235
#                  Solved 0 Times
#
# 			 *** Episode 999 at Total Seconds 22.614587***
#                  Average Reward for last 333 steps: 28.390390
#                  Average Reward for all steps: 24.689000
#                  Epsilon: 0.020000000016679623, Frames Total :24689
#                  Solved 0 Times
#
#
#               Last 200 Episode Average for Agent BNN_0.05_0.85_0.02_0_0_0: 24.355
#
#         ***Testing Agent BNN***
#         learning_rate = 0.05,
#         gamma = 0.9,
#         egreedy_final = 0.02,
#         hidden_layer = 0,
#         batch_size = 0,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 6.345416***
#                  Average Reward for last 333 steps: 20.738739
#                  Average Reward for all steps: 20.724551
#                  Epsilon: 0.020867553504394367, Frames Total :6922
#                  Solved 0 Times
#
# 			 *** Episode 666 at Total Seconds 14.524247***
#                  Average Reward for last 333 steps: 27.582583
#                  Average Reward for all steps: 24.148426
#                  Epsilon: 0.020000088981854368, Frames Total :16107
#                  Solved 0 Times
#
# 			 *** Episode 999 at Total Seconds 23.873477***
#                  Average Reward for last 333 steps: 32.567568
#                  Average Reward for all steps: 26.952000
#                  Epsilon: 0.020000000001735314, Frames Total :26952
#                  Solved 0 Times
#
#
#               Last 200 Episode Average for Agent BNN_0.05_0.9_0.02_0_0_0: 33.07
#
#         ***Testing Agent BNN***
#         learning_rate = 0.05,
#         gamma = 0.9,
#         egreedy_final = 0.02,
#         hidden_layer = 0,
#         batch_size = 0,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 5.610981***
#                  Average Reward for last 333 steps: 17.882883
#                  Average Reward for all steps: 17.895210
#                  Epsilon: 0.022232053262747013, Frames Total :5977
#                  Solved 0 Times
#
# 			 *** Episode 666 at Total Seconds 13.882393***
#                  Average Reward for last 333 steps: 28.087087
#                  Average Reward for all steps: 22.983508
#                  Epsilon: 0.02000019352998572, Frames Total :15330
#                  Solved 0 Times
#
# 			 *** Episode 999 at Total Seconds 21.373835***
#                  Average Reward for last 333 steps: 24.945946
#                  Average Reward for all steps: 23.637000
#                  Epsilon: 0.020000000047759967, Frames Total :23637
#                  Solved 0 Times
#
#
#               Last 200 Episode Average for Agent BNN_0.05_0.9_0.02_0_0_0: 26.64
#
#         ***Testing Agent BNN***
#         learning_rate = 0.05,
#         gamma = 0.95,
#         egreedy_final = 0.02,
#         hidden_layer = 0,
#         batch_size = 0,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 5.787685***
#                  Average Reward for last 333 steps: 19.345345
#                  Average Reward for all steps: 19.401198
#                  Epsilon: 0.021349753397805527, Frames Total :6480
#                  Solved 0 Times
#
# 			 *** Episode 666 at Total Seconds 12.221973***
#                  Average Reward for last 333 steps: 21.171171
#                  Average Reward for all steps: 20.284858
#                  Epsilon: 0.020001170788187413, Frames Total :13530
#                  Solved 0 Times
#
# 			 *** Episode 999 at Total Seconds 19.662815***
#                  Average Reward for last 333 steps: 25.159159
#                  Average Reward for all steps: 21.908000
#                  Epsilon: 0.02000000026912817, Frames Total :21908
#                  Solved 0 Times
#
#
#               Last 200 Episode Average for Agent BNN_0.05_0.95_0.02_0_0_0: 26.61
#
#         ***Testing Agent BNN***
#         learning_rate = 0.05,
#         gamma = 0.95,
#         egreedy_final = 0.02,
#         hidden_layer = 0,
#         batch_size = 0,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 5.408781***
#                  Average Reward for last 333 steps: 17.051051
#                  Average Reward for all steps: 17.047904
#                  Epsilon: 0.02296216940644239, Frames Total :5694
#                  Solved 0 Times
#
# 			 *** Episode 666 at Total Seconds 12.416684***
#                  Average Reward for last 333 steps: 22.699700
#                  Average Reward for all steps: 19.869565
#                  Epsilon: 0.020001544464404438, Frames Total :13253
#                  Solved 0 Times
#
# 			 *** Episode 999 at Total Seconds 20.520654***
#                  Average Reward for last 333 steps: 27.615616
#                  Average Reward for all steps: 22.449000
#                  Epsilon: 0.020000000156677217, Frames Total :22449
#                  Solved 0 Times
#
#
#               Last 200 Episode Average for Agent BNN_0.05_0.95_0.02_0_0_0: 24.855
#
#         ***Testing Agent BNN***
#         learning_rate = 0.05,
#         gamma = 0.995,
#         egreedy_final = 0.02,
#         hidden_layer = 0,
#         batch_size = 0,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 5.137445***
#                  Average Reward for last 333 steps: 16.996997
#                  Average Reward for all steps: 16.997006
#                  Epsilon: 0.023012956755697814, Frames Total :5677
#                  Solved 0 Times
#
# 			 *** Episode 666 at Total Seconds 13.269260***
#                  Average Reward for last 333 steps: 28.366366
#                  Average Reward for all steps: 22.673163
#                  Epsilon: 0.020000238038509557, Frames Total :15123
#                  Solved 0 Times
# 			 *** Episode 999 at Total Seconds 20.977171***
#                  Average Reward for last 333 steps: 26.681682
#                  Average Reward for all steps: 24.008000
#                  Epsilon: 0.020000000032956475, Frames Total :24008
#                  Solved 0 Times
#
#
#               Last 200 Episode Average for Agent BNN_0.05_0.995_0.02_0_0_0: 26.735
#
#         ***Testing Agent BNN***
#         learning_rate = 0.05,
#         gamma = 0.995,
#         egreedy_final = 0.02,
#         hidden_layer = 0,
#         batch_size = 0,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 5.777595***
#                  Average Reward for last 333 steps: 18.264264
#                  Average Reward for all steps: 18.248503
#                  Epsilon: 0.02198361692382885, Frames Total :6095
#                  Solved 0 Times
#
# 			 *** Episode 666 at Total Seconds 14.176655***
#                  Average Reward for last 333 steps: 27.912913
#                  Average Reward for all steps: 23.073463
#                  Epsilon: 0.02000018225967674, Frames Total :15390
#                  Solved 0 Times
#
# 			 *** Episode 999 at Total Seconds 20.751804***
#                  Average Reward for last 333 steps: 22.033033
#                  Average Reward for all steps: 22.727000
#                  Epsilon: 0.02000000011865116, Frames Total :22727
#                  Solved 0 Times
#
#
#               Last 200 Episode Average for Agent BNN_0.05_0.995_0.02_0_0_0: 20.99
#
#         ***Testing Agent BNN***
#         learning_rate = 0.01,
#         gamma = 0.85,
#         egreedy_final = 0.02,
#         hidden_layer = 0,
#         batch_size = 0,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 5.539321***
#                  Average Reward for last 333 steps: 18.105105
#                  Average Reward for all steps: 18.083832
#                  Epsilon: 0.022095771843982846, Frames Total :6040
#                  Solved 0 Times
#
# 			 *** Episode 666 at Total Seconds 13.663919***
#                  Average Reward for last 333 steps: 27.093093
#                  Average Reward for all steps: 22.581709
#                  Epsilon: 0.020000253010873343, Frames Total :15062
#                  Solved 0 Times
#
# 			 *** Episode 999 at Total Seconds 22.122976***
#                  Average Reward for last 333 steps: 27.774775
#                  Average Reward for all steps: 24.311000
#                  Epsilon: 0.020000000024341623, Frames Total :24311
#                  Solved 0 Times
#
#
#               Last 200 Episode Average for Agent BNN_0.01_0.85_0.02_0_0_0: 25.9
#
#         ***Testing Agent BNN***
#         learning_rate = 0.01,
#         gamma = 0.85,
#         egreedy_final = 0.02,
#         hidden_layer = 0,
#         batch_size = 0,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 6.231568***
#                  Average Reward for last 333 steps: 16.114114
#                  Average Reward for all steps: 16.200599
#                  Epsilon: 0.023931110309466565, Frames Total :5411
#                  Solved 0 Times
#
# 			 *** Episode 666 at Total Seconds 14.773714***
#                  Average Reward for last 333 steps: 28.096096
#                  Average Reward for all steps: 22.139430
#                  Epsilon: 0.02000033982557302, Frames Total :14767
#                  Solved 0 Times
#
# 			 *** Episode 999 at Total Seconds 23.107512***
#                  Average Reward for last 333 steps: 27.699700
#                  Average Reward for all steps: 23.991000
#                  Epsilon: 0.020000000033521526, Frames Total :23991
#                  Solved 0 Times
#
#
#               Last 200 Episode Average for Agent BNN_0.01_0.85_0.02_0_0_0: 25.505
#
#         ***Testing Agent BNN***
#         learning_rate = 0.01,
#         gamma = 0.9,
#         egreedy_final = 0.02,
#         hidden_layer = 0,
#         batch_size = 0,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 6.199315***
#                  Average Reward for last 333 steps: 19.954955
#                  Average Reward for all steps: 19.946108
#                  Epsilon: 0.021125156241641383, Frames Total :6662
#                  Solved 0 Times
#
# 			 *** Episode 666 at Total Seconds 13.973826***
#                  Average Reward for last 333 steps: 25.456456
#                  Average Reward for all steps: 22.697151
#                  Epsilon: 0.020000234260200478, Frames Total :15139
#                  Solved 0 Times
#
# 			 *** Episode 999 at Total Seconds 22.437979***
#                  Average Reward for last 333 steps: 27.657658
#                  Average Reward for all steps: 24.349000
#                  Epsilon: 0.020000000023433995, Frames Total :24349
#                  Solved 0 Times
#
#
#               Last 200 Episode Average for Agent BNN_0.01_0.9_0.02_0_0_0: 27.95
#
#         ***Testing Agent BNN***
#         learning_rate = 0.01,
#         gamma = 0.9,
#         egreedy_final = 0.02,
#         hidden_layer = 0,
#         batch_size = 0,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 5.345327***
#                  Average Reward for last 333 steps: 16.693694
#                  Average Reward for all steps: 16.676647
#                  Epsilon: 0.023353222780680992, Frames Total :5570
#                  Solved 0 Times
#
# 			 *** Episode 666 at Total Seconds 13.362594***
#                  Average Reward for last 333 steps: 25.861862
#                  Average Reward for all steps: 21.262369
#                  Epsilon: 0.02000060998384026, Frames Total :14182
#                  Solved 0 Times
#
# 			 *** Episode 999 at Total Seconds 23.003398***
#                  Average Reward for last 333 steps: 28.708709
#                  Average Reward for all steps: 23.742000
#                  Epsilon: 0.02000000004299947, Frames Total :23742
#                  Solved 0 Times
#
#
#               Last 200 Episode Average for Agent BNN_0.01_0.9_0.02_0_0_0: 28.405
#
#         ***Testing Agent BNN***
#         learning_rate = 0.01,
#         gamma = 0.95,
#         egreedy_final = 0.02,
#         hidden_layer = 0,
#         batch_size = 0,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 5.620049***
#                  Average Reward for last 333 steps: 18.327327
#                  Average Reward for all steps: 18.323353
#                  Epsilon: 0.02193464124747743, Frames Total :6120
#                  Solved 0 Times
#
# 			 *** Episode 666 at Total Seconds 13.837629***
#                  Average Reward for last 333 steps: 27.051051
#                  Average Reward for all steps: 22.680660
#                  Epsilon: 0.020000236851287535, Frames Total :15128
#                  Solved 0 Times
#
# 			 *** Episode 999 at Total Seconds 22.064308***
#                  Average Reward for last 333 steps: 26.888889
#                  Average Reward for all steps: 24.082000
#                  Epsilon: 0.020000000030605744, Frames Total :24082
#                  Solved 0 Times
#
#
#               Last 200 Episode Average for Agent BNN_0.01_0.95_0.02_0_0_0: 25.82
#
#         ***Testing Agent BNN***
#         learning_rate = 0.01,
#         gamma = 0.95,
#         egreedy_final = 0.02,
#         hidden_layer = 0,
#         batch_size = 0,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 5.364866***
#                  Average Reward for last 333 steps: 17.546547
#                  Average Reward for all steps: 17.520958
#                  Epsilon: 0.022529247701844543, Frames Total :5852
#                  Solved 0 Times
#
# 			 *** Episode 666 at Total Seconds 14.224807***
#                  Average Reward for last 333 steps: 30.027027
#                  Average Reward for all steps: 23.764618
#                  Epsilon: 0.02000011494255312, Frames Total :15851
#                  Solved 0 Times
#
# 			 *** Episode 999 at Total Seconds 21.926838***
#                  Average Reward for last 333 steps: 25.357357
#                  Average Reward for all steps: 24.295000
#                  Epsilon: 0.020000000024734222, Frames Total :24295
#                  Solved 0 Times
#
#
#               Last 200 Episode Average for Agent BNN_0.01_0.95_0.02_0_0_0: 22.525
#
#         ***Testing Agent BNN***
#         learning_rate = 0.01,
#         gamma = 0.995,
#         egreedy_final = 0.02,
#         hidden_layer = 0,
#         batch_size = 0,
#         update_target_frequency = 0
# 			 *** Episode 333 at Total Seconds 6.397825***
#                  Average Reward for last 333 steps: 21.417417
#                  Average Reward for all steps: 21.425150
#                  Epsilon: 0.020686548716624106, Frames Total :7156
#                  Solved 0 Times
#
# 			 *** Episode 666 at Total Seconds 13.710065***
#                  Average Reward for last 333 steps: 24.021021
#                  Average Reward for all steps: 22.721139
#                  Epsilon: 0.020000230541863295, Frames Total :15155
#                  Solved 0 Times
#
# 			 *** Episode 999 at Total Seconds 21.866871***
#                  Average Reward for last 333 steps: 27.651652
#                  Average Reward for all steps: 24.363000
#                  Epsilon: 0.020000000023108207, Frames Total :24363
#                  Solved 0 Times
#
#
#               Last 200 Episode Average for Agent BNN_0.01_0.995_0.02_0_0_0: 26.335
#
#         ***Testing Agent BNN***
#         learning_rate = 0.01,
#         gamma = 0.995,
#         egreedy_final = 0.02,
#         hidden_layer = 0,
#         batch_size = 0,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 5.660115***
#                  Average Reward for last 333 steps: 18.129129
#                  Average Reward for all steps: 18.128743
#                  Epsilon: 0.02206456986619143, Frames Total :6055
#                  Solved 0 Times
#
# 			 *** Episode 666 at Total Seconds 13.734060***
#                  Average Reward for last 333 steps: 26.774775
#                  Average Reward for all steps: 22.445277
#                  Epsilon: 0.020000277114967564, Frames Total :14971
#                  Solved 0 Times
#
# 			 *** Episode 999 at Total Seconds 21.797945***
#                  Average Reward for last 333 steps: 26.528529
#                  Average Reward for all steps: 23.805000
#                  Epsilon: 0.02000000004037407, Frames Total :23805
#                  Solved 0 Times
#
#
#               Last 200 Episode Average for Agent BNN_0.01_0.995_0.02_0_0_0: 27.36
# /n/nBNN_0.05_0.9_0.02_0_0_0 is the best of the test

# %% [markdown]
# ## Two Layer Neural Nets

# %% [markdown]
# ### BNN - TLN Differences

# %% [markdown]
# <strong>The only major difference between these two networks is the addition of an extra linear layer in the neural net</strong>

# %% [markdown]
# ### Two Layer Neural Net Definition

# %%
class NeuralNetwork_2(nn.Module):
    def __init__(self):
        super(NeuralNetwork_2, self).__init__()
        
        #In this notebook, I am most interested in how different algorithms
        #Effect the performance of the learning agents. Therefore, I will 
        #Keep the network design relitively simple
        self.linear1 = nn.Linear(number_of_inputs,hidden_layer)
        self.linear2 = nn.Linear(hidden_layer,number_of_outputs)

        self.activation = nn.Tanh()
        #self.activation = nn.ReLU()
        
        
    def forward(self, x):
        output1 = self.linear1(x)
        #Adding activation function between layers
        output1 = self.activation(output1)
        output2 = self.linear2(output1)
        
        return output2

# %% [markdown]
# ### TLN Class

# %%
class TLN(object):
    
    def __init__(self,Agent, label):
        self.nn = NeuralNetwork_2().to(device)
        self.name = label

        self.loss_func = nn.MSELoss()
        #self.loss_func = nn.SmoothL1Loss()
        
        self.optimizer = optim.Adam(params=self.nn.parameters(), lr=learning_rate)
        #self.optimizer = optim.RMSprop(params=mynn.parameters(), lr=learning_rate)

#Bringing in the prior defined functions into the TLN Class
setattr(TLN, "calculate_epsilon", calculate_epsilon)
setattr(TLN, "select_action", select_action)
setattr(TLN, "optimize", optimize)

# %% [markdown]
# ### TLN Parameters

# %%
#Reset Params
#Step Size
learning_rate = 0.01

#Discount Factor
gamma = 0.995

#Exploration vs Explotation trade off
egreedy = 0.9
egreedy_final = 0.02
egreedy_decay = 1000

#Need to add a hidden layer in the neural net
hidden_layer = 128

# %% [markdown]
# ### TLN Simulation

# %%
record = simulation(1000, "TLN","TLN_1", record, 333)

plot_agent(record, "TLN_1")
# Out:
# 			 *** Episode 333 at Total Seconds 79.351158***
#                  Average Reward for last 333 steps: 221.465465
#                  Average Reward for all steps: 220.856287
#                  Epsilon: 0.02, Frames Total :73766
#                  Solved 104 Times
#
# 			 *** Episode 666 at Total Seconds 214.390603***
#                  Average Reward for last 333 steps: 371.459459
#                  Average Reward for all steps: 296.044978
#                  Epsilon: 0.02, Frames Total :197462
#                  Solved 296 Times
#
# 			 *** Episode 999 at Total Seconds 362.922356***
#                  Average Reward for last 333 steps: 409.303303
#                  Average Reward for all steps: 333.760000
#                  Epsilon: 0.02, Frames Total :333760
#                  Solved 533 Times
#
# [0.141, 0.26, 0.378, 0.433, 0.451]

# %% [markdown]
# ### TLN Notes
# <br><br><strong>
# This network is a significant improvement over the one layer network, however, it is very inconsistent, often slipping. Next we will explore an experience learning algorithm</strong>

# %% [markdown]
# ### HyperTunning TLN

# %%
hyper = {
    "learning_rate" :          [.02, .005, .001],
    "gamma":                   [0.95, .995],
    "egreedy_final":           [0.02, .002], 
    "hidden_layer":            [256],
    "batch_size":              [0],
    "update_target_frequency": [0],}

record = hyper_and_beyond(hyper, record, "TLN", knobs = knobs)
# Out:
#         ***Testing Agent TLN***
#         learning_rate = 0.1,
#         gamma = 0.85,
#         egreedy_final = 0.02,
#         hidden_layer = 64,
#         batch_size = 0,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 43.648427***
#                  Average Reward for last 333 steps: 76.141141
#                  Average Reward for all steps: 75.961078
#                  Epsilon: 0.020000000008433296, Frames Total :25371
#                  Solved 7 Times
#
# 			 *** Episode 666 at Total Seconds 124.307960***
#                  Average Reward for last 333 steps: 100.915916
#                  Average Reward for all steps: 88.419790
#                  Epsilon: 0.02, Frames Total :58976
#                  Solved 18 Times
#
# 			 *** Episode 999 at Total Seconds 204.180972***
#                  Average Reward for last 333 steps: 103.348348
#                  Average Reward for all steps: 93.391000
#                  Epsilon: 0.02, Frames Total :93391
#                  Solved 19 Times
#
#
#               Last 200 Episode Average for Agent TLN_0.1_0.85_0.02_64_0_0: 88.995
#
#         ***Testing Agent TLN***
#         learning_rate = 0.1,
#         gamma = 0.85,
#         egreedy_final = 0.02,
#         hidden_layer = 128,
#         batch_size = 0,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 75.642566***
#                  Average Reward for last 333 steps: 109.555556
#                  Average Reward for all steps: 109.320359
#                  Epsilon: 0.020000000000000122, Frames Total :36513
#                  Solved 6 Times
#
# 			 *** Episode 666 at Total Seconds 187.143388***
#                  Average Reward for last 333 steps: 156.981982
#                  Average Reward for all steps: 133.115442
#                  Epsilon: 0.02, Frames Total :88788
#                  Solved 34 Times
#
# 			 *** Episode 999 at Total Seconds 314.536921***
#                  Average Reward for last 333 steps: 131.975976
#                  Average Reward for all steps: 132.736000
#                  Epsilon: 0.02, Frames Total :132736
#                  Solved 51 Times
#
#
#               Last 200 Episode Average for Agent TLN_0.1_0.85_0.02_128_0_0: 116.84
#
#         ***Testing Agent TLN***
#         learning_rate = 0.1,
#         gamma = 0.85,
#         egreedy_final = 0.02,
#         hidden_layer = 256,
#         batch_size = 0,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 112.312221***
#                  Average Reward for last 333 steps: 110.324324
#                  Average Reward for all steps: 110.050898
#                  Epsilon: 0.020000000000000098, Frames Total :36757
#                  Solved 9 Times
#
# 			 *** Episode 666 at Total Seconds 306.605767***
#                  Average Reward for last 333 steps: 175.468468
#                  Average Reward for all steps: 142.710645
#                  Epsilon: 0.02, Frames Total :95188
#                  Solved 42 Times
#
# 			 *** Episode 999 at Total Seconds 391.017103***
#                  Average Reward for last 333 steps: 132.714715
#                  Average Reward for all steps: 139.382000
#                  Epsilon: 0.02, Frames Total :139382
#                  Solved 45 Times
#
#
#               Last 200 Episode Average for Agent TLN_0.1_0.85_0.02_256_0_0: 135.545
#
#         ***Testing Agent TLN***
#         learning_rate = 0.1,
#         gamma = 0.85,
#         egreedy_final = 0.02,
#         hidden_layer = 64,
#         batch_size = 0,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 65.795569***
#                  Average Reward for last 333 steps: 144.705706
#                  Average Reward for all steps: 144.320359
#                  Epsilon: 0.02, Frames Total :48203
#                  Solved 32 Times
#
# 			 *** Episode 666 at Total Seconds 119.013382***
#                  Average Reward for last 333 steps: 114.651652
#                  Average Reward for all steps: 129.508246
#                  Epsilon: 0.02, Frames Total :86382
#                  Solved 35 Times
#
# 			 *** Episode 999 at Total Seconds 163.763386***
#                  Average Reward for last 333 steps: 95.498498
#                  Average Reward for all steps: 118.183000
#                  Epsilon: 0.02, Frames Total :118183
#                  Solved 36 Times
#
#
#               Last 200 Episode Average for Agent TLN_0.1_0.85_0.02_64_0_0: 74.66
#
#         ***Testing Agent TLN***
#         learning_rate = 0.1,
#         gamma = 0.85,
#         egreedy_final = 0.02,
#         hidden_layer = 128,
#         batch_size = 0,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 61.282650***
#                  Average Reward for last 333 steps: 140.300300
#                  Average Reward for all steps: 139.913174
#                  Epsilon: 0.02, Frames Total :46731
#                  Solved 23 Times
#
# 			 *** Episode 666 at Total Seconds 107.737947***
#                  Average Reward for last 333 steps: 124.795796
#                  Average Reward for all steps: 132.365817
#                  Epsilon: 0.02, Frames Total :88288
#                  Solved 30 Times
#
# 			 *** Episode 999 at Total Seconds 154.012867***
#                  Average Reward for last 333 steps: 123.924925
#                  Average Reward for all steps: 129.555000
#                  Epsilon: 0.02, Frames Total :129555
#                  Solved 38 Times
#
#
#               Last 200 Episode Average for Agent TLN_0.1_0.85_0.02_128_0_0: 126.975
#
#         ***Testing Agent TLN***
#         learning_rate = 0.1,
#         gamma = 0.85,
#         egreedy_final = 0.02,
#         hidden_layer = 256,
#         batch_size = 0,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 36.157884***
#                  Average Reward for last 333 steps: 97.042042
#                  Average Reward for all steps: 96.838323
#                  Epsilon: 0.0200000000000079, Frames Total :32344
#                  Solved 11 Times
#
# 			 *** Episode 666 at Total Seconds 87.239382***
#                  Average Reward for last 333 steps: 138.606607
#                  Average Reward for all steps: 117.691154
#                  Epsilon: 0.02, Frames Total :78500
#                  Solved 23 Times
#
# 			 *** Episode 999 at Total Seconds 112.925658***
#                  Average Reward for last 333 steps: 68.840841
#                  Average Reward for all steps: 101.424000
#                  Epsilon: 0.02, Frames Total :101424
#                  Solved 23 Times
#
#
#               Last 200 Episode Average for Agent TLN_0.1_0.85_0.02_256_0_0: 34.02
#
#         ***Testing Agent TLN***
#         learning_rate = 0.1,
#         gamma = 0.9,
#         egreedy_final = 0.02,
#         hidden_layer = 64,
#         batch_size = 0,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 16.839799***
#                  Average Reward for last 333 steps: 45.327327
#                  Average Reward for all steps: 45.257485
#                  Epsilon: 0.020000239710624697, Frames Total :15116
#                  Solved 1 Times
#
# 			 *** Episode 666 at Total Seconds 68.427422***
#                  Average Reward for last 333 steps: 139.621622
#                  Average Reward for all steps: 92.368816
#                  Epsilon: 0.02, Frames Total :61610
#                  Solved 17 Times
#
# 			 *** Episode 999 at Total Seconds 107.277238***
#                  Average Reward for last 333 steps: 105.648649
#                  Average Reward for all steps: 96.791000
#                  Epsilon: 0.02, Frames Total :96791
#                  Solved 21 Times
#
#
#               Last 200 Episode Average for Agent TLN_0.1_0.9_0.02_64_0_0: 120.515
#
#         ***Testing Agent TLN***
#         learning_rate = 0.1,
#         gamma = 0.9,
#         egreedy_final = 0.02,
#         hidden_layer = 128,
#         batch_size = 0,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 39.319855***
#                  Average Reward for last 333 steps: 104.648649
#                  Average Reward for all steps: 104.386228
#                  Epsilon: 0.020000000000000635, Frames Total :34865
#                  Solved 11 Times
# 			 *** Episode 666 at Total Seconds 85.159712***
#                  Average Reward for last 333 steps: 125.570571
#                  Average Reward for all steps: 114.962519
#                  Epsilon: 0.02, Frames Total :76680
#                  Solved 14 Times
#
# 			 *** Episode 999 at Total Seconds 118.359906***
#                  Average Reward for last 333 steps: 88.534535
#                  Average Reward for all steps: 106.162000
#                  Epsilon: 0.02, Frames Total :106162
#                  Solved 16 Times
#
#
#               Last 200 Episode Average for Agent TLN_0.1_0.9_0.02_128_0_0: 89.99
#
#         ***Testing Agent TLN***
#         learning_rate = 0.1,
#         gamma = 0.9,
#         egreedy_final = 0.02,
#         hidden_layer = 256,
#         batch_size = 0,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 44.507728***
#                  Average Reward for last 333 steps: 120.801802
#                  Average Reward for all steps: 120.491018
#                  Epsilon: 0.020000000000000004, Frames Total :40244
#                  Solved 19 Times
#
# 			 *** Episode 666 at Total Seconds 92.236969***
#                  Average Reward for last 333 steps: 128.852853
#                  Average Reward for all steps: 124.665667
#                  Epsilon: 0.02, Frames Total :83152
#                  Solved 28 Times
#
# 			 *** Episode 999 at Total Seconds 138.714779***
#                  Average Reward for last 333 steps: 126.423423
#                  Average Reward for all steps: 125.251000
#                  Epsilon: 0.02, Frames Total :125251
#                  Solved 31 Times
#
#
#               Last 200 Episode Average for Agent TLN_0.1_0.9_0.02_256_0_0: 130.825
#
#         ***Testing Agent TLN***
#         learning_rate = 0.1,
#         gamma = 0.9,
#         egreedy_final = 0.02,
#         hidden_layer = 64,
#         batch_size = 0,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 43.269381***
#                  Average Reward for last 333 steps: 119.765766
#                  Average Reward for all steps: 119.449102
#                  Epsilon: 0.020000000000000004, Frames Total :39896
#                  Solved 10 Times
#
# 			 *** Episode 666 at Total Seconds 90.006383***
#                  Average Reward for last 333 steps: 126.423423
#                  Average Reward for all steps: 122.931034
#                  Epsilon: 0.02, Frames Total :81995
#                  Solved 19 Times
#
# 			 *** Episode 999 at Total Seconds 154.274671***
#                  Average Reward for last 333 steps: 175.312312
#                  Average Reward for all steps: 140.374000
#                  Epsilon: 0.02, Frames Total :140374
#                  Solved 67 Times
#
#
#               Last 200 Episode Average for Agent TLN_0.1_0.9_0.02_64_0_0: 204.525
#
#         ***Testing Agent TLN***
#         learning_rate = 0.1,
#         gamma = 0.9,
#         egreedy_final = 0.02,
#         hidden_layer = 128,
#         batch_size = 0,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 34.811018***
#                  Average Reward for last 333 steps: 94.084084
#                  Average Reward for all steps: 93.832335
#                  Epsilon: 0.020000000000021563, Frames Total :31340
#                  Solved 14 Times
#
# 			 *** Episode 666 at Total Seconds 77.565188***
#                  Average Reward for last 333 steps: 117.678679
#                  Average Reward for all steps: 105.737631
#                  Epsilon: 0.02, Frames Total :70527
#                  Solved 20 Times
#
# 			 *** Episode 999 at Total Seconds 104.491091***
#                  Average Reward for last 333 steps: 72.525526
#                  Average Reward for all steps: 94.678000
#                  Epsilon: 0.02, Frames Total :94678
#                  Solved 21 Times
#
#
#               Last 200 Episode Average for Agent TLN_0.1_0.9_0.02_128_0_0: 58.475
#
#         ***Testing Agent TLN***
#         learning_rate = 0.1,
#         gamma = 0.9,
#         egreedy_final = 0.02,
#         hidden_layer = 256,
#         batch_size = 0,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 39.062100***
#                  Average Reward for last 333 steps: 105.606607
#                  Average Reward for all steps: 105.344311
#                  Epsilon: 0.020000000000000462, Frames Total :35185
#                  Solved 4 Times
#
# 			 *** Episode 666 at Total Seconds 76.496074***
#                  Average Reward for last 333 steps: 100.966967
#                  Average Reward for all steps: 103.158921
#                  Epsilon: 0.02, Frames Total :68807
#                  Solved 16 Times
#
# 			 *** Episode 999 at Total Seconds 126.353000***
#                  Average Reward for last 333 steps: 135.711712
#                  Average Reward for all steps: 113.999000
#                  Epsilon: 0.02, Frames Total :113999
#                  Solved 44 Times
#
#
#               Last 200 Episode Average for Agent TLN_0.1_0.9_0.02_256_0_0: 114.24
#
#         ***Testing Agent TLN***
#         learning_rate = 0.1,
#         gamma = 0.95,
#         egreedy_final = 0.02,
#         hidden_layer = 64,
#         batch_size = 0,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 38.419366***
#                  Average Reward for last 333 steps: 105.174174
#                  Average Reward for all steps: 104.907186
#                  Epsilon: 0.020000000000000535, Frames Total :35039
#                  Solved 9 Times
#
# 			 *** Episode 666 at Total Seconds 85.481091***
#                  Average Reward for last 333 steps: 127.417417
#                  Average Reward for all steps: 116.145427
#                  Epsilon: 0.02, Frames Total :77469
#                  Solved 23 Times
#
# 			 *** Episode 999 at Total Seconds 136.883103***
#                  Average Reward for last 333 steps: 138.885886
#                  Average Reward for all steps: 123.718000
#                  Epsilon: 0.02, Frames Total :123718
#                  Solved 37 Times
#
#
#               Last 200 Episode Average for Agent TLN_0.1_0.95_0.02_64_0_0: 152.595
#
#         ***Testing Agent TLN***
#         learning_rate = 0.1,
#         gamma = 0.95,
#         egreedy_final = 0.02,
#         hidden_layer = 128,
#         batch_size = 0,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 42.167091***
#                  Average Reward for last 333 steps: 114.219219
#                  Average Reward for all steps: 113.943114
#                  Epsilon: 0.020000000000000028, Frames Total :38057
#                  Solved 5 Times
#
# 			 *** Episode 666 at Total Seconds 100.869391***
#                  Average Reward for last 333 steps: 160.153153
#                  Average Reward for all steps: 137.013493
#                  Epsilon: 0.02, Frames Total :91388
#                  Solved 32 Times
#
# 			 *** Episode 999 at Total Seconds 147.057398***
#                  Average Reward for last 333 steps: 125.270270
#                  Average Reward for all steps: 133.103000
#                  Epsilon: 0.02, Frames Total :133103
#                  Solved 40 Times
#
#
#               Last 200 Episode Average for Agent TLN_0.1_0.95_0.02_128_0_0: 133.225
#
#         ***Testing Agent TLN***
#         learning_rate = 0.1,
#         gamma = 0.95,
#         egreedy_final = 0.02,
#         hidden_layer = 256,
#         batch_size = 0,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 25.611570***
#                  Average Reward for last 333 steps: 69.756757
#                  Average Reward for all steps: 69.589820
#                  Epsilon: 0.020000000070823278, Frames Total :23243
#                  Solved 8 Times
#
# 			 *** Episode 666 at Total Seconds 84.709728***
#                  Average Reward for last 333 steps: 161.573574
#                  Average Reward for all steps: 115.512744
#                  Epsilon: 0.02, Frames Total :77047
#                  Solved 41 Times
#
# 			 *** Episode 999 at Total Seconds 134.414406***
#                  Average Reward for last 333 steps: 136.000000
#                  Average Reward for all steps: 122.335000
#                  Epsilon: 0.02, Frames Total :122335
#                  Solved 55 Times
#
#
#               Last 200 Episode Average for Agent TLN_0.1_0.95_0.02_256_0_0: 135.125
#
#         ***Testing Agent TLN***
#         learning_rate = 0.1,
#         gamma = 0.95,
#         egreedy_final = 0.02,
#         hidden_layer = 64,
#         batch_size = 0,
#         update_target_frequency = 0
# 			 *** Episode 333 at Total Seconds 20.768544***
#                  Average Reward for last 333 steps: 55.672673
#                  Average Reward for all steps: 55.559880
#                  Epsilon: 0.020000007678563348, Frames Total :18557
#                  Solved 1 Times
#
# 			 *** Episode 666 at Total Seconds 72.624808***
#                  Average Reward for last 333 steps: 140.852853
#                  Average Reward for all steps: 98.142429
#                  Epsilon: 0.02, Frames Total :65461
#                  Solved 12 Times
#
# 			 *** Episode 999 at Total Seconds 114.614119***
#                  Average Reward for last 333 steps: 113.216216
#                  Average Reward for all steps: 103.162000
#                  Epsilon: 0.02, Frames Total :103162
#                  Solved 19 Times
#
#
#               Last 200 Episode Average for Agent TLN_0.1_0.95_0.02_64_0_0: 111.085
#
#         ***Testing Agent TLN***
#         learning_rate = 0.1,
#         gamma = 0.95,
#         egreedy_final = 0.02,
#         hidden_layer = 128,
#         batch_size = 0,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 49.992480***
#                  Average Reward for last 333 steps: 134.855856
#                  Average Reward for all steps: 134.514970
#                  Epsilon: 0.02, Frames Total :44928
#                  Solved 29 Times
#
# 			 *** Episode 666 at Total Seconds 94.423642***
#                  Average Reward for last 333 steps: 120.360360
#                  Average Reward for all steps: 127.448276
#                  Epsilon: 0.02, Frames Total :85008
#                  Solved 33 Times
#
# 			 *** Episode 999 at Total Seconds 127.364735***
#                  Average Reward for last 333 steps: 89.516517
#                  Average Reward for all steps: 114.817000
#                  Epsilon: 0.02, Frames Total :114817
#                  Solved 35 Times
#
#
#               Last 200 Episode Average for Agent TLN_0.1_0.95_0.02_128_0_0: 96.065
#
#         ***Testing Agent TLN***
#         learning_rate = 0.1,
#         gamma = 0.95,
#         egreedy_final = 0.02,
#         hidden_layer = 256,
#         batch_size = 0,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 40.881293***
#                  Average Reward for last 333 steps: 111.915916
#                  Average Reward for all steps: 111.610778
#                  Epsilon: 0.020000000000000056, Frames Total :37278
#                  Solved 15 Times
#
# 			 *** Episode 666 at Total Seconds 85.809747***
#                  Average Reward for last 333 steps: 122.342342
#                  Average Reward for all steps: 116.968516
#                  Epsilon: 0.02, Frames Total :78018
#                  Solved 25 Times
#
# 			 *** Episode 999 at Total Seconds 154.367126***
#                  Average Reward for last 333 steps: 188.738739
#                  Average Reward for all steps: 140.868000
#                  Epsilon: 0.02, Frames Total :140868
#                  Solved 62 Times
#
#
#               Last 200 Episode Average for Agent TLN_0.1_0.95_0.02_256_0_0: 172.01
#
#         ***Testing Agent TLN***
#         learning_rate = 0.1,
#         gamma = 0.995,
#         egreedy_final = 0.02,
#         hidden_layer = 64,
#         batch_size = 0,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 39.114888***
#                  Average Reward for last 333 steps: 105.645646
#                  Average Reward for all steps: 105.356287
#                  Epsilon: 0.02000000000000046, Frames Total :35189
#                  Solved 17 Times
#
# 			 *** Episode 666 at Total Seconds 62.581430***
#                  Average Reward for last 333 steps: 62.975976
#                  Average Reward for all steps: 84.197901
#                  Epsilon: 0.02, Frames Total :56160
#                  Solved 17 Times
#
# 			 *** Episode 999 at Total Seconds 115.367819***
#                  Average Reward for last 333 steps: 143.582583
#                  Average Reward for all steps: 103.973000
#                  Epsilon: 0.02, Frames Total :103973
#                  Solved 32 Times
#
#
#               Last 200 Episode Average for Agent TLN_0.1_0.995_0.02_64_0_0: 146.56
#
#         ***Testing Agent TLN***
#         learning_rate = 0.1,
#         gamma = 0.995,
#         egreedy_final = 0.02,
#         hidden_layer = 128,
#         batch_size = 0,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 40.687913***
#                  Average Reward for last 333 steps: 110.168168
#                  Average Reward for all steps: 109.925150
#                  Epsilon: 0.0200000000000001, Frames Total :36715
#                  Solved 17 Times
#
# 			 *** Episode 666 at Total Seconds 73.303406***
#                  Average Reward for last 333 steps: 87.825826
#                  Average Reward for all steps: 98.892054
#                  Epsilon: 0.02, Frames Total :65961
#                  Solved 25 Times
#
# 			 *** Episode 999 at Total Seconds 121.288983***
#                  Average Reward for last 333 steps: 129.582583
#                  Average Reward for all steps: 109.112000
#                  Epsilon: 0.02, Frames Total :109112
#                  Solved 28 Times
#
#
#               Last 200 Episode Average for Agent TLN_0.1_0.995_0.02_128_0_0: 137.855
#
#         ***Testing Agent TLN***
#         learning_rate = 0.1,
#         gamma = 0.995,
#         egreedy_final = 0.02,
#         hidden_layer = 256,
#         batch_size = 0,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 39.901449***
#                  Average Reward for last 333 steps: 108.072072
#                  Average Reward for all steps: 107.793413
#                  Epsilon: 0.020000000000000205, Frames Total :36003
#                  Solved 10 Times
#
# 			 *** Episode 666 at Total Seconds 79.194608***
#                  Average Reward for last 333 steps: 107.555556
#                  Average Reward for all steps: 107.674663
#                  Epsilon: 0.02, Frames Total :71819
#                  Solved 13 Times
#
# 			 *** Episode 999 at Total Seconds 126.797631***
#                  Average Reward for last 333 steps: 129.102102
#                  Average Reward for all steps: 114.810000
#                  Epsilon: 0.02, Frames Total :114810
#                  Solved 17 Times
#
#
#               Last 200 Episode Average for Agent TLN_0.1_0.995_0.02_256_0_0: 150.2
#
#         ***Testing Agent TLN***
#         learning_rate = 0.1,
#         gamma = 0.995,
#         egreedy_final = 0.02,
#         hidden_layer = 64,
#         batch_size = 0,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 28.198909***
#                  Average Reward for last 333 steps: 77.984985
#                  Average Reward for all steps: 77.775449
#                  Epsilon: 0.020000000004600605, Frames Total :25977
#                  Solved 5 Times
#
# 			 *** Episode 666 at Total Seconds 76.322515***
#                  Average Reward for last 333 steps: 130.969970
#                  Average Reward for all steps: 104.332834
#                  Epsilon: 0.02, Frames Total :69590
#                  Solved 21 Times
#
# 			 *** Episode 999 at Total Seconds 111.827983***
#                  Average Reward for last 333 steps: 97.129129
#                  Average Reward for all steps: 101.934000
#                  Epsilon: 0.02, Frames Total :101934
#                  Solved 23 Times
#
#
#               Last 200 Episode Average for Agent TLN_0.1_0.995_0.02_64_0_0: 97.81
#
#         ***Testing Agent TLN***
#         learning_rate = 0.1,
#         gamma = 0.995,
#         egreedy_final = 0.02,
#         hidden_layer = 128,
#         batch_size = 0,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 39.325494***
#                  Average Reward for last 333 steps: 106.864865
#                  Average Reward for all steps: 106.586826
#                  Epsilon: 0.020000000000000306, Frames Total :35600
#                  Solved 7 Times
#
# 			 *** Episode 666 at Total Seconds 104.446089***
#                  Average Reward for last 333 steps: 176.624625
#                  Average Reward for all steps: 141.553223
#                  Epsilon: 0.02, Frames Total :94416
#                  Solved 35 Times
# 			 *** Episode 999 at Total Seconds 146.820274***
#                  Average Reward for last 333 steps: 114.429429
#                  Average Reward for all steps: 132.521000
#                  Epsilon: 0.02, Frames Total :132521
#                  Solved 45 Times
#
#
#               Last 200 Episode Average for Agent TLN_0.1_0.995_0.02_128_0_0: 97.28
#
#         ***Testing Agent TLN***
#         learning_rate = 0.1,
#         gamma = 0.995,
#         egreedy_final = 0.02,
#         hidden_layer = 256,
#         batch_size = 0,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 28.362741***
#                  Average Reward for last 333 steps: 77.135135
#                  Average Reward for all steps: 76.943114
#                  Epsilon: 0.020000000006075037, Frames Total :25699
#                  Solved 6 Times
#
# 			 *** Episode 666 at Total Seconds 71.644303***
#                  Average Reward for last 333 steps: 115.723724
#                  Average Reward for all steps: 96.304348
#                  Epsilon: 0.02, Frames Total :64235
#                  Solved 13 Times
#
# 			 *** Episode 999 at Total Seconds 95.167759***
#                  Average Reward for last 333 steps: 63.045045
#                  Average Reward for all steps: 85.229000
#                  Epsilon: 0.02, Frames Total :85229
#                  Solved 15 Times
#
#
#               Last 200 Episode Average for Agent TLN_0.1_0.995_0.02_256_0_0: 76.71
#
#         ***Testing Agent TLN***
#         learning_rate = 0.05,
#         gamma = 0.85,
#         egreedy_final = 0.02,
#         hidden_layer = 64,
#         batch_size = 0,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 39.700430***
#                  Average Reward for last 333 steps: 107.540541
#                  Average Reward for all steps: 107.257485
#                  Epsilon: 0.020000000000000243, Frames Total :35824
#                  Solved 8 Times
#
# 			 *** Episode 666 at Total Seconds 78.941422***
#                  Average Reward for last 333 steps: 106.003003
#                  Average Reward for all steps: 106.631184
#                  Epsilon: 0.02, Frames Total :71123
#                  Solved 15 Times
#
# 			 *** Episode 999 at Total Seconds 117.414334***
#                  Average Reward for last 333 steps: 103.330330
#                  Average Reward for all steps: 105.532000
#                  Epsilon: 0.02, Frames Total :105532
#                  Solved 26 Times
#
#
#               Last 200 Episode Average for Agent TLN_0.05_0.85_0.02_64_0_0: 85.77
#
#         ***Testing Agent TLN***
#         learning_rate = 0.05,
#         gamma = 0.85,
#         egreedy_final = 0.02,
#         hidden_layer = 128,
#         batch_size = 0,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 52.721616***
#                  Average Reward for last 333 steps: 142.582583
#                  Average Reward for all steps: 142.188623
#                  Epsilon: 0.02, Frames Total :47491
#                  Solved 24 Times
#
# 			 *** Episode 666 at Total Seconds 105.229999***
#                  Average Reward for last 333 steps: 141.336336
#                  Average Reward for all steps: 141.763118
#                  Epsilon: 0.02, Frames Total :94556
#                  Solved 46 Times
#
# 			 *** Episode 999 at Total Seconds 140.685567***
#                  Average Reward for last 333 steps: 95.729730
#                  Average Reward for all steps: 126.434000
#                  Epsilon: 0.02, Frames Total :126434
#                  Solved 55 Times
#
#
#               Last 200 Episode Average for Agent TLN_0.05_0.85_0.02_128_0_0: 119.54
#
#         ***Testing Agent TLN***
#         learning_rate = 0.05,
#         gamma = 0.85,
#         egreedy_final = 0.02,
#         hidden_layer = 256,
#         batch_size = 0,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 36.707206***
#                  Average Reward for last 333 steps: 98.819820
#                  Average Reward for all steps: 98.553892
#                  Epsilon: 0.020000000000004455, Frames Total :32917
#                  Solved 2 Times
#
# 			 *** Episode 666 at Total Seconds 75.412173***
#                  Average Reward for last 333 steps: 105.282282
#                  Average Reward for all steps: 101.913043
#                  Epsilon: 0.02, Frames Total :67976
#                  Solved 2 Times
#
# 			 *** Episode 999 at Total Seconds 133.094514***
#                  Average Reward for last 333 steps: 157.087087
#                  Average Reward for all steps: 120.286000
#                  Epsilon: 0.02, Frames Total :120286
#                  Solved 20 Times
#
#
#               Last 200 Episode Average for Agent TLN_0.05_0.85_0.02_256_0_0: 171.115
#
#         ***Testing Agent TLN***
#         learning_rate = 0.05,
#         gamma = 0.85,
#         egreedy_final = 0.02,
#         hidden_layer = 64,
#         batch_size = 0,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 39.856368***
#                  Average Reward for last 333 steps: 108.273273
#                  Average Reward for all steps: 108.005988
#                  Epsilon: 0.02000000000000019, Frames Total :36074
#                  Solved 9 Times
#
# 			 *** Episode 666 at Total Seconds 98.122469***
#                  Average Reward for last 333 steps: 158.075075
#                  Average Reward for all steps: 133.002999
#                  Epsilon: 0.02, Frames Total :88713
#                  Solved 24 Times
#
# 			 *** Episode 999 at Total Seconds 150.414449***
#                  Average Reward for last 333 steps: 141.606607
#                  Average Reward for all steps: 135.868000
#                  Epsilon: 0.02, Frames Total :135868
#                  Solved 40 Times
#
#
#               Last 200 Episode Average for Agent TLN_0.05_0.85_0.02_64_0_0: 130.535
#
#         ***Testing Agent TLN***
#         learning_rate = 0.05,
#         gamma = 0.85,
#         egreedy_final = 0.02,
#         hidden_layer = 128,
#         batch_size = 0,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 38.489848***
#                  Average Reward for last 333 steps: 103.828829
#                  Average Reward for all steps: 103.550898
#                  Epsilon: 0.02000000000000084, Frames Total :34586
#                  Solved 6 Times
#
# 			 *** Episode 666 at Total Seconds 88.140479***
#                  Average Reward for last 333 steps: 135.891892
#                  Average Reward for all steps: 119.697151
#                  Epsilon: 0.02, Frames Total :79838
#                  Solved 12 Times
#
# 			 *** Episode 999 at Total Seconds 146.049916***
#                  Average Reward for last 333 steps: 157.081081
#                  Average Reward for all steps: 132.146000
#                  Epsilon: 0.02, Frames Total :132146
#                  Solved 35 Times
#
#
#               Last 200 Episode Average for Agent TLN_0.05_0.85_0.02_128_0_0: 166.57
#
#         ***Testing Agent TLN***
#         learning_rate = 0.05,
#         gamma = 0.85,
#         egreedy_final = 0.02,
#         hidden_layer = 256,
#         batch_size = 0,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 44.431080***
#                  Average Reward for last 333 steps: 120.435435
#                  Average Reward for all steps: 120.119760
#                  Epsilon: 0.020000000000000004, Frames Total :40120
#                  Solved 7 Times
#
# 			 *** Episode 666 at Total Seconds 86.877417***
#                  Average Reward for last 333 steps: 115.195195
#                  Average Reward for all steps: 117.661169
#                  Epsilon: 0.02, Frames Total :78480
#                  Solved 11 Times
#
# 			 *** Episode 999 at Total Seconds 139.286181***
#                  Average Reward for last 333 steps: 143.309309
#                  Average Reward for all steps: 126.202000
#                  Epsilon: 0.02, Frames Total :126202
#                  Solved 17 Times
#
#
#               Last 200 Episode Average for Agent TLN_0.05_0.85_0.02_256_0_0: 147.255
#
#         ***Testing Agent TLN***
#         learning_rate = 0.05,
#         gamma = 0.9,
#         egreedy_final = 0.02,
#         hidden_layer = 64,
#         batch_size = 0,
#         update_target_frequency = 0
# 			 *** Episode 333 at Total Seconds 38.080683***
#                  Average Reward for last 333 steps: 102.492492
#                  Average Reward for all steps: 102.266467
#                  Epsilon: 0.02000000000000129, Frames Total :34157
#                  Solved 10 Times
#
# 			 *** Episode 666 at Total Seconds 90.009021***
#                  Average Reward for last 333 steps: 140.717718
#                  Average Reward for all steps: 121.463268
#                  Epsilon: 0.02, Frames Total :81016
#                  Solved 21 Times
#
# 			 *** Episode 999 at Total Seconds 142.934590***
#                  Average Reward for last 333 steps: 143.009009
#                  Average Reward for all steps: 128.638000
#                  Epsilon: 0.02, Frames Total :128638
#                  Solved 33 Times
#
#
#               Last 200 Episode Average for Agent TLN_0.05_0.9_0.02_64_0_0: 122.48
#
#         ***Testing Agent TLN***
#         learning_rate = 0.05,
#         gamma = 0.9,
#         egreedy_final = 0.02,
#         hidden_layer = 128,
#         batch_size = 0,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 30.991380***
#                  Average Reward for last 333 steps: 83.084084
#                  Average Reward for all steps: 82.907186
#                  Epsilon: 0.02000000000082877, Frames Total :27691
#                  Solved 2 Times
#
# 			 *** Episode 666 at Total Seconds 70.434417***
#                  Average Reward for last 333 steps: 105.663664
#                  Average Reward for all steps: 94.268366
#                  Epsilon: 0.02, Frames Total :62877
#                  Solved 7 Times
#
# 			 *** Episode 999 at Total Seconds 114.035835***
#                  Average Reward for last 333 steps: 120.633634
#                  Average Reward for all steps: 103.048000
#                  Epsilon: 0.02, Frames Total :103048
#                  Solved 9 Times
#
#
#               Last 200 Episode Average for Agent TLN_0.05_0.9_0.02_128_0_0: 103.99
#
#         ***Testing Agent TLN***
#         learning_rate = 0.05,
#         gamma = 0.9,
#         egreedy_final = 0.02,
#         hidden_layer = 256,
#         batch_size = 0,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 36.394873***
#                  Average Reward for last 333 steps: 98.507508
#                  Average Reward for all steps: 98.257485
#                  Epsilon: 0.02000000000000492, Frames Total :32818
#                  Solved 4 Times
#
# 			 *** Episode 666 at Total Seconds 73.556499***
#                  Average Reward for last 333 steps: 99.558559
#                  Average Reward for all steps: 98.907046
#                  Epsilon: 0.02, Frames Total :65971
#                  Solved 7 Times
#
# 			 *** Episode 999 at Total Seconds 107.946424***
#                  Average Reward for last 333 steps: 92.249249
#                  Average Reward for all steps: 96.690000
#                  Epsilon: 0.02, Frames Total :96690
#                  Solved 9 Times
#
#
#               Last 200 Episode Average for Agent TLN_0.05_0.9_0.02_256_0_0: 114.395
#
#         ***Testing Agent TLN***
#         learning_rate = 0.05,
#         gamma = 0.9,
#         egreedy_final = 0.02,
#         hidden_layer = 64,
#         batch_size = 0,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 30.791641***
#                  Average Reward for last 333 steps: 83.207207
#                  Average Reward for all steps: 83.011976
#                  Epsilon: 0.020000000000800267, Frames Total :27726
#                  Solved 14 Times
#
# 			 *** Episode 666 at Total Seconds 78.686922***
#                  Average Reward for last 333 steps: 130.333333
#                  Average Reward for all steps: 106.637181
#                  Epsilon: 0.02, Frames Total :71127
#                  Solved 27 Times
#
# 			 *** Episode 999 at Total Seconds 123.799891***
#                  Average Reward for last 333 steps: 122.267267
#                  Average Reward for all steps: 111.842000
#                  Epsilon: 0.02, Frames Total :111842
#                  Solved 30 Times
#
#
#               Last 200 Episode Average for Agent TLN_0.05_0.9_0.02_64_0_0: 116.67
#
#         ***Testing Agent TLN***
#         learning_rate = 0.05,
#         gamma = 0.9,
#         egreedy_final = 0.02,
#         hidden_layer = 128,
#         batch_size = 0,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 14.968213***
#                  Average Reward for last 333 steps: 40.195195
#                  Average Reward for all steps: 40.134731
#                  Epsilon: 0.020001326676823434, Frames Total :13405
#                  Solved 2 Times
#
# 			 *** Episode 666 at Total Seconds 47.413283***
#                  Average Reward for last 333 steps: 88.882883
#                  Average Reward for all steps: 64.472264
#                  Epsilon: 0.02, Frames Total :43003
#                  Solved 10 Times
#
# 			 *** Episode 999 at Total Seconds 102.231441***
#                  Average Reward for last 333 steps: 149.474474
#                  Average Reward for all steps: 92.778000
#                  Epsilon: 0.02, Frames Total :92778
#                  Solved 30 Times
#
#
#               Last 200 Episode Average for Agent TLN_0.05_0.9_0.02_128_0_0: 170.27
#
#         ***Testing Agent TLN***
#         learning_rate = 0.05,
#         gamma = 0.9,
#         egreedy_final = 0.02,
#         hidden_layer = 256,
#         batch_size = 0,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 18.282195***
#                  Average Reward for last 333 steps: 48.651652
#                  Average Reward for all steps: 48.532934
#                  Epsilon: 0.020000080272930976, Frames Total :16210
#                  Solved 0 Times
#
# 			 *** Episode 666 at Total Seconds 63.220465***
#                  Average Reward for last 333 steps: 122.114114
#                  Average Reward for all steps: 85.268366
#                  Epsilon: 0.02, Frames Total :56874
#                  Solved 2 Times
#
# 			 *** Episode 999 at Total Seconds 120.456618***
#                  Average Reward for last 333 steps: 156.348348
#                  Average Reward for all steps: 108.938000
#                  Epsilon: 0.02, Frames Total :108938
#                  Solved 26 Times
#
#
#               Last 200 Episode Average for Agent TLN_0.05_0.9_0.02_256_0_0: 157.095
#
#         ***Testing Agent TLN***
#         learning_rate = 0.05,
#         gamma = 0.95,
#         egreedy_final = 0.02,
#         hidden_layer = 64,
#         batch_size = 0,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 44.596740***
#                  Average Reward for last 333 steps: 120.456456
#                  Average Reward for all steps: 120.155689
#                  Epsilon: 0.020000000000000004, Frames Total :40132
#                  Solved 10 Times
#
# 			 *** Episode 666 at Total Seconds 87.732983***
#                  Average Reward for last 333 steps: 117.591592
#                  Average Reward for all steps: 118.875562
#                  Epsilon: 0.02, Frames Total :79290
#                  Solved 13 Times
#
# 			 *** Episode 999 at Total Seconds 126.193172***
#                  Average Reward for last 333 steps: 105.219219
#                  Average Reward for all steps: 114.328000
#                  Epsilon: 0.02, Frames Total :114328
#                  Solved 26 Times
#
#
#               Last 200 Episode Average for Agent TLN_0.05_0.95_0.02_64_0_0: 71.315
#
#         ***Testing Agent TLN***
#         learning_rate = 0.05,
#         gamma = 0.95,
#         egreedy_final = 0.02,
#         hidden_layer = 128,
#         batch_size = 0,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 27.614343***
#                  Average Reward for last 333 steps: 74.642643
#                  Average Reward for all steps: 74.455090
#                  Epsilon: 0.02000000001394593, Frames Total :24868
#                  Solved 10 Times
#
# 			 *** Episode 666 at Total Seconds 66.874111***
#                  Average Reward for last 333 steps: 107.339339
#                  Average Reward for all steps: 90.872564
#                  Epsilon: 0.02, Frames Total :60612
#                  Solved 22 Times
# 			 *** Episode 999 at Total Seconds 109.381424***
#                  Average Reward for last 333 steps: 118.972973
#                  Average Reward for all steps: 100.230000
#                  Epsilon: 0.02, Frames Total :100230
#                  Solved 29 Times
#
#
#               Last 200 Episode Average for Agent TLN_0.05_0.95_0.02_128_0_0: 135.855
#
#         ***Testing Agent TLN***
#         learning_rate = 0.05,
#         gamma = 0.95,
#         egreedy_final = 0.02,
#         hidden_layer = 256,
#         batch_size = 0,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 46.262820***
#                  Average Reward for last 333 steps: 126.078078
#                  Average Reward for all steps: 125.796407
#                  Epsilon: 0.02, Frames Total :42016
#                  Solved 14 Times
#
# 			 *** Episode 666 at Total Seconds 99.604991***
#                  Average Reward for last 333 steps: 145.771772
#                  Average Reward for all steps: 135.769115
#                  Epsilon: 0.02, Frames Total :90558
#                  Solved 36 Times
#
# 			 *** Episode 999 at Total Seconds 143.857231***
#                  Average Reward for last 333 steps: 120.210210
#                  Average Reward for all steps: 130.588000
#                  Epsilon: 0.02, Frames Total :130588
#                  Solved 51 Times
#
#
#               Last 200 Episode Average for Agent TLN_0.05_0.95_0.02_256_0_0: 106.305
#
#         ***Testing Agent TLN***
#         learning_rate = 0.05,
#         gamma = 0.95,
#         egreedy_final = 0.02,
#         hidden_layer = 64,
#         batch_size = 0,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 34.576907***
#                  Average Reward for last 333 steps: 94.870871
#                  Average Reward for all steps: 94.730539
#                  Epsilon: 0.020000000000015974, Frames Total :31640
#                  Solved 4 Times
#
# 			 *** Episode 666 at Total Seconds 83.775333***
#                  Average Reward for last 333 steps: 134.534535
#                  Average Reward for all steps: 114.602699
#                  Epsilon: 0.02, Frames Total :76440
#                  Solved 16 Times
#
# 			 *** Episode 999 at Total Seconds 145.607744***
#                  Average Reward for last 333 steps: 168.993994
#                  Average Reward for all steps: 132.715000
#                  Epsilon: 0.02, Frames Total :132715
#                  Solved 56 Times
#
#
#               Last 200 Episode Average for Agent TLN_0.05_0.95_0.02_64_0_0: 189.585
#
#         ***Testing Agent TLN***
#         learning_rate = 0.05,
#         gamma = 0.95,
#         egreedy_final = 0.02,
#         hidden_layer = 128,
#         batch_size = 0,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 18.867918***
#                  Average Reward for last 333 steps: 50.876877
#                  Average Reward for all steps: 50.769461
#                  Epsilon: 0.02000003803217323, Frames Total :16957
#                  Solved 7 Times
#
# 			 *** Episode 666 at Total Seconds 38.476017***
#                  Average Reward for last 333 steps: 52.009009
#                  Average Reward for all steps: 51.388306
#                  Epsilon: 0.020000000000001145, Frames Total :34276
#                  Solved 11 Times
#
# 			 *** Episode 999 at Total Seconds 79.344410***
#                  Average Reward for last 333 steps: 111.381381
#                  Average Reward for all steps: 71.366000
#                  Epsilon: 0.02, Frames Total :71366
#                  Solved 25 Times
#
#
#               Last 200 Episode Average for Agent TLN_0.05_0.95_0.02_128_0_0: 85.31
#
#         ***Testing Agent TLN***
#         learning_rate = 0.05,
#         gamma = 0.95,
#         egreedy_final = 0.02,
#         hidden_layer = 256,
#         batch_size = 0,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 20.957116***
#                  Average Reward for last 333 steps: 56.396396
#                  Average Reward for all steps: 56.296407
#                  Epsilon: 0.020000006004039336, Frames Total :18803
#                  Solved 1 Times
#
# 			 *** Episode 666 at Total Seconds 68.093379***
#                  Average Reward for last 333 steps: 128.093093
#                  Average Reward for all steps: 92.140930
#                  Epsilon: 0.02, Frames Total :61458
#                  Solved 5 Times
#
# 			 *** Episode 999 at Total Seconds 118.322001***
#                  Average Reward for last 333 steps: 136.702703
#                  Average Reward for all steps: 106.980000
#                  Epsilon: 0.02, Frames Total :106980
#                  Solved 12 Times
#
#
#               Last 200 Episode Average for Agent TLN_0.05_0.95_0.02_256_0_0: 134.355
#
#         ***Testing Agent TLN***
#         learning_rate = 0.05,
#         gamma = 0.995,
#         egreedy_final = 0.02,
#         hidden_layer = 64,
#         batch_size = 0,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 36.709882***
#                  Average Reward for last 333 steps: 100.567568
#                  Average Reward for all steps: 100.356287
#                  Epsilon: 0.02000000000000244, Frames Total :33519
#                  Solved 7 Times
#
# 			 *** Episode 666 at Total Seconds 84.946490***
#                  Average Reward for last 333 steps: 130.453453
#                  Average Reward for all steps: 115.382309
#                  Epsilon: 0.02, Frames Total :76960
#                  Solved 17 Times
#
# 			 *** Episode 999 at Total Seconds 118.745944***
#                  Average Reward for last 333 steps: 91.876877
#                  Average Reward for all steps: 107.555000
# ...
#                  Epsilon: 0.02, Frames Total :111581
#                  Solved 33 Times
#
#
#               Last 200 Episode Average for Agent TLN_0.01_0.9_0.02_64_0_0: 130.89
#
#         ***Testing Agent TLN***
#         learning_rate = 0.01,
#         gamma = 0.9,
#         egreedy_final = 0.02,
#         hidden_layer = 128,
#         batch_size = 0,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 26.964917***
#                  Average Reward for last 333 steps: 71.930931
#                  Average Reward for all steps: 71.814371
#                  Epsilon: 0.02000000003368955, Frames Total :23986
#                  Solved 6 Times
#
# 			 *** Episode 666 at Total Seconds 73.289533***
#                  Average Reward for last 333 steps: 126.315315
#                  Average Reward for all steps: 99.023988
#                  Epsilon: 0.02, Frames Total :66049
#                  Solved 19 Times
#
# 			 *** Episode 999 at Total Seconds 127.304987***
#                  Average Reward for last 333 steps: 145.906907
#                  Average Reward for all steps: 114.636000
#                  Epsilon: 0.02, Frames Total :114636
#                  Solved 28 Times
#
#
#               Last 200 Episode Average for Agent TLN_0.01_0.9_0.02_128_0_0: 157.52
#
#         ***Testing Agent TLN***
#         learning_rate = 0.01,
#         gamma = 0.9,
#         egreedy_final = 0.02,
#         hidden_layer = 256,
#         batch_size = 0,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 43.178354***
#                  Average Reward for last 333 steps: 116.714715
#                  Average Reward for all steps: 116.395210
#                  Epsilon: 0.02000000000000001, Frames Total :38876
#                  Solved 9 Times
#
# 			 *** Episode 666 at Total Seconds 89.572555***
#                  Average Reward for last 333 steps: 125.945946
#                  Average Reward for all steps: 121.163418
#                  Epsilon: 0.02, Frames Total :80816
#                  Solved 17 Times
#
# 			 *** Episode 999 at Total Seconds 150.381170***
#                  Average Reward for last 333 steps: 162.807808
#                  Average Reward for all steps: 135.031000
#                  Epsilon: 0.02, Frames Total :135031
#                  Solved 35 Times
#
#
#               Last 200 Episode Average for Agent TLN_0.01_0.9_0.02_256_0_0: 182.325
#
#         ***Testing Agent TLN***
#         learning_rate = 0.01,
#         gamma = 0.95,
#         egreedy_final = 0.02,
#         hidden_layer = 64,
#         batch_size = 0,
#         update_target_frequency = 0
# 			 *** Episode 333 at Total Seconds 44.533927***
#                  Average Reward for last 333 steps: 119.573574
#                  Average Reward for all steps: 119.287425
#                  Epsilon: 0.020000000000000004, Frames Total :39842
#                  Solved 13 Times
#
# 			 *** Episode 666 at Total Seconds 96.561617***
#                  Average Reward for last 333 steps: 139.213213
#                  Average Reward for all steps: 129.235382
#                  Epsilon: 0.02, Frames Total :86200
#                  Solved 32 Times
#
# 			 *** Episode 999 at Total Seconds 132.242112***
#                  Average Reward for last 333 steps: 96.837838
#                  Average Reward for all steps: 118.447000
#                  Epsilon: 0.02, Frames Total :118447
#                  Solved 33 Times
#
#
#               Last 200 Episode Average for Agent TLN_0.01_0.95_0.02_64_0_0: 102.64
#
#         ***Testing Agent TLN***
#         learning_rate = 0.01,
#         gamma = 0.95,
#         egreedy_final = 0.02,
#         hidden_layer = 128,
#         batch_size = 0,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 52.048592***
#                  Average Reward for last 333 steps: 141.786787
#                  Average Reward for all steps: 141.416168
#                  Epsilon: 0.02, Frames Total :47233
#                  Solved 28 Times
#
# 			 *** Episode 666 at Total Seconds 97.948971***
#                  Average Reward for last 333 steps: 124.786787
#                  Average Reward for all steps: 133.113943
#                  Epsilon: 0.02, Frames Total :88787
#                  Solved 35 Times
#
# 			 *** Episode 999 at Total Seconds 144.304013***
#                  Average Reward for last 333 steps: 126.192192
#                  Average Reward for all steps: 130.809000
#                  Epsilon: 0.02, Frames Total :130809
#                  Solved 42 Times
#
#
#               Last 200 Episode Average for Agent TLN_0.01_0.95_0.02_128_0_0: 133.75
#
#         ***Testing Agent TLN***
#         learning_rate = 0.01,
#         gamma = 0.95,
#         egreedy_final = 0.02,
#         hidden_layer = 256,
#         batch_size = 0,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 31.609038***
#                  Average Reward for last 333 steps: 85.198198
#                  Average Reward for all steps: 84.979042
#                  Epsilon: 0.02000000000041486, Frames Total :28383
#                  Solved 9 Times
#
# 			 *** Episode 666 at Total Seconds 91.086410***
#                  Average Reward for last 333 steps: 164.081081
#                  Average Reward for all steps: 124.470765
#                  Epsilon: 0.02, Frames Total :83022
#                  Solved 35 Times
#
# 			 *** Episode 999 at Total Seconds 139.312523***
#                  Average Reward for last 333 steps: 131.414414
#                  Average Reward for all steps: 126.783000
#                  Epsilon: 0.02, Frames Total :126783
#                  Solved 41 Times
#
#
#               Last 200 Episode Average for Agent TLN_0.01_0.95_0.02_256_0_0: 123.085
#
#         ***Testing Agent TLN***
#         learning_rate = 0.01,
#         gamma = 0.95,
#         egreedy_final = 0.02,
#         hidden_layer = 64,
#         batch_size = 0,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 43.033207***
#                  Average Reward for last 333 steps: 117.321321
#                  Average Reward for all steps: 117.008982
#                  Epsilon: 0.02000000000000001, Frames Total :39081
#                  Solved 12 Times
#
# 			 *** Episode 666 at Total Seconds 84.971305***
#                  Average Reward for last 333 steps: 116.126126
#                  Average Reward for all steps: 116.568216
#                  Epsilon: 0.02, Frames Total :77751
#                  Solved 18 Times
#
# 			 *** Episode 999 at Total Seconds 116.852875***
#                  Average Reward for last 333 steps: 86.639640
#                  Average Reward for all steps: 106.602000
#                  Epsilon: 0.02, Frames Total :106602
#                  Solved 23 Times
#
#
#               Last 200 Episode Average for Agent TLN_0.01_0.95_0.02_64_0_0: 72.64
#
#         ***Testing Agent TLN***
#         learning_rate = 0.01,
#         gamma = 0.95,
#         egreedy_final = 0.02,
#         hidden_layer = 128,
#         batch_size = 0,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 40.203012***
#                  Average Reward for last 333 steps: 109.351351
#                  Average Reward for all steps: 109.053892
#                  Epsilon: 0.020000000000000136, Frames Total :36424
#                  Solved 2 Times
#
# 			 *** Episode 666 at Total Seconds 88.475372***
#                  Average Reward for last 333 steps: 131.348348
#                  Average Reward for all steps: 120.184408
#                  Epsilon: 0.02, Frames Total :80163
#                  Solved 10 Times
#
# 			 *** Episode 999 at Total Seconds 128.600511***
#                  Average Reward for last 333 steps: 108.663664
#                  Average Reward for all steps: 116.348000
#                  Epsilon: 0.02, Frames Total :116348
#                  Solved 10 Times
#
#
#               Last 200 Episode Average for Agent TLN_0.01_0.95_0.02_128_0_0: 116.295
#
#         ***Testing Agent TLN***
#         learning_rate = 0.01,
#         gamma = 0.95,
#         egreedy_final = 0.02,
#         hidden_layer = 256,
#         batch_size = 0,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 43.012905***
#                  Average Reward for last 333 steps: 117.087087
#                  Average Reward for all steps: 116.784431
#                  Epsilon: 0.02000000000000001, Frames Total :39006
#                  Solved 9 Times
#
# 			 *** Episode 666 at Total Seconds 81.624120***
#                  Average Reward for last 333 steps: 104.009009
#                  Average Reward for all steps: 110.406297
#                  Epsilon: 0.02, Frames Total :73641
#                  Solved 11 Times
#
# 			 *** Episode 999 at Total Seconds 132.845083***
#                  Average Reward for last 333 steps: 139.723724
#                  Average Reward for all steps: 120.169000
#                  Epsilon: 0.02, Frames Total :120169
#                  Solved 18 Times
#
#
#               Last 200 Episode Average for Agent TLN_0.01_0.95_0.02_256_0_0: 133.145
#
#         ***Testing Agent TLN***
#         learning_rate = 0.01,
#         gamma = 0.995,
#         egreedy_final = 0.02,
#         hidden_layer = 64,
#         batch_size = 0,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 42.875428***
#                  Average Reward for last 333 steps: 116.615616
#                  Average Reward for all steps: 116.335329
#                  Epsilon: 0.02000000000000001, Frames Total :38856
#                  Solved 8 Times
#
# 			 *** Episode 666 at Total Seconds 83.334668***
#                  Average Reward for last 333 steps: 110.063063
#                  Average Reward for all steps: 113.203898
#                  Epsilon: 0.02, Frames Total :75507
#                  Solved 20 Times
#
# 			 *** Episode 999 at Total Seconds 130.559469***
#                  Average Reward for last 333 steps: 128.663664
#                  Average Reward for all steps: 118.352000
#                  Epsilon: 0.02, Frames Total :118352
#                  Solved 35 Times
#
#
#               Last 200 Episode Average for Agent TLN_0.01_0.995_0.02_64_0_0: 146.435
#
#         ***Testing Agent TLN***
#         learning_rate = 0.01,
#         gamma = 0.995,
#         egreedy_final = 0.02,
#         hidden_layer = 128,
#         batch_size = 0,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 39.586055***
#                  Average Reward for last 333 steps: 107.744745
#                  Average Reward for all steps: 107.458084
#                  Epsilon: 0.02000000000000023, Frames Total :35891
#                  Solved 5 Times
#
# 			 *** Episode 666 at Total Seconds 73.810620***
#                  Average Reward for last 333 steps: 92.591592
#                  Average Reward for all steps: 100.035982
#                  Epsilon: 0.02, Frames Total :66724
#                  Solved 7 Times
# 			 *** Episode 999 at Total Seconds 113.068181***
#                  Average Reward for last 333 steps: 106.471471
#                  Average Reward for all steps: 102.179000
#                  Epsilon: 0.02, Frames Total :102179
#                  Solved 18 Times
#
#
#               Last 200 Episode Average for Agent TLN_0.01_0.995_0.02_128_0_0: 122.425
#
#         ***Testing Agent TLN***
#         learning_rate = 0.01,
#         gamma = 0.995,
#         egreedy_final = 0.02,
#         hidden_layer = 256,
#         batch_size = 0,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 33.641068***
#                  Average Reward for last 333 steps: 89.984985
#                  Average Reward for all steps: 89.748503
#                  Epsilon: 0.020000000000084346, Frames Total :29976
#                  Solved 1 Times
#
# 			 *** Episode 666 at Total Seconds 85.110404***
#                  Average Reward for last 333 steps: 140.696697
#                  Average Reward for all steps: 115.184408
#                  Epsilon: 0.02, Frames Total :76828
#                  Solved 21 Times
#
# 			 *** Episode 999 at Total Seconds 130.204598***
#                  Average Reward for last 333 steps: 123.135135
#                  Average Reward for all steps: 117.832000
#                  Epsilon: 0.02, Frames Total :117832
#                  Solved 35 Times
#
#
#               Last 200 Episode Average for Agent TLN_0.01_0.995_0.02_256_0_0: 98.8
#
#         ***Testing Agent TLN***
#         learning_rate = 0.01,
#         gamma = 0.995,
#         egreedy_final = 0.02,
#         hidden_layer = 64,
#         batch_size = 0,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 37.310852***
#                  Average Reward for last 333 steps: 102.114114
#                  Average Reward for all steps: 101.844311
#                  Epsilon: 0.020000000000001485, Frames Total :34016
#                  Solved 15 Times
#
# 			 *** Episode 666 at Total Seconds 84.854881***
#                  Average Reward for last 333 steps: 128.267267
#                  Average Reward for all steps: 115.035982
#                  Epsilon: 0.02, Frames Total :76729
#                  Solved 23 Times
#
# 			 *** Episode 999 at Total Seconds 123.595364***
#                  Average Reward for last 333 steps: 104.030030
#                  Average Reward for all steps: 111.371000
#                  Epsilon: 0.02, Frames Total :111371
#                  Solved 24 Times
#
#
#               Last 200 Episode Average for Agent TLN_0.01_0.995_0.02_64_0_0: 108.635
#
#         ***Testing Agent TLN***
#         learning_rate = 0.01,
#         gamma = 0.995,
#         egreedy_final = 0.02,
#         hidden_layer = 128,
#         batch_size = 0,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 27.562634***
#                  Average Reward for last 333 steps: 75.186186
#                  Average Reward for all steps: 75.000000
#                  Epsilon: 0.020000000011625347, Frames Total :25050
#                  Solved 1 Times
#
# 			 *** Episode 666 at Total Seconds 70.732870***
#                  Average Reward for last 333 steps: 116.804805
#                  Average Reward for all steps: 95.871064
#                  Epsilon: 0.02, Frames Total :63946
#                  Solved 2 Times
#
# 			 *** Episode 999 at Total Seconds 127.460974***
#                  Average Reward for last 333 steps: 155.099099
#                  Average Reward for all steps: 115.594000
#                  Epsilon: 0.02, Frames Total :115594
#                  Solved 10 Times
#
#
#               Last 200 Episode Average for Agent TLN_0.01_0.995_0.02_128_0_0: 169.74
#
#         ***Testing Agent TLN***
#         learning_rate = 0.01,
#         gamma = 0.995,
#         egreedy_final = 0.02,
#         hidden_layer = 256,
#         batch_size = 0,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 32.786221***
#                  Average Reward for last 333 steps: 89.432432
#                  Average Reward for all steps: 89.197605
#                  Epsilon: 0.020000000000101388, Frames Total :29792
#                  Solved 11 Times
#
# 			 *** Episode 666 at Total Seconds 68.598058***
#                  Average Reward for last 333 steps: 96.573574
#                  Average Reward for all steps: 92.880060
#                  Epsilon: 0.02, Frames Total :61951
#                  Solved 12 Times
#
# 			 *** Episode 999 at Total Seconds 91.623154***
#                  Average Reward for last 333 steps: 61.297297
#                  Average Reward for all steps: 82.363000
#                  Epsilon: 0.02, Frames Total :82363
#                  Solved 15 Times
#
#
#               Last 200 Episode Average for Agent TLN_0.01_0.995_0.02_256_0_0: 34.505
# /n/nTLN_0.1_0.9_0.02_64_0_0 is the best of the test

# %% [markdown]
# ## Experience Replay Network

# %% [markdown]
# ### TLN - ERN Differences
#
# <br>
# <strong>According to the paper <span style="text-decoration:underline">Playing Atari with Deep Reinforcement Learning</span>, two main problems arise from simple neural nets in RL problems. First, there is a delay between action and rewards; these problems are thus "particularly daunting when compared to the direct association between inputs and targets found in supervised learning." Second, "most deep
# learning algorithms assume the data samples to be independent, while in reinforcement learning one
# typically encounters sequences of highly correlated states." In other words, the data distributions are non stationary.<br><br>
# Deep Mind's solution to this problem was to use: "an experience replay mechanism which randomly samples previous transitions, and thereby smooths the training distribution over many past behaviors." These samples are taken in batches, not sequentially.</strong>
#
# <img src="./DQN.png">
#
# <br>
# <strong>In terms of our Pytorch Algorithm, This will involve two major improvements:
# 1. The addition of the Experience Replay Class
# 1. Pushing all memory inside of tensors</strong>

# %% [markdown]
# ### Experience Replay Class

# %%
class ExperienceReplay(object):
    def __init__(self, capacity):
        self.capacity = capacity
        self.memory = []
        self.position = 0
     
    #Now Training is batches to avoid the clustering and oversampling
    #Of past training
    def push(self, state, action, new_state, reward, done):
        transition = (state, action, new_state, reward, done)
        
        #Checks to see if memory ready to be filled
        if self.position >= len(self.memory):
            self.memory.append(transition)
        else:
            #Overwriting exisiting memory if overfilled
            self.memory[self.position] = transition
        
        self.position = ( self.position + 1 ) % self.capacity
        
        
    def sample(self, batch_size):
        #aggregates elements based on iterables, here it is making
        #batches of experiences, using random sampling
        return zip(*random.sample(self.memory, batch_size))
        
    
    #Verify Memory size
    def __len__(self):
        return len(self.memory)

# %% [markdown]
# ### New Optimize Function

# %% [markdown]
# <strong>The ExperienceReplay function is carrying a lot of the sampling transition for learning, thus a significant update is necessary for our optimize function</strong>

# %%
#Instead of feeding the optimize function all of the state information
#We will sample if from memory
def mem_optimize(self):

    #If memory is smaller than batch size, we will not run the program
    if (len(memory) < batch_size):
        return

    #Changing the batch_size signifantly effects our outputs.
    state, action, new_state, reward, done = memory.sample(batch_size)

    #Feed in the states into the network
    state = Tensor(state).to(device)
    new_state = Tensor(new_state).to(device)
    reward = Tensor(reward).to(device)
    
    #We are going to need 64-bit integer tensors since we 
    #Are using them as indicies, hence the LongTensor instead of the float
    action = LongTensor(action).to(device)
    done = Tensor(done).to(device)

    new_state_values = self.nn(new_state).detach()
    #Only want the max of the index
    max_new_state_values = torch.max(new_state_values, 1)[0]
    
    #If the episode is done, we are only going to want to reward values
    #Hence, the (1 - done) to zero out the gamma and state max
    target_value = reward + ( 1 - done ) * gamma * max_new_state_values

    #We have to make sure the dimensions match, hence the unsqueeze
    #gather takes the right values from the Neural Net
    predicted_value = self.nn(state).gather(1, action.unsqueeze(1)).squeeze(1)

    loss = self.loss_func(predicted_value, target_value)

    self.optimizer.zero_grad()
    loss.backward()
    self.optimizer.step()

# %% [markdown]
# ### ERN Class

# %%
class ERN(object):
    def __init__(self, Agent, label):
        self.nn = NeuralNetwork_2().to(device)
        self.name = label
        
        self.loss_func = nn.MSELoss()
        #self.loss_func = nn.SmoothL1Loss()
        
        self.optimizer = optim.Adam(params=self.nn.parameters(), lr=learning_rate)
        #self.optimizer = optim.RMSprop(params=mynn.parameters(), lr=learning_rate)
        
setattr(ERN, "calculate_epsilon", calculate_epsilon)
setattr(ERN, "select_action", select_action)
setattr(ERN, "optimize", mem_optimize)

# %% [markdown]
# ### ERN Parameters

# %%
mem = True
#New Parameters added, memory size and batch elements
replay_mem_size = 500_000
batch_size = 32

# %% [markdown]
# ### Simulating ERN

# %%
memory = ExperienceReplay(replay_mem_size)

record = simulation(1000, "ERN","ERN_1", record, 333)
plot_agent(record, "TLN_1")
# Out:
# 			 *** Episode 333 at Total Seconds 175.445992***
#                  Average Reward for last 333 steps: 421.756757
#                  Average Reward for all steps: 420.694611
#                  Epsilon: 0.02, Frames Total :140512
#                  Solved 240 Times
#
# 			 *** Episode 666 at Total Seconds 372.876455***
#                  Average Reward for last 333 steps: 468.843844
#                  Average Reward for all steps: 444.733133
#                  Epsilon: 0.02, Frames Total :296637
#                  Solved 533 Times
#
# 			 *** Episode 999 at Total Seconds 571.115269***
#                  Average Reward for last 333 steps: 461.465465
#                  Average Reward for all steps: 450.305000
#                  Epsilon: 0.02, Frames Total :450305
#                  Solved 818 Times

# %% [markdown]
# ### HyperTunning ERN

# %%
hyper = {
    "learning_rate" :          [0.1, .01],
    "gamma":                   [.85, 0.995],
    "egreedy_final":           [.02, 0.02], 
    "hidden_layer":            [256],
    "batch_size":              [32, 64],
    "update_target_frequency": [0],}

record = hyper_and_beyond(hyper, record, "ERN", knobs = knobs)
# Out:
#         ***Testing Agent ERN***
#         learning_rate = 0.1,
#         gamma = 0.85,
#         egreedy_final = 0.02,
#         hidden_layer = 64,
#         batch_size = 32,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 105.143164***
#                  Average Reward for last 333 steps: 255.450450
#                  Average Reward for all steps: 254.739521
#                  Epsilon: 0.02, Frames Total :85083
#                  Solved 110 Times
#
# 			 *** Episode 666 at Total Seconds 188.335983***
#                  Average Reward for last 333 steps: 198.240240
#                  Average Reward for all steps: 226.532234
#                  Epsilon: 0.02, Frames Total :151097
#                  Solved 155 Times
#
# 			 *** Episode 999 at Total Seconds 237.925882***
#                  Average Reward for last 333 steps: 120.390390
#                  Average Reward for all steps: 191.187000
#                  Epsilon: 0.02, Frames Total :191187
#                  Solved 165 Times
#
#
#               Last 200 Episode Average for Agent ERN_0.1_0.85_0.02_64_32_0: 137.44
#
#         ***Testing Agent ERN***
#         learning_rate = 0.1,
#         gamma = 0.85,
#         egreedy_final = 0.02,
#         hidden_layer = 64,
#         batch_size = 64,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 105.723244***
#                  Average Reward for last 333 steps: 251.768769
#                  Average Reward for all steps: 251.074850
#                  Epsilon: 0.02, Frames Total :83859
#                  Solved 100 Times
#
# 			 *** Episode 666 at Total Seconds 158.728099***
#                  Average Reward for last 333 steps: 126.003003
#                  Average Reward for all steps: 188.632684
#                  Epsilon: 0.02, Frames Total :125818
#                  Solved 132 Times
#
# 			 *** Episode 999 at Total Seconds 259.540837***
#                  Average Reward for last 333 steps: 239.126126
#                  Average Reward for all steps: 205.447000
#                  Epsilon: 0.02, Frames Total :205447
#                  Solved 198 Times
#
#
#               Last 200 Episode Average for Agent ERN_0.1_0.85_0.02_64_64_0: 189.455
#
#         ***Testing Agent ERN***
#         learning_rate = 0.1,
#         gamma = 0.85,
#         egreedy_final = 0.02,
#         hidden_layer = 64,
#         batch_size = 128,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 94.274540***
#                  Average Reward for last 333 steps: 225.432432
#                  Average Reward for all steps: 224.907186
#                  Epsilon: 0.02, Frames Total :75119
#                  Solved 99 Times
#
# 			 *** Episode 666 at Total Seconds 217.904443***
#                  Average Reward for last 333 steps: 297.483483
#                  Average Reward for all steps: 261.140930
#                  Epsilon: 0.02, Frames Total :174181
#                  Solved 198 Times
#
# 			 *** Episode 999 at Total Seconds 276.939595***
#                  Average Reward for last 333 steps: 140.363363
#                  Average Reward for all steps: 220.922000
#                  Epsilon: 0.02, Frames Total :220922
#                  Solved 214 Times
#
#
#               Last 200 Episode Average for Agent ERN_0.1_0.85_0.02_64_128_0: 110.56
#
#         ***Testing Agent ERN***
#         learning_rate = 0.1,
#         gamma = 0.85,
#         egreedy_final = 0.02,
#         hidden_layer = 128,
#         batch_size = 32,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 108.671025***
#                  Average Reward for last 333 steps: 258.555556
#                  Average Reward for all steps: 257.859281
#                  Epsilon: 0.02, Frames Total :86125
#                  Solved 112 Times
#
# 			 *** Episode 666 at Total Seconds 216.470744***
#                  Average Reward for last 333 steps: 255.807808
#                  Average Reward for all steps: 256.835082
#                  Epsilon: 0.02, Frames Total :171309
#                  Solved 186 Times
#
# 			 *** Episode 999 at Total Seconds 260.927945***
#                  Average Reward for last 333 steps: 103.678679
#                  Average Reward for all steps: 205.834000
#                  Epsilon: 0.02, Frames Total :205834
#                  Solved 192 Times
#
#
#               Last 200 Episode Average for Agent ERN_0.1_0.85_0.02_128_32_0: 89.235
#
#         ***Testing Agent ERN***
#         learning_rate = 0.1,
#         gamma = 0.85,
#         egreedy_final = 0.02,
#         hidden_layer = 128,
#         batch_size = 64,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 99.514838***
#                  Average Reward for last 333 steps: 238.147147
#                  Average Reward for all steps: 237.491018
#                  Epsilon: 0.02, Frames Total :79322
#                  Solved 104 Times
#
# 			 *** Episode 666 at Total Seconds 171.650368***
#                  Average Reward for last 333 steps: 176.282282
#                  Average Reward for all steps: 206.932534
#                  Epsilon: 0.02, Frames Total :138024
#                  Solved 128 Times
#
# 			 *** Episode 999 at Total Seconds 199.606496***
#                  Average Reward for last 333 steps: 64.735736
#                  Average Reward for all steps: 159.581000
#                  Epsilon: 0.02, Frames Total :159581
#                  Solved 128 Times
#
#
#               Last 200 Episode Average for Agent ERN_0.1_0.85_0.02_128_64_0: 46.06
#
#         ***Testing Agent ERN***
#         learning_rate = 0.1,
#         gamma = 0.85,
#         egreedy_final = 0.02,
#         hidden_layer = 128,
#         batch_size = 128,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 113.131083***
#                  Average Reward for last 333 steps: 270.132132
#                  Average Reward for all steps: 269.350299
#                  Epsilon: 0.02, Frames Total :89963
#                  Solved 120 Times
#
# 			 *** Episode 666 at Total Seconds 208.305012***
#                  Average Reward for last 333 steps: 228.183183
#                  Average Reward for all steps: 248.797601
#                  Epsilon: 0.02, Frames Total :165948
#                  Solved 177 Times
#
# 			 *** Episode 999 at Total Seconds 238.431656***
#                  Average Reward for last 333 steps: 70.129129
#                  Average Reward for all steps: 189.301000
#                  Epsilon: 0.02, Frames Total :189301
#                  Solved 178 Times
#
#
#               Last 200 Episode Average for Agent ERN_0.1_0.85_0.02_128_128_0: 46.34
#
#         ***Testing Agent ERN***
#         learning_rate = 0.1,
#         gamma = 0.85,
#         egreedy_final = 0.02,
#         hidden_layer = 256,
#         batch_size = 32,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 103.665340***
#                  Average Reward for last 333 steps: 248.123123
#                  Average Reward for all steps: 247.443114
#                  Epsilon: 0.02, Frames Total :82646
#                  Solved 108 Times
#
# 			 *** Episode 666 at Total Seconds 184.958745***
#                  Average Reward for last 333 steps: 197.285285
#                  Average Reward for all steps: 222.401799
#                  Epsilon: 0.02, Frames Total :148342
#                  Solved 153 Times
#
# 			 *** Episode 999 at Total Seconds 230.351942***
#                  Average Reward for last 333 steps: 107.234234
#                  Average Reward for all steps: 184.051000
#                  Epsilon: 0.02, Frames Total :184051
#                  Solved 156 Times
#
#
#               Last 200 Episode Average for Agent ERN_0.1_0.85_0.02_256_32_0: 84.825
#
#         ***Testing Agent ERN***
#         learning_rate = 0.1,
#         gamma = 0.85,
#         egreedy_final = 0.02,
#         hidden_layer = 256,
#         batch_size = 64,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 126.489070***
#                  Average Reward for last 333 steps: 302.240240
#                  Average Reward for all steps: 301.371257
#                  Epsilon: 0.02, Frames Total :100658
#                  Solved 114 Times
# 			 *** Episode 666 at Total Seconds 181.237869***
#                  Average Reward for last 333 steps: 128.555556
#                  Average Reward for all steps: 215.092954
#                  Epsilon: 0.02, Frames Total :143467
#                  Solved 122 Times
#
# 			 *** Episode 999 at Total Seconds 203.894189***
#                  Average Reward for last 333 steps: 52.237237
#                  Average Reward for all steps: 160.862000
#                  Epsilon: 0.02, Frames Total :160862
#                  Solved 122 Times
#
#
#               Last 200 Episode Average for Agent ERN_0.1_0.85_0.02_256_64_0: 56.21
#
#         ***Testing Agent ERN***
#         learning_rate = 0.1,
#         gamma = 0.85,
#         egreedy_final = 0.02,
#         hidden_layer = 256,
#         batch_size = 128,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 100.590395***
#                  Average Reward for last 333 steps: 238.468468
#                  Average Reward for all steps: 237.820359
#                  Epsilon: 0.02, Frames Total :79432
#                  Solved 97 Times
#
# 			 *** Episode 666 at Total Seconds 197.191926***
#                  Average Reward for last 333 steps: 229.324324
#                  Average Reward for all steps: 233.578711
#                  Epsilon: 0.02, Frames Total :155797
#                  Solved 159 Times
#
# 			 *** Episode 999 at Total Seconds 228.200138***
#                  Average Reward for last 333 steps: 72.447447
#                  Average Reward for all steps: 179.922000
#                  Epsilon: 0.02, Frames Total :179922
#                  Solved 161 Times
#
#
#               Last 200 Episode Average for Agent ERN_0.1_0.85_0.02_256_128_0: 45.43
#
#         ***Testing Agent ERN***
#         learning_rate = 0.1,
#         gamma = 0.85,
#         egreedy_final = 0.02,
#         hidden_layer = 64,
#         batch_size = 32,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 105.970101***
#                  Average Reward for last 333 steps: 252.801802
#                  Average Reward for all steps: 252.095808
#                  Epsilon: 0.02, Frames Total :84200
#                  Solved 106 Times
#
# 			 *** Episode 666 at Total Seconds 206.472912***
#                  Average Reward for last 333 steps: 237.906907
#                  Average Reward for all steps: 245.011994
#                  Epsilon: 0.02, Frames Total :163423
#                  Solved 175 Times
#
# 			 *** Episode 999 at Total Seconds 226.765630***
#                  Average Reward for last 333 steps: 46.432432
#                  Average Reward for all steps: 178.885000
#                  Epsilon: 0.02, Frames Total :178885
#                  Solved 175 Times
#
#
#               Last 200 Episode Average for Agent ERN_0.1_0.85_0.02_64_32_0: 41.11
#
#         ***Testing Agent ERN***
#         learning_rate = 0.1,
#         gamma = 0.85,
#         egreedy_final = 0.02,
#         hidden_layer = 64,
#         batch_size = 64,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 110.427632***
#                  Average Reward for last 333 steps: 263.405405
#                  Average Reward for all steps: 262.769461
#                  Epsilon: 0.02, Frames Total :87765
#                  Solved 97 Times
#
# 			 *** Episode 666 at Total Seconds 201.125535***
#                  Average Reward for last 333 steps: 216.288288
#                  Average Reward for all steps: 239.563718
#                  Epsilon: 0.02, Frames Total :159789
#                  Solved 135 Times
#
# 			 *** Episode 999 at Total Seconds 249.720226***
#                  Average Reward for last 333 steps: 113.423423
#                  Average Reward for all steps: 197.559000
#                  Epsilon: 0.02, Frames Total :197559
#                  Solved 145 Times
#
#
#               Last 200 Episode Average for Agent ERN_0.1_0.85_0.02_64_64_0: 75.57
#
#         ***Testing Agent ERN***
#         learning_rate = 0.1,
#         gamma = 0.85,
#         egreedy_final = 0.02,
#         hidden_layer = 64,
#         batch_size = 128,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 119.905171***
#                  Average Reward for last 333 steps: 285.534535
#                  Average Reward for all steps: 284.715569
#                  Epsilon: 0.02, Frames Total :95095
#                  Solved 129 Times
#
# 			 *** Episode 666 at Total Seconds 205.027103***
#                  Average Reward for last 333 steps: 203.840841
#                  Average Reward for all steps: 244.338831
#                  Epsilon: 0.02, Frames Total :162974
#                  Solved 183 Times
#
# 			 *** Episode 999 at Total Seconds 236.231714***
#                  Average Reward for last 333 steps: 73.297297
#                  Average Reward for all steps: 187.382000
#                  Epsilon: 0.02, Frames Total :187382
#                  Solved 184 Times
#
#
#               Last 200 Episode Average for Agent ERN_0.1_0.85_0.02_64_128_0: 86.105
#
#         ***Testing Agent ERN***
#         learning_rate = 0.1,
#         gamma = 0.85,
#         egreedy_final = 0.02,
#         hidden_layer = 128,
#         batch_size = 32,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 86.539737***
#                  Average Reward for last 333 steps: 202.981982
#                  Average Reward for all steps: 202.416168
#                  Epsilon: 0.02, Frames Total :67607
#                  Solved 82 Times
#
# 			 *** Episode 666 at Total Seconds 205.678074***
#                  Average Reward for last 333 steps: 284.003003
#                  Average Reward for all steps: 243.148426
#                  Epsilon: 0.02, Frames Total :162180
#                  Solved 182 Times
#
# 			 *** Episode 999 at Total Seconds 252.791663***
#                  Average Reward for last 333 steps: 111.546547
#                  Average Reward for all steps: 199.325000
#                  Epsilon: 0.02, Frames Total :199325
#                  Solved 190 Times
#
#
#               Last 200 Episode Average for Agent ERN_0.1_0.85_0.02_128_32_0: 73.88
#
#         ***Testing Agent ERN***
#         learning_rate = 0.1,
#         gamma = 0.85,
#         egreedy_final = 0.02,
#         hidden_layer = 128,
#         batch_size = 64,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 115.303000***
#                  Average Reward for last 333 steps: 273.345345
#                  Average Reward for all steps: 272.577844
#                  Epsilon: 0.02, Frames Total :91041
#                  Solved 108 Times
#
# 			 *** Episode 666 at Total Seconds 210.423565***
#                  Average Reward for last 333 steps: 225.762763
#                  Average Reward for all steps: 249.205397
#                  Epsilon: 0.02, Frames Total :166220
#                  Solved 171 Times
#
# 			 *** Episode 999 at Total Seconds 243.187932***
#                  Average Reward for last 333 steps: 76.486486
#                  Average Reward for all steps: 191.690000
#                  Epsilon: 0.02, Frames Total :191690
#                  Solved 171 Times
#
#
#               Last 200 Episode Average for Agent ERN_0.1_0.85_0.02_128_64_0: 89.135
#
#         ***Testing Agent ERN***
#         learning_rate = 0.1,
#         gamma = 0.85,
#         egreedy_final = 0.02,
#         hidden_layer = 128,
#         batch_size = 128,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 115.540196***
#                  Average Reward for last 333 steps: 275.525526
#                  Average Reward for all steps: 274.787425
#                  Epsilon: 0.02, Frames Total :91779
#                  Solved 112 Times
#
# 			 *** Episode 666 at Total Seconds 198.689116***
#                  Average Reward for last 333 steps: 197.921922
#                  Average Reward for all steps: 236.412294
#                  Epsilon: 0.02, Frames Total :157687
#                  Solved 174 Times
#
# 			 *** Episode 999 at Total Seconds 227.457170***
#                  Average Reward for last 333 steps: 67.981982
#                  Average Reward for all steps: 180.325000
#                  Epsilon: 0.02, Frames Total :180325
#                  Solved 175 Times
#
#
#               Last 200 Episode Average for Agent ERN_0.1_0.85_0.02_128_128_0: 54.995
#
#         ***Testing Agent ERN***
#         learning_rate = 0.1,
#         gamma = 0.85,
#         egreedy_final = 0.02,
#         hidden_layer = 256,
#         batch_size = 32,
#         update_target_frequency = 0
# 			 *** Episode 333 at Total Seconds 99.964926***
#                  Average Reward for last 333 steps: 238.315315
#                  Average Reward for all steps: 237.670659
#                  Epsilon: 0.02, Frames Total :79382
#                  Solved 86 Times
#
# 			 *** Episode 666 at Total Seconds 227.186357***
#                  Average Reward for last 333 steps: 302.120120
#                  Average Reward for all steps: 269.847076
#                  Epsilon: 0.02, Frames Total :179988
#                  Solved 195 Times
#
# 			 *** Episode 999 at Total Seconds 287.402549***
#                  Average Reward for last 333 steps: 142.690691
#                  Average Reward for all steps: 227.504000
#                  Epsilon: 0.02, Frames Total :227504
#                  Solved 207 Times
#
#
#               Last 200 Episode Average for Agent ERN_0.1_0.85_0.02_256_32_0: 111.12
#
#         ***Testing Agent ERN***
#         learning_rate = 0.1,
#         gamma = 0.85,
#         egreedy_final = 0.02,
#         hidden_layer = 256,
#         batch_size = 64,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 98.193285***
#                  Average Reward for last 333 steps: 234.096096
#                  Average Reward for all steps: 233.491018
#                  Epsilon: 0.02, Frames Total :77986
#                  Solved 98 Times
#
# 			 *** Episode 666 at Total Seconds 199.506681***
#                  Average Reward for last 333 steps: 239.459459
#                  Average Reward for all steps: 236.470765
#                  Epsilon: 0.02, Frames Total :157726
#                  Solved 162 Times
#
# 			 *** Episode 999 at Total Seconds 260.350544***
#                  Average Reward for last 333 steps: 143.294294
#                  Average Reward for all steps: 205.443000
#                  Epsilon: 0.02, Frames Total :205443
#                  Solved 178 Times
#
#
#               Last 200 Episode Average for Agent ERN_0.1_0.85_0.02_256_64_0: 104.035
#
#         ***Testing Agent ERN***
#         learning_rate = 0.1,
#         gamma = 0.85,
#         egreedy_final = 0.02,
#         hidden_layer = 256,
#         batch_size = 128,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 93.338102***
#                  Average Reward for last 333 steps: 222.231231
#                  Average Reward for all steps: 221.649701
#                  Epsilon: 0.02, Frames Total :74031
#                  Solved 87 Times
#
# 			 *** Episode 666 at Total Seconds 195.996110***
#                  Average Reward for last 333 steps: 244.036036
#                  Average Reward for all steps: 232.826087
#                  Epsilon: 0.02, Frames Total :155295
#                  Solved 172 Times
#
# 			 *** Episode 999 at Total Seconds 237.704105***
#                  Average Reward for last 333 steps: 98.609610
#                  Average Reward for all steps: 188.132000
#                  Epsilon: 0.02, Frames Total :188132
#                  Solved 179 Times
#
#
#               Last 200 Episode Average for Agent ERN_0.1_0.85_0.02_256_128_0: 55.2
#
#         ***Testing Agent ERN***
#         learning_rate = 0.1,
#         gamma = 0.9,
#         egreedy_final = 0.02,
#         hidden_layer = 64,
#         batch_size = 32,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 111.763340***
#                  Average Reward for last 333 steps: 268.933934
#                  Average Reward for all steps: 268.218563
#                  Epsilon: 0.02, Frames Total :89585
#                  Solved 117 Times
#
# 			 *** Episode 666 at Total Seconds 202.412865***
#                  Average Reward for last 333 steps: 213.237237
#                  Average Reward for all steps: 240.769115
#                  Epsilon: 0.02, Frames Total :160593
#                  Solved 158 Times
#
# 			 *** Episode 999 at Total Seconds 270.626949***
#                  Average Reward for last 333 steps: 160.783784
#                  Average Reward for all steps: 214.134000
#                  Epsilon: 0.02, Frames Total :214134
#                  Solved 190 Times
#
#
#               Last 200 Episode Average for Agent ERN_0.1_0.9_0.02_64_32_0: 113.4
#
#         ***Testing Agent ERN***
#         learning_rate = 0.1,
#         gamma = 0.9,
#         egreedy_final = 0.02,
#         hidden_layer = 64,
#         batch_size = 64,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 113.422639***
#                  Average Reward for last 333 steps: 269.639640
#                  Average Reward for all steps: 268.877246
#                  Epsilon: 0.02, Frames Total :89805
#                  Solved 103 Times
#
# 			 *** Episode 666 at Total Seconds 196.131817***
#                  Average Reward for last 333 steps: 197.096096
#                  Average Reward for all steps: 233.040480
#                  Epsilon: 0.02, Frames Total :155438
#                  Solved 146 Times
#
# 			 *** Episode 999 at Total Seconds 246.493937***
#                  Average Reward for last 333 steps: 120.330330
#                  Average Reward for all steps: 195.508000
#                  Epsilon: 0.02, Frames Total :195508
#                  Solved 150 Times
#
#
#               Last 200 Episode Average for Agent ERN_0.1_0.9_0.02_64_64_0: 107.515
#
#         ***Testing Agent ERN***
#         learning_rate = 0.1,
#         gamma = 0.9,
#         egreedy_final = 0.02,
#         hidden_layer = 64,
#         batch_size = 128,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 127.406336***
#                  Average Reward for last 333 steps: 302.462462
#                  Average Reward for all steps: 301.598802
#                  Epsilon: 0.02, Frames Total :100734
#                  Solved 130 Times
#
# 			 *** Episode 666 at Total Seconds 212.287230***
#                  Average Reward for last 333 steps: 201.843844
#                  Average Reward for all steps: 251.796102
#                  Epsilon: 0.02, Frames Total :167948
#                  Solved 177 Times
#
# 			 *** Episode 999 at Total Seconds 233.790060***
#                  Average Reward for last 333 steps: 49.753754
#                  Average Reward for all steps: 184.516000
#                  Epsilon: 0.02, Frames Total :184516
#                  Solved 177 Times
#
#
#               Last 200 Episode Average for Agent ERN_0.1_0.9_0.02_64_128_0: 33.39
#
#         ***Testing Agent ERN***
#         learning_rate = 0.1,
#         gamma = 0.9,
#         egreedy_final = 0.02,
#         hidden_layer = 128,
#         batch_size = 32,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 128.107962***
#                  Average Reward for last 333 steps: 303.321321
#                  Average Reward for all steps: 302.541916
#                  Epsilon: 0.02, Frames Total :101049
#                  Solved 140 Times
#
# 			 *** Episode 666 at Total Seconds 201.451708***
#                  Average Reward for last 333 steps: 175.081081
#                  Average Reward for all steps: 238.907046
#                  Epsilon: 0.02, Frames Total :159351
#                  Solved 180 Times
#
# 			 *** Episode 999 at Total Seconds 241.925599***
#                  Average Reward for last 333 steps: 96.339339
#                  Average Reward for all steps: 191.432000
#                  Epsilon: 0.02, Frames Total :191432
#                  Solved 182 Times
#
#
#               Last 200 Episode Average for Agent ERN_0.1_0.9_0.02_128_32_0: 83.83
#
#         ***Testing Agent ERN***
#         learning_rate = 0.1,
#         gamma = 0.9,
#         egreedy_final = 0.02,
#         hidden_layer = 128,
#         batch_size = 64,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 116.031063***
#                  Average Reward for last 333 steps: 276.885886
#                  Average Reward for all steps: 276.137725
#                  Epsilon: 0.02, Frames Total :92230
#                  Solved 128 Times
#
# 			 *** Episode 666 at Total Seconds 215.284727***
#                  Average Reward for last 333 steps: 237.189189
#                  Average Reward for all steps: 256.692654
#                  Epsilon: 0.02, Frames Total :171214
#                  Solved 201 Times
# 			 *** Episode 999 at Total Seconds 239.054040***
#                  Average Reward for last 333 steps: 54.579580
#                  Average Reward for all steps: 189.389000
#                  Epsilon: 0.02, Frames Total :189389
#                  Solved 202 Times
#
#
#               Last 200 Episode Average for Agent ERN_0.1_0.9_0.02_128_64_0: 46.105
#
#         ***Testing Agent ERN***
#         learning_rate = 0.1,
#         gamma = 0.9,
#         egreedy_final = 0.02,
#         hidden_layer = 128,
#         batch_size = 128,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 97.541964***
#                  Average Reward for last 333 steps: 231.051051
#                  Average Reward for all steps: 230.428144
#                  Epsilon: 0.02, Frames Total :76963
#                  Solved 79 Times
#
# 			 *** Episode 666 at Total Seconds 188.875017***
#                  Average Reward for last 333 steps: 217.183183
#                  Average Reward for all steps: 223.815592
#                  Epsilon: 0.02, Frames Total :149285
#                  Solved 134 Times
#
# 			 *** Episode 999 at Total Seconds 217.091114***
#                  Average Reward for last 333 steps: 64.780781
#                  Average Reward for all steps: 170.857000
#                  Epsilon: 0.02, Frames Total :170857
#                  Solved 134 Times
#
#
#               Last 200 Episode Average for Agent ERN_0.1_0.9_0.02_128_128_0: 69.655
#
#         ***Testing Agent ERN***
#         learning_rate = 0.1,
#         gamma = 0.9,
#         egreedy_final = 0.02,
#         hidden_layer = 256,
#         batch_size = 32,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 55.834084***
#                  Average Reward for last 333 steps: 132.042042
#                  Average Reward for all steps: 131.691617
#                  Epsilon: 0.02, Frames Total :43985
#                  Solved 43 Times
#
# 			 *** Episode 666 at Total Seconds 147.891330***
#                  Average Reward for last 333 steps: 220.534535
#                  Average Reward for all steps: 176.046477
#                  Epsilon: 0.02, Frames Total :117423
#                  Solved 97 Times
#
# 			 *** Episode 999 at Total Seconds 174.640624***
#                  Average Reward for last 333 steps: 62.756757
#                  Average Reward for all steps: 138.321000
#                  Epsilon: 0.02, Frames Total :138321
#                  Solved 97 Times
#
#
#               Last 200 Episode Average for Agent ERN_0.1_0.9_0.02_256_32_0: 52.885
#
#         ***Testing Agent ERN***
#         learning_rate = 0.1,
#         gamma = 0.9,
#         egreedy_final = 0.02,
#         hidden_layer = 256,
#         batch_size = 64,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 48.071573***
#                  Average Reward for last 333 steps: 113.468468
#                  Average Reward for all steps: 113.173653
#                  Epsilon: 0.020000000000000035, Frames Total :37800
#                  Solved 29 Times
#
# 			 *** Episode 666 at Total Seconds 173.990005***
#                  Average Reward for last 333 steps: 299.390390
#                  Average Reward for all steps: 206.142429
#                  Epsilon: 0.02, Frames Total :137497
#                  Solved 145 Times
#
# 			 *** Episode 999 at Total Seconds 217.178535***
#                  Average Reward for last 333 steps: 101.666667
#                  Average Reward for all steps: 171.352000
#                  Epsilon: 0.02, Frames Total :171352
#                  Solved 146 Times
#
#
#               Last 200 Episode Average for Agent ERN_0.1_0.9_0.02_256_64_0: 78.05
#
#         ***Testing Agent ERN***
#         learning_rate = 0.1,
#         gamma = 0.9,
#         egreedy_final = 0.02,
#         hidden_layer = 256,
#         batch_size = 128,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 111.213142***
#                  Average Reward for last 333 steps: 266.204204
#                  Average Reward for all steps: 265.446108
#                  Epsilon: 0.02, Frames Total :88659
#                  Solved 109 Times
#
# 			 *** Episode 666 at Total Seconds 233.281083***
#                  Average Reward for last 333 steps: 290.867868
#                  Average Reward for all steps: 278.137931
#                  Epsilon: 0.02, Frames Total :185518
#                  Solved 224 Times
#
# 			 *** Episode 999 at Total Seconds 286.958191***
#                  Average Reward for last 333 steps: 127.300300
#                  Average Reward for all steps: 227.909000
#                  Epsilon: 0.02, Frames Total :227909
#                  Solved 234 Times
#
#
#               Last 200 Episode Average for Agent ERN_0.1_0.9_0.02_256_128_0: 124.255
#
#         ***Testing Agent ERN***
#         learning_rate = 0.1,
#         gamma = 0.9,
#         egreedy_final = 0.02,
#         hidden_layer = 64,
#         batch_size = 32,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 107.205446***
#                  Average Reward for last 333 steps: 254.261261
#                  Average Reward for all steps: 253.544910
#                  Epsilon: 0.02, Frames Total :84684
#                  Solved 107 Times
#
# 			 *** Episode 666 at Total Seconds 205.604191***
#                  Average Reward for last 333 steps: 232.240240
#                  Average Reward for all steps: 242.908546
#                  Epsilon: 0.02, Frames Total :162020
#                  Solved 172 Times
#
# 			 *** Episode 999 at Total Seconds 238.974324***
#                  Average Reward for last 333 steps: 78.288288
#                  Average Reward for all steps: 188.090000
#                  Epsilon: 0.02, Frames Total :188090
#                  Solved 172 Times
#
#
#               Last 200 Episode Average for Agent ERN_0.1_0.9_0.02_64_32_0: 65.77
#
#         ***Testing Agent ERN***
#         learning_rate = 0.1,
#         gamma = 0.9,
#         egreedy_final = 0.02,
#         hidden_layer = 64,
#         batch_size = 64,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 41.171653***
#                  Average Reward for last 333 steps: 98.492492
#                  Average Reward for all steps: 98.251497
#                  Epsilon: 0.020000000000004927, Frames Total :32816
#                  Solved 23 Times
#
# 			 *** Episode 666 at Total Seconds 170.368196***
#                  Average Reward for last 333 steps: 308.597598
#                  Average Reward for all steps: 203.266867
#                  Epsilon: 0.02, Frames Total :135579
#                  Solved 153 Times
#
# 			 *** Episode 999 at Total Seconds 240.280433***
#                  Average Reward for last 333 steps: 167.351351
#                  Average Reward for all steps: 191.307000
#                  Epsilon: 0.02, Frames Total :191307
#                  Solved 175 Times
#
#
#               Last 200 Episode Average for Agent ERN_0.1_0.9_0.02_64_64_0: 155.645
#
#         ***Testing Agent ERN***
#         learning_rate = 0.1,
#         gamma = 0.9,
#         egreedy_final = 0.02,
#         hidden_layer = 64,
#         batch_size = 128,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 87.184331***
#                  Average Reward for last 333 steps: 208.549550
#                  Average Reward for all steps: 207.961078
#                  Epsilon: 0.02, Frames Total :69459
#                  Solved 72 Times
#
# 			 *** Episode 666 at Total Seconds 189.748092***
#                  Average Reward for last 333 steps: 244.816817
#                  Average Reward for all steps: 226.361319
#                  Epsilon: 0.02, Frames Total :150983
#                  Solved 145 Times
#
# 			 *** Episode 999 at Total Seconds 232.598891***
#                  Average Reward for last 333 steps: 100.456456
#                  Average Reward for all steps: 184.435000
#                  Epsilon: 0.02, Frames Total :184435
#                  Solved 150 Times
#
#
#               Last 200 Episode Average for Agent ERN_0.1_0.9_0.02_64_128_0: 69.205
#
#         ***Testing Agent ERN***
#         learning_rate = 0.1,
#         gamma = 0.9,
#         egreedy_final = 0.02,
#         hidden_layer = 128,
#         batch_size = 32,
#         update_target_frequency = 0
# 			 *** Episode 333 at Total Seconds 105.424072***
#                  Average Reward for last 333 steps: 250.501502
#                  Average Reward for all steps: 249.784431
#                  Epsilon: 0.02, Frames Total :83428
#                  Solved 99 Times
#
# 			 *** Episode 666 at Total Seconds 208.911865***
#                  Average Reward for last 333 steps: 247.048048
#                  Average Reward for all steps: 248.418291
#                  Epsilon: 0.02, Frames Total :165695
#                  Solved 173 Times
#
# 			 *** Episode 999 at Total Seconds 258.957557***
#                  Average Reward for last 333 steps: 117.825826
#                  Average Reward for all steps: 204.931000
#                  Epsilon: 0.02, Frames Total :204931
#                  Solved 177 Times
#
#
#               Last 200 Episode Average for Agent ERN_0.1_0.9_0.02_128_32_0: 97.075
#
#         ***Testing Agent ERN***
#         learning_rate = 0.1,
#         gamma = 0.9,
#         egreedy_final = 0.02,
#         hidden_layer = 128,
#         batch_size = 64,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 101.930938***
#                  Average Reward for last 333 steps: 240.339339
#                  Average Reward for all steps: 239.664671
#                  Epsilon: 0.02, Frames Total :80048
#                  Solved 105 Times
#
# 			 *** Episode 666 at Total Seconds 204.453319***
#                  Average Reward for last 333 steps: 245.054054
#                  Average Reward for all steps: 242.355322
#                  Epsilon: 0.02, Frames Total :161651
#                  Solved 177 Times
#
# 			 *** Episode 999 at Total Seconds 255.807822***
#                  Average Reward for last 333 steps: 123.033033
#                  Average Reward for all steps: 202.621000
#                  Epsilon: 0.02, Frames Total :202621
#                  Solved 186 Times
#
#
#               Last 200 Episode Average for Agent ERN_0.1_0.9_0.02_128_64_0: 108.835
#
#         ***Testing Agent ERN***
#         learning_rate = 0.1,
#         gamma = 0.9,
#         egreedy_final = 0.02,
#         hidden_layer = 128,
#         batch_size = 128,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 116.647371***
#                  Average Reward for last 333 steps: 277.408408
#                  Average Reward for all steps: 276.613772
#                  Epsilon: 0.02, Frames Total :92389
#                  Solved 115 Times
#
# 			 *** Episode 666 at Total Seconds 198.053953***
#                  Average Reward for last 333 steps: 192.705706
#                  Average Reward for all steps: 234.722639
#                  Epsilon: 0.02, Frames Total :156560
#                  Solved 155 Times
#
# 			 *** Episode 999 at Total Seconds 246.837466***
#                  Average Reward for last 333 steps: 114.912913
#                  Average Reward for all steps: 194.826000
#                  Epsilon: 0.02, Frames Total :194826
#                  Solved 157 Times
#
#
#               Last 200 Episode Average for Agent ERN_0.1_0.9_0.02_128_128_0: 103.41
#
#         ***Testing Agent ERN***
#         learning_rate = 0.1,
#         gamma = 0.9,
#         egreedy_final = 0.02,
#         hidden_layer = 256,
#         batch_size = 32,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 130.220228***
#                  Average Reward for last 333 steps: 308.429429
#                  Average Reward for all steps: 307.592814
#                  Epsilon: 0.02, Frames Total :102736
#                  Solved 142 Times
#
# 			 *** Episode 666 at Total Seconds 217.600832***
#                  Average Reward for last 333 steps: 207.996997
#                  Average Reward for all steps: 257.869565
#                  Epsilon: 0.02, Frames Total :171999
#                  Solved 191 Times
#
# 			 *** Episode 999 at Total Seconds 265.555326***
#                  Average Reward for last 333 steps: 112.081081
#                  Average Reward for all steps: 209.322000
#                  Epsilon: 0.02, Frames Total :209322
#                  Solved 197 Times
#
#
#               Last 200 Episode Average for Agent ERN_0.1_0.9_0.02_256_32_0: 130.855
#
#         ***Testing Agent ERN***
#         learning_rate = 0.1,
#         gamma = 0.9,
#         egreedy_final = 0.02,
#         hidden_layer = 256,
#         batch_size = 64,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 77.692973***
#                  Average Reward for last 333 steps: 183.606607
#                  Average Reward for all steps: 183.113772
#                  Epsilon: 0.02, Frames Total :61160
#                  Solved 69 Times
#
# 			 *** Episode 666 at Total Seconds 186.256589***
#                  Average Reward for last 333 steps: 257.057057
#                  Average Reward for all steps: 220.029985
#                  Epsilon: 0.02, Frames Total :146760
#                  Solved 143 Times
#
# 			 *** Episode 999 at Total Seconds 222.334217***
#                  Average Reward for last 333 steps: 84.642643
#                  Average Reward for all steps: 174.946000
#                  Epsilon: 0.02, Frames Total :174946
#                  Solved 143 Times
#
#
#               Last 200 Episode Average for Agent ERN_0.1_0.9_0.02_256_64_0: 58.405
#
#         ***Testing Agent ERN***
#         learning_rate = 0.1,
#         gamma = 0.9,
#         egreedy_final = 0.02,
#         hidden_layer = 256,
#         batch_size = 128,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 109.570944***
#                  Average Reward for last 333 steps: 260.687688
#                  Average Reward for all steps: 259.952096
#                  Epsilon: 0.02, Frames Total :86824
#                  Solved 113 Times
#
# 			 *** Episode 666 at Total Seconds 167.613053***
#                  Average Reward for last 333 steps: 136.861862
#                  Average Reward for all steps: 198.499250
#                  Epsilon: 0.02, Frames Total :132399
#                  Solved 130 Times
#
# 			 *** Episode 999 at Total Seconds 188.692589***
#                  Average Reward for last 333 steps: 48.555556
#                  Average Reward for all steps: 148.568000
#                  Epsilon: 0.02, Frames Total :148568
#                  Solved 130 Times
#
#
#               Last 200 Episode Average for Agent ERN_0.1_0.9_0.02_256_128_0: 46.35
#
#         ***Testing Agent ERN***
#         learning_rate = 0.1,
#         gamma = 0.95,
#         egreedy_final = 0.02,
#         hidden_layer = 64,
#         batch_size = 32,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 107.505891***
#                  Average Reward for last 333 steps: 255.132132
#                  Average Reward for all steps: 254.422156
#                  Epsilon: 0.02, Frames Total :84977
#                  Solved 130 Times
#
# 			 *** Episode 666 at Total Seconds 207.239933***
#                  Average Reward for last 333 steps: 236.240240
#                  Average Reward for all steps: 245.344828
#                  Epsilon: 0.02, Frames Total :163645
#                  Solved 195 Times
#
# 			 *** Episode 999 at Total Seconds 233.321220***
#                  Average Reward for last 333 steps: 60.555556
#                  Average Reward for all steps: 183.810000
#                  Epsilon: 0.02, Frames Total :183810
#                  Solved 195 Times
#
#
#               Last 200 Episode Average for Agent ERN_0.1_0.95_0.02_64_32_0: 56.635
#
#         ***Testing Agent ERN***
#         learning_rate = 0.1,
#         gamma = 0.95,
#         egreedy_final = 0.02,
#         hidden_layer = 64,
#         batch_size = 64,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 76.882766***
#                  Average Reward for last 333 steps: 181.366366
#                  Average Reward for all steps: 180.943114
#                  Epsilon: 0.02, Frames Total :60435
#                  Solved 49 Times
#
# 			 *** Episode 666 at Total Seconds 135.681103***
#                  Average Reward for last 333 steps: 138.843844
#                  Average Reward for all steps: 159.925037
#                  Epsilon: 0.02, Frames Total :106670
#                  Solved 68 Times
# 			 *** Episode 999 at Total Seconds 177.198489***
#                  Average Reward for last 333 steps: 97.051051
#                  Average Reward for all steps: 138.988000
#                  Epsilon: 0.02, Frames Total :138988
#                  Solved 70 Times
#
#
#               Last 200 Episode Average for Agent ERN_0.1_0.95_0.02_64_64_0: 91.44
#
#         ***Testing Agent ERN***
#         learning_rate = 0.1,
#         gamma = 0.95,
#         egreedy_final = 0.02,
#         hidden_layer = 64,
#         batch_size = 128,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 117.201987***
#                  Average Reward for last 333 steps: 278.666667
#                  Average Reward for all steps: 277.895210
#                  Epsilon: 0.02, Frames Total :92817
#                  Solved 124 Times
#
# 			 *** Episode 666 at Total Seconds 227.462803***
#                  Average Reward for last 333 steps: 261.879880
#                  Average Reward for all steps: 269.899550
#                  Epsilon: 0.02, Frames Total :180023
#                  Solved 200 Times
#
# 			 *** Episode 999 at Total Seconds 255.431576***
#                  Average Reward for last 333 steps: 65.093093
#                  Average Reward for all steps: 201.699000
#                  Epsilon: 0.02, Frames Total :201699
#                  Solved 200 Times
#
#
#               Last 200 Episode Average for Agent ERN_0.1_0.95_0.02_64_128_0: 41.345
#
#         ***Testing Agent ERN***
#         learning_rate = 0.1,
#         gamma = 0.95,
#         egreedy_final = 0.02,
#         hidden_layer = 128,
#         batch_size = 32,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 97.988703***
#                  Average Reward for last 333 steps: 234.174174
#                  Average Reward for all steps: 233.601796
#                  Epsilon: 0.02, Frames Total :78023
#                  Solved 104 Times
#
# 			 *** Episode 666 at Total Seconds 202.212719***
#                  Average Reward for last 333 steps: 247.900901
#                  Average Reward for all steps: 240.740630
#                  Epsilon: 0.02, Frames Total :160574
#                  Solved 181 Times
#
# 			 *** Episode 999 at Total Seconds 243.023435***
#                  Average Reward for last 333 steps: 95.369369
#                  Average Reward for all steps: 192.332000
#                  Epsilon: 0.02, Frames Total :192332
#                  Solved 192 Times
#
#
#               Last 200 Episode Average for Agent ERN_0.1_0.95_0.02_128_32_0: 62.67
#
#         ***Testing Agent ERN***
#         learning_rate = 0.1,
#         gamma = 0.95,
#         egreedy_final = 0.02,
#         hidden_layer = 128,
#         batch_size = 64,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 111.384730***
#                  Average Reward for last 333 steps: 268.507508
#                  Average Reward for all steps: 267.754491
#                  Epsilon: 0.02, Frames Total :89430
#                  Solved 112 Times
#
# 			 *** Episode 666 at Total Seconds 203.243095***
#                  Average Reward for last 333 steps: 217.684685
#                  Average Reward for all steps: 242.757121
#                  Epsilon: 0.02, Frames Total :161919
#                  Solved 161 Times
#
# 			 *** Episode 999 at Total Seconds 235.493383***
#                  Average Reward for last 333 steps: 74.453453
#                  Average Reward for all steps: 186.712000
#                  Epsilon: 0.02, Frames Total :186712
#                  Solved 168 Times
#
#
#               Last 200 Episode Average for Agent ERN_0.1_0.95_0.02_128_64_0: 51.3
#
#         ***Testing Agent ERN***
#         learning_rate = 0.1,
#         gamma = 0.95,
#         egreedy_final = 0.02,
#         hidden_layer = 128,
#         batch_size = 128,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 82.301121***
#                  Average Reward for last 333 steps: 195.684685
#                  Average Reward for all steps: 195.185629
#                  Epsilon: 0.02, Frames Total :65192
#                  Solved 71 Times
#
# 			 *** Episode 666 at Total Seconds 191.373441***
#                  Average Reward for last 333 steps: 258.447447
#                  Average Reward for all steps: 226.769115
#                  Epsilon: 0.02, Frames Total :151255
#                  Solved 139 Times
#
# 			 *** Episode 999 at Total Seconds 236.876336***
#                  Average Reward for last 333 steps: 107.933934
#                  Average Reward for all steps: 187.197000
#                  Epsilon: 0.02, Frames Total :187197
#                  Solved 142 Times
#
#
#               Last 200 Episode Average for Agent ERN_0.1_0.95_0.02_128_128_0: 67.185
#
#         ***Testing Agent ERN***
#         learning_rate = 0.1,
#         gamma = 0.95,
#         egreedy_final = 0.02,
#         hidden_layer = 256,
#         batch_size = 32,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 96.100925***
#                  Average Reward for last 333 steps: 229.018018
#                  Average Reward for all steps: 228.488024
#                  Epsilon: 0.02, Frames Total :76315
#                  Solved 92 Times
#
# 			 *** Episode 666 at Total Seconds 180.187377***
#                  Average Reward for last 333 steps: 199.828829
#                  Average Reward for all steps: 214.179910
#                  Epsilon: 0.02, Frames Total :142858
#                  Solved 140 Times
#
# 			 *** Episode 999 at Total Seconds 209.026429***
#                  Average Reward for last 333 steps: 66.777778
#                  Average Reward for all steps: 165.095000
#                  Epsilon: 0.02, Frames Total :165095
#                  Solved 141 Times
#
#
#               Last 200 Episode Average for Agent ERN_0.1_0.95_0.02_256_32_0: 64.675
#
#         ***Testing Agent ERN***
#         learning_rate = 0.1,
# ...
#
#
#               Last 200 Episode Average for Agent ERN_0.05_0.85_0.02_64_64_0: 52.69
#
#         ***Testing Agent ERN***
#         learning_rate = 0.05,
#         gamma = 0.85,
#         egreedy_final = 0.02,
#         hidden_layer = 64,
#         batch_size = 128,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 134.702414***
#                  Average Reward for last 333 steps: 257.390390
#                  Average Reward for all steps: 256.691617
#                  Epsilon: 0.02, Frames Total :85735
#                  Solved 120 Times
#
# 			 *** Episode 666 at Total Seconds 255.511972***
#                  Average Reward for last 333 steps: 214.570571
#                  Average Reward for all steps: 235.662669
#                  Epsilon: 0.02, Frames Total :157187
#                  Solved 164 Times
#
# 			 *** Episode 999 at Total Seconds 296.269839***
#                  Average Reward for last 333 steps: 65.396396
#                  Average Reward for all steps: 178.964000
#                  Epsilon: 0.02, Frames Total :178964
#                  Solved 166 Times
#
#
#               Last 200 Episode Average for Agent ERN_0.05_0.85_0.02_64_128_0: 38.19
#
#         ***Testing Agent ERN***
#         learning_rate = 0.05,
#         gamma = 0.85,
#         egreedy_final = 0.02,
#         hidden_layer = 128,
#         batch_size = 32,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 182.029806***
#                  Average Reward for last 333 steps: 295.777778
#                  Average Reward for all steps: 294.925150
#                  Epsilon: 0.02, Frames Total :98505
#                  Solved 123 Times
#
# 			 *** Episode 666 at Total Seconds 311.163905***
#                  Average Reward for last 333 steps: 218.699700
#                  Average Reward for all steps: 256.869565
#                  Epsilon: 0.02, Frames Total :171332
#                  Solved 176 Times
#
# 			 *** Episode 999 at Total Seconds 343.502994***
#                  Average Reward for last 333 steps: 50.267267
#                  Average Reward for all steps: 188.071000
#                  Epsilon: 0.02, Frames Total :188071
#                  Solved 176 Times
#
#
#               Last 200 Episode Average for Agent ERN_0.05_0.85_0.02_128_32_0: 47.74
#
#         ***Testing Agent ERN***
#         learning_rate = 0.05,
#         gamma = 0.85,
#         egreedy_final = 0.02,
#         hidden_layer = 128,
#         batch_size = 64,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 143.055810***
#                  Average Reward for last 333 steps: 230.270270
#                  Average Reward for all steps: 229.643713
#                  Epsilon: 0.02, Frames Total :76701
#                  Solved 92 Times
#
# 			 *** Episode 666 at Total Seconds 255.976280***
#                  Average Reward for last 333 steps: 191.381381
#                  Average Reward for all steps: 210.541229
#                  Epsilon: 0.02, Frames Total :140431
#                  Solved 140 Times
#
# 			 *** Episode 999 at Total Seconds 303.029100***
#                  Average Reward for last 333 steps: 73.066066
#                  Average Reward for all steps: 164.762000
#                  Epsilon: 0.02, Frames Total :164762
#                  Solved 141 Times
#
#
#               Last 200 Episode Average for Agent ERN_0.05_0.85_0.02_128_64_0: 55.09
#
#         ***Testing Agent ERN***
#         learning_rate = 0.05,
#         gamma = 0.85,
#         egreedy_final = 0.02,
#         hidden_layer = 128,
#         batch_size = 128,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 156.132852***
#                  Average Reward for last 333 steps: 238.813814
#                  Average Reward for all steps: 238.155689
#                  Epsilon: 0.02, Frames Total :79544
#                  Solved 106 Times
#
# 			 *** Episode 666 at Total Seconds 289.327752***
#                  Average Reward for last 333 steps: 206.315315
#                  Average Reward for all steps: 222.259370
#                  Epsilon: 0.02, Frames Total :148247
#                  Solved 156 Times
#
# 			 *** Episode 999 at Total Seconds 322.178651***
#                  Average Reward for last 333 steps: 62.843844
#                  Average Reward for all steps: 169.174000
#                  Epsilon: 0.02, Frames Total :169174
#                  Solved 156 Times
#
#
#               Last 200 Episode Average for Agent ERN_0.05_0.85_0.02_128_128_0: 59.005
#
#         ***Testing Agent ERN***
#         learning_rate = 0.05,
#         gamma = 0.85,
#         egreedy_final = 0.02,
#         hidden_layer = 256,
#         batch_size = 32,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 31.684123***
#                  Average Reward for last 333 steps: 61.582583
#                  Average Reward for all steps: 61.440120
#                  Epsilon: 0.020000001077272588, Frames Total :20521
#                  Solved 8 Times
#
# 			 *** Episode 666 at Total Seconds 179.554629***
#                  Average Reward for last 333 steps: 297.426426
#                  Average Reward for all steps: 179.256372
#                  Epsilon: 0.02, Frames Total :119564
#                  Solved 105 Times
#
# 			 *** Episode 999 at Total Seconds 304.968651***
#                  Average Reward for last 333 steps: 178.399399
#                  Average Reward for all steps: 178.971000
#                  Epsilon: 0.02, Frames Total :178971
#                  Solved 128 Times
#
#
#               Last 200 Episode Average for Agent ERN_0.05_0.85_0.02_256_32_0: 135.805
#
#         ***Testing Agent ERN***
#         learning_rate = 0.05,
#         gamma = 0.85,
#         egreedy_final = 0.02,
#         hidden_layer = 256,
#         batch_size = 64,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 188.467892***
#                  Average Reward for last 333 steps: 287.372372
#                  Average Reward for all steps: 286.697605
#                  Epsilon: 0.02, Frames Total :95757
#                  Solved 126 Times
#
# 			 *** Episode 666 at Total Seconds 334.377830***
#                  Average Reward for last 333 steps: 212.945946
#                  Average Reward for all steps: 249.877061
#                  Epsilon: 0.02, Frames Total :166668
#                  Solved 173 Times
#
# 			 *** Episode 999 at Total Seconds 458.397823***
#                  Average Reward for last 333 steps: 174.939940
#                  Average Reward for all steps: 224.923000
#                  Epsilon: 0.02, Frames Total :224923
#                  Solved 209 Times
#
#
#               Last 200 Episode Average for Agent ERN_0.05_0.85_0.02_256_64_0: 139.665
#
#         ***Testing Agent ERN***
#         learning_rate = 0.05,
#         gamma = 0.85,
#         egreedy_final = 0.02,
#         hidden_layer = 256,
#         batch_size = 128,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 210.279845***
#                  Average Reward for last 333 steps: 284.627628
#                  Average Reward for all steps: 283.841317
#                  Epsilon: 0.02, Frames Total :94803
#                  Solved 125 Times
#
# 			 *** Episode 666 at Total Seconds 356.277175***
#                  Average Reward for last 333 steps: 185.096096
#                  Average Reward for all steps: 234.542729
#                  Epsilon: 0.02, Frames Total :156440
#                  Solved 164 Times
#
# 			 *** Episode 999 at Total Seconds 467.965380***
#                  Average Reward for last 333 steps: 123.537538
#                  Average Reward for all steps: 197.578000
#                  Epsilon: 0.02, Frames Total :197578
#                  Solved 171 Times
#
#
#               Last 200 Episode Average for Agent ERN_0.05_0.85_0.02_256_128_0: 159.315
#
#         ***Testing Agent ERN***
#         learning_rate = 0.05,
#         gamma = 0.9,
#         egreedy_final = 0.02,
#         hidden_layer = 64,
#         batch_size = 32,
#         update_target_frequency = 0
# 			 *** Episode 333 at Total Seconds 106.813109***
#                  Average Reward for last 333 steps: 112.291291
#                  Average Reward for all steps: 112.005988
#                  Epsilon: 0.02000000000000005, Frames Total :37410
#                  Solved 37 Times
#
# 			 *** Episode 666 at Total Seconds 280.664861***
#                  Average Reward for last 333 steps: 287.969970
#                  Average Reward for all steps: 199.856072
#                  Epsilon: 0.02, Frames Total :133304
#                  Solved 140 Times
#
# 			 *** Episode 999 at Total Seconds 336.990070***
#                  Average Reward for last 333 steps: 133.837838
#                  Average Reward for all steps: 177.872000
#                  Epsilon: 0.02, Frames Total :177872
#                  Solved 162 Times
#
#
#               Last 200 Episode Average for Agent ERN_0.05_0.9_0.02_64_32_0: 82.375
#
#         ***Testing Agent ERN***
#         learning_rate = 0.05,
#         gamma = 0.9,
#         egreedy_final = 0.02,
#         hidden_layer = 64,
#         batch_size = 64,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 102.335277***
#                  Average Reward for last 333 steps: 243.297297
#                  Average Reward for all steps: 242.622754
#                  Epsilon: 0.02, Frames Total :81036
#                  Solved 96 Times
#
# 			 *** Episode 666 at Total Seconds 183.784756***
#                  Average Reward for last 333 steps: 192.774775
#                  Average Reward for all steps: 217.736132
#                  Epsilon: 0.02, Frames Total :145230
#                  Solved 131 Times
#
# 			 *** Episode 999 at Total Seconds 217.891227***
#                  Average Reward for last 333 steps: 79.048048
#                  Average Reward for all steps: 171.553000
#                  Epsilon: 0.02, Frames Total :171553
#                  Solved 131 Times
#
#
#               Last 200 Episode Average for Agent ERN_0.05_0.9_0.02_64_64_0: 83.065
#
#         ***Testing Agent ERN***
#         learning_rate = 0.05,
#         gamma = 0.9,
#         egreedy_final = 0.02,
#         hidden_layer = 64,
#         batch_size = 128,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 121.592039***
#                  Average Reward for last 333 steps: 289.306306
#                  Average Reward for all steps: 288.571856
#                  Epsilon: 0.02, Frames Total :96383
#                  Solved 113 Times
#
# 			 *** Episode 666 at Total Seconds 200.780493***
#                  Average Reward for last 333 steps: 187.699700
#                  Average Reward for all steps: 238.211394
#                  Epsilon: 0.02, Frames Total :158887
#                  Solved 151 Times
#
# 			 *** Episode 999 at Total Seconds 239.998683***
#                  Average Reward for last 333 steps: 91.948949
#                  Average Reward for all steps: 189.506000
#                  Epsilon: 0.02, Frames Total :189506
#                  Solved 152 Times
#
#
#               Last 200 Episode Average for Agent ERN_0.05_0.9_0.02_64_128_0: 91.015
#
#         ***Testing Agent ERN***
#         learning_rate = 0.05,
#         gamma = 0.9,
#         egreedy_final = 0.02,
#         hidden_layer = 128,
#         batch_size = 32,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 92.296115***
#                  Average Reward for last 333 steps: 219.426426
#                  Average Reward for all steps: 218.802395
#                  Epsilon: 0.02, Frames Total :73080
#                  Solved 91 Times
#
# 			 *** Episode 666 at Total Seconds 201.041542***
#                  Average Reward for last 333 steps: 259.810811
#                  Average Reward for all steps: 239.275862
#                  Epsilon: 0.02, Frames Total :159597
#                  Solved 174 Times
#
# 			 *** Episode 999 at Total Seconds 240.672013***
#                  Average Reward for last 333 steps: 93.897898
#                  Average Reward for all steps: 190.865000
#                  Epsilon: 0.02, Frames Total :190865
#                  Solved 178 Times
#
#
#               Last 200 Episode Average for Agent ERN_0.05_0.9_0.02_128_32_0: 71.045
#
#         ***Testing Agent ERN***
#         learning_rate = 0.05,
#         gamma = 0.9,
#         egreedy_final = 0.02,
#         hidden_layer = 128,
#         batch_size = 64,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 93.428493***
#                  Average Reward for last 333 steps: 222.996997
#                  Average Reward for all steps: 222.368263
#                  Epsilon: 0.02, Frames Total :74271
#                  Solved 92 Times
#
# 			 *** Episode 666 at Total Seconds 198.562824***
#                  Average Reward for last 333 steps: 238.555556
#                  Average Reward for all steps: 230.449775
#                  Epsilon: 0.02, Frames Total :153710
#                  Solved 154 Times
#
# 			 *** Episode 999 at Total Seconds 220.917448***
#                  Average Reward for last 333 steps: 46.498498
#                  Average Reward for all steps: 169.194000
#                  Epsilon: 0.02, Frames Total :169194
#                  Solved 154 Times
#
#
#               Last 200 Episode Average for Agent ERN_0.05_0.9_0.02_128_64_0: 42.72
#
#         ***Testing Agent ERN***
#         learning_rate = 0.05,
#         gamma = 0.9,
#         egreedy_final = 0.02,
#         hidden_layer = 128,
#         batch_size = 128,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 24.378901***
#                  Average Reward for last 333 steps: 51.582583
#                  Average Reward for all steps: 51.479042
#                  Epsilon: 0.020000030007053343, Frames Total :17194
#                  Solved 0 Times
#
# 			 *** Episode 666 at Total Seconds 159.154908***
#                  Average Reward for last 333 steps: 264.951952
#                  Average Reward for all steps: 158.055472
#                  Epsilon: 0.02, Frames Total :105423
#                  Solved 77 Times
#
# 			 *** Episode 999 at Total Seconds 260.056950***
#                  Average Reward for last 333 steps: 212.006006
#                  Average Reward for all steps: 176.021000
#                  Epsilon: 0.02, Frames Total :176021
#                  Solved 123 Times
#
#
#               Last 200 Episode Average for Agent ERN_0.05_0.9_0.02_128_128_0: 163.93
#
#         ***Testing Agent ERN***
#         learning_rate = 0.05,
#         gamma = 0.9,
#         egreedy_final = 0.02,
#         hidden_layer = 256,
#         batch_size = 32,
#         update_target_frequency = 0
#
# 			 *** Episode 333 at Total Seconds 148.447185***
#                  Average Reward for last 333 steps: 268.183183
#                  Average Reward for all steps: 267.437126
#                  Epsilon: 0.02, Frames Total :89324
#                  Solved 106 Times
#
# 			 *** Episode 666 at Total Seconds 277.459285***
#                  Average Reward for last 333 steps: 252.081081
#                  Average Reward for all steps: 259.770615
#                  Epsilon: 0.02, Frames Total :173267
#                  Solved 168 Times
#
# 			 *** Episode 999 at Total Seconds 354.968732***
#                  Average Reward for last 333 steps: 150.306306
#                  Average Reward for all steps: 223.319000
#                  Epsilon: 0.02, Frames Total :223319
#                  Solved 177 Times
#
#
#               Last 200 Episode Average for Agent ERN_0.05_0.9_0.02_256_32_0: 137.54
#
#         ***Testing Agent ERN***
#         learning_rate = 0.05,
#         gamma = 0.9,
#         egreedy_final = 0.02,
#         hidden_layer = 256,
#         batch_size = 64,
#         update_target_frequency = 0

# %% [markdown]
# ### ERN Demonstration

# %%
#_ = simulation(25, "ERN","ERN_1", record, 100, mem = True, show = True)

# %% [markdown]
# ## Deep Q-Network

# %% [markdown]
# ### ERN - DQN Differences
#
# <img src="./DQNNet.png">
# <div style="text-align: right">Source: Atamai AI</div><br><br>
# <strong>The main update here is adding splitting the updating work, approaching a supervised learning technique</strong>

# %% [markdown]
# ### New DQN Optimize Class

# %%
def DQN_optimize(self):

    if (len(memory) < batch_size):
        return

    state, action, new_state, reward, done = memory.sample(batch_size)

    state = Tensor(state).to(device)
    new_state = Tensor(new_state).to(device)
    reward = Tensor(reward).to(device)
    action = LongTensor(action).to(device)
    done = Tensor(done).to(device)

    #The New states are updated here, use detach to control updates
    new_state_values = self.target_nn(new_state).detach()
    max_new_state_values = torch.max(new_state_values, 1)[0]
    target_value = reward + ( 1 - done ) * gamma * max_new_state_values

    predicted_value = self.nn(state).gather(1, action.unsqueeze(1)).squeeze(1)

    loss = self.loss_func(predicted_value, target_value)

    self.optimizer.zero_grad()
    loss.backward()

    #This is also an addition from https://storage.googleapis.com/deepmind-media/dqn/DQNNaturePaper.pdf
    #This point is added for completeness
    if clip_error:
        for param in self.nn.parameters():
            param.grad.data.clamp_(-1,1)

    self.optimizer.step()

    if self.update_target_counter % update_target_frequency == 0:
        self.target_nn.load_state_dict(self.nn.state_dict())

    #Counter to control how often the updates occurr
    self.update_target_counter += 1

# %% [markdown]
# ### DQN Class

# %%
class DQN(object):
    def __init__(self, Agent, label):
        self.name = label
        self.nn = NeuralNetwork_2().to(device)
        
        #This is a big difference, now we have a target network that is
        #Responsible for updating
        self.target_nn = NeuralNetwork_2().to(device)

        self.loss_func = nn.MSELoss()
        self.optimizer = optim.Adam(params=self.nn.parameters(), lr=learning_rate)
        
        #Also adding a network update counter
        self.update_target_counter = 0
        
setattr(DQN, "calculate_epsilon", calculate_epsilon)
setattr(DQN, "select_action", select_action)
setattr(DQN, "optimize", DQN_optimize)

# %% [markdown]
# ### DQN Parameters

# %%
#This is the New Parameter to update the action network
update_target_frequency = 250

#We will not be using this item from the DQN Nature paper
clip_error = False

# %% [markdown]
# ### Simulating DQN

# %%
record = simulation(1000, "DQN","DQN_1", record, 333)
plot_agent(record, "DQN_1")
# Out:
# 			 *** Episode 333 at Total Seconds 99.885496***
#                  Average Reward for last 333 steps: 240.270270
#                  Average Reward for all steps: 239.598802
#                  Epsilon: 0.02, Frames Total :80026
#                  Solved 122 Times
#
# 			 *** Episode 666 at Total Seconds 282.747018***
#                  Average Reward for last 333 steps: 436.555556
#                  Average Reward for all steps: 337.929535
#                  Epsilon: 0.02, Frames Total :225399
#                  Solved 381 Times
#
# 			 *** Episode 999 at Total Seconds 475.908830***
#                  Average Reward for last 333 steps: 461.216216
#                  Average Reward for all steps: 378.984000
#                  Epsilon: 0.02, Frames Total :378984
#                  Solved 664 Times

# %% [markdown]
# ### Hypertunning DQN

# %%
hyper = {
    "learning_rate" :          [0.1, .01],
    "gamma":                   [.85, 0.995],
    "egreedy_final":           [.02, 0.02], 
    "hidden_layer":            [256],
    "batch_size":              [32, 64],
    "update_target_frequency": [100, 500],}

record = hyper_and_beyond(hyper, record, "DQN", knobs = knobs)

# %% [markdown]
# ## Double DQN Network

# %% [markdown]
# ### Double DQN Optimize

# %%
def DoubleDQN_optimize(self):
        
        if (len(memory) < batch_size):
            return
        
        state, action, new_state, reward, done = memory.sample(batch_size)
        
        state = Tensor(state).to(device)
        new_state = Tensor(new_state).to(device)
        reward = Tensor(reward).to(device)
        action = LongTensor(action).to(device)
        done = Tensor(done).to(device)

        #The big implementation, here we are looking at the correct indexes and then 
        #Running those indices through the analysis. 
        new_state_indexes = self.nn(new_state).detach()
        max_new_state_indexes = torch.max(new_state_indexes, 1)[1]  

        new_state_values = self.target_nn(new_state).detach()

        #Squeeze and Unsqueeze ensure the dimensions fit
        max_new_state_values = new_state_values.gather(1, max_new_state_indexes.unsqueeze(1)).squeeze(1)
        
        target_value = reward + ( 1 - done ) * gamma * max_new_state_values
  
        predicted_value = self.nn(state).gather(1, action.unsqueeze(1)).squeeze(1)
        
        loss = self.loss_func(predicted_value, target_value)
    
        self.optimizer.zero_grad()
        loss.backward()
        
        if clip_error:
            for param in self.nn.parameters():
                param.grad.data.clamp_(-1,1)
        
        self.optimizer.step()
        
        if self.update_target_counter % update_target_frequency == 0:
            self.target_nn.load_state_dict(self.nn.state_dict())
        
        self.update_target_counter += 1

# %% [markdown]
# ### Double DQN Class

# %%
class DoubleDQN(object):
    def __init__(self, Agent, label):
        self.name = label
        self.nn = NeuralNetwork_2().to(device)
        
        #This is a big difference, now we have a target network that is
        #Responsible for updating
        self.target_nn = NeuralNetwork_2().to(device)

        self.loss_func = nn.MSELoss()
        self.optimizer = optim.Adam(params=self.nn.parameters(), lr=learning_rate)
        
        #Also adding a network update counter
        self.update_target_counter = 0
        
setattr(DoubleDQN, "calculate_epsilon", calculate_epsilon)
setattr(DoubleDQN, "select_action", select_action)
setattr(DoubleDQN, "optimize", DoubleDQN_optimize)

# %% [markdown]
# ### Double DQN Parameters

# %%
#Here I am deviating from the prior parameters a little 
learning_rate = 0.001
gamma = 0.9999

hidden_layer = 128

batch_size = 64

update_target_frequency = 250

egreedy = 0.9
egreedy_final = 0.005
egreedy_decay = 500

# %% [markdown]
# ### DoubleDQN Simulation

# %%
record = simulation(1000, "DoubleDQN","DoubleDQN_1", record, 333)
plot_agent(record, "DoubleDQN_1")
# Out:
# 			 *** Episode 333 at Total Seconds 102.136918***
#                  Average Reward for last 333 steps: 215.201201
#                  Average Reward for all steps: 214.649701
#                  Epsilon: 0.005, Frames Total :71693
#                  Solved 129 Times
#
# 			 *** Episode 666 at Total Seconds 341.069508***
#                  Average Reward for last 333 steps: 499.000000
#                  Average Reward for all steps: 356.611694
#                  Epsilon: 0.005, Frames Total :237860
#                  Solved 462 Times
#
# 			 *** Episode 999 at Total Seconds 579.272867***
#                  Average Reward for last 333 steps: 499.000000
#                  Average Reward for all steps: 404.027000
#                  Epsilon: 0.005, Frames Total :404027
#                  Solved 795 Times

# %% [markdown]
# ### DoubleDQN Hypertunning

# %%
hyper = {
    "learning_rate" :          [0.1, .05, .01],
    "gamma":                   [.85, 0.995],
    "egreedy_final":           [.02, 0.02], 
    "hidden_layer":            [256],
    "batch_size":              [32, 64],
    "update_target_frequency": [100, 500],}

record = hyper_and_beyond(hyper, record, "DQN", knobs = knobs)

# %% [markdown]
# ## Exploration of Different Environments

# %% [markdown]
# ### Random

# %%
import torch
import random

import matplotlib.pyplot as plt

from atari_wrappers import make_atari, wrap_deepmind

env_id = "PongNoFrameskip-v4"
env = make_atari(env_id)
env = wrap_deepmind(env)

seed_value = 23
env.seed(seed_value)
torch.manual_seed(seed_value)
random.seed(seed_value)

num_episodes = 5

rewards_total = []

for i_episode in range(num_episodes):
    
    state = env.reset()
    
    score = 0
    #for step in range(100):
    while True:
                
        action = env.action_space.sample()
        
        new_state, reward, done, info = env.step(action)
        
        score += reward
        #print(new_state)
        #print(info)
        
        env.render()
        
        if done:
            rewards_total.append(score)
            print("Episode finished. Reward: %i" % score )
            break
        

print("Average reward: %.2f" % (sum(rewards_total)/num_episodes))
print("Average reward (last 100 episodes): %.2f" % (sum(rewards_total[-100:])/100))

plt.figure(figsize=(12,5))
plt.title("Rewards")
plt.plot(rewards_total, alpha=0.6, color='green')
plt.show()

env.close()
env.env.close()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-85-619ee1a810f7> in <module>
#       4 import matplotlib.pyplot as plt
#       5
# ----> 6 from atari_wrappers import make_atari, wrap_deepmind
#       7
#       8 env_id = "PongNoFrameskip-v4"
#
# /media/michael/ExtraDrive2/Documents/Github/Code_and_Presentations/python/PyTorch/CartPole_NN/atari_wrappers.py in <module>
#       7 import cv2
#       8 cv2.ocl.setUseOpenCL(False)
# ----> 9 from .wrappers import TimeLimit
#      10
#      11
#
# ImportError: attempted relative import with no known parent package

# %%
env = gym.make('MountainCarContinuous-v0')
inputs = env.observation_space.shape[0]

print("Input Space:\t{}\nOutput Space:\t{}".format(inputs, outputs))
# Out:
# Input Space:	2
# Output Space:	3

# %%
mem = True
record = simulation(1000, "DoubleDQN","DoubleDQN_1", record, 25, cart = False)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-80-0892a0ee42ba> in <module>
#       1 mem = True
# ----> 2 record = simulation(1000, "DoubleDQN","DoubleDQN_1", record, 25, cart = False)
#
# <ipython-input-71-110ebe6b238c> in simulation(num_episodes, agent, label, record, report_interval, extra_name, show, cart)
#      49
#      50             #Actor acts
# ---> 51             action = actor.select_action(state, epsilon)
#      52
#      53             #Record States
#
# <ipython-input-14-1fd049da6040> in select_action(self, state, epsilon)
#       7         with torch.no_grad():
#       8             state = Tensor(state).to(device)
# ----> 9             action_from_nn = self.nn(state)
#      10             action = torch.max(action_from_nn,0)[1]
#      11             action = action.item()
#
# ~/anaconda3/envs/monster/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# <ipython-input-61-840e489d310c> in forward(self, x)
#      14
#      15     def forward(self, x):
# ---> 16         output1 = self.linear1(x)
#      17         #Adding activation function between layers
#      18         output1 = self.activation(output1)
#
# ~/anaconda3/envs/monster/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# ~/anaconda3/envs/monster/lib/python3.7/site-packages/torch/nn/modules/linear.py in forward(self, input)
#      65     @weak_script_method
#      66     def forward(self, input):
# ---> 67         return F.linear(input, self.weight, self.bias)
#      68
#      69     def extra_repr(self):
#
# ~/anaconda3/envs/monster/lib/python3.7/site-packages/torch/nn/functional.py in linear(input, weight, bias)
#    1352         ret = torch.addmm(torch.jit._unwrap_optional(bias), input, weight.t())
#    1353     else:
# -> 1354         output = input.matmul(weight.t())
#    1355         if bias is not None:
#    1356             output += torch.jit._unwrap_optional(bias)
#
# RuntimeError: size mismatch, m1: [1 x 2], m2: [4 x 128] at /opt/conda/conda-bld/pytorch_1550796191843/work/aten/src/THC/generic/THCTensorMathBlas.cu:266

# %% [markdown]
# ## Sources

# %% [markdown]
# 1. Robert Alvarez's 2019 Pytorch Presentation at ODSC: https://github.com/robert-alvarez/pytorch_tutorial
# 1. Code Development Atamis's Udemy Course: https://www.udemy.com/reinforcement-learning-with-pytorch/
# 1. Deep Mind's Papers: https://storage.googleapis.com/deepmind-media/dqn/DQNNaturePaper.pdf and https://storage.googleapis.com/deepmind-media/dqn/DQNNaturePaper.pdf
# 1. Reinforcement Learning 2018, Sutton & Barto http://incompleteideas.net/book/RLbook2018.pdf
# 1. UCL Course on RL: http://www0.cs.ucl.ac.uk/staff/d.silver/web/Teaching.html
