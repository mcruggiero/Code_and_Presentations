# %% [markdown]
# # Comparison of DQL Networks
# <strong>Michael Ruggiero<br>
# Tuesday, August 6th, 2019<br>
# michael@mcruggiero.com</strong>

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Introduction" data-toc-modified-id="Introduction-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Introduction</a></span></li><li><span><a href="#Sources" data-toc-modified-id="Sources-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Sources</a></span></li><li><span><a href="#Setup" data-toc-modified-id="Setup-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Setup</a></span><ul class="toc-item"><li><span><a href="#Library-Imports" data-toc-modified-id="Library-Imports-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Library Imports</a></span></li><li><span><a href="#Cuda-Support" data-toc-modified-id="Cuda-Support-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Cuda Support</a></span></li></ul></li><li><span><a href="#CartPole-v1-Environment" data-toc-modified-id="CartPole-v1-Environment-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>CartPole v1 Environment</a></span><ul class="toc-item"><li><span><a href="#Human-Demonstration" data-toc-modified-id="Human-Demonstration-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Human Demonstration</a></span></li><li><span><a href="#Action/Input-Space" data-toc-modified-id="Action/Input-Space-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Action/Input Space</a></span></li><li><span><a href="#Observation/Output-Space" data-toc-modified-id="Observation/Output-Space-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Observation/Output Space</a></span></li></ul></li><li><span><a href="#Functions" data-toc-modified-id="Functions-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Functions</a></span><ul class="toc-item"><li><span><a href="#Report-Function" data-toc-modified-id="Report-Function-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Report Function</a></span></li><li><span><a href="#Agent-Factory" data-toc-modified-id="Agent-Factory-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Agent Factory</a></span></li><li><span><a href="#Simulation-Function" data-toc-modified-id="Simulation-Function-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Simulation Function</a></span></li></ul></li><li><span><a href="#Random-Agent" data-toc-modified-id="Random-Agent-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Random Agent</a></span><ul class="toc-item"><li><span><a href="#Random_Agent-Class" data-toc-modified-id="Random_Agent-Class-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Random_Agent Class</a></span></li><li><span><a href="#Random-Demonstration" data-toc-modified-id="Random-Demonstration-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Random Demonstration</a></span></li><li><span><a href="#Random-Simulation" data-toc-modified-id="Random-Simulation-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Random Simulation</a></span></li></ul></li><li><span><a href="#Reinforcement-Learning-Introduction" data-toc-modified-id="Reinforcement-Learning-Introduction-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Reinforcement Learning Introduction</a></span><ul class="toc-item"><li><span><a href="#Work-Piece-Indicator" data-toc-modified-id="Work-Piece-Indicator-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Work Piece Indicator</a></span></li><li><span><a href="#Reinforcement-Learning-in-Cartpole" data-toc-modified-id="Reinforcement-Learning-in-Cartpole-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>Reinforcement Learning in Cartpole</a></span></li><li><span><a href="#Markov-Decision-Process" data-toc-modified-id="Markov-Decision-Process-7.3"><span class="toc-item-num">7.3&nbsp;&nbsp;</span>Markov Decision Process</a></span></li><li><span><a href="#Deterministic-vs-Stochastic" data-toc-modified-id="Deterministic-vs-Stochastic-7.4"><span class="toc-item-num">7.4&nbsp;&nbsp;</span>Deterministic vs Stochastic</a></span></li><li><span><a href="#Q-Learning" data-toc-modified-id="Q-Learning-7.5"><span class="toc-item-num">7.5&nbsp;&nbsp;</span>Q Learning</a></span></li></ul></li><li><span><a href="#One-Layer-Neural-Nets" data-toc-modified-id="One-Layer-Neural-Nets-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>One Layer Neural Nets</a></span><ul class="toc-item"><li><span><a href="#One-Layer-Neural-Net-Definition" data-toc-modified-id="One-Layer-Neural-Net-Definition-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>One Layer Neural Net Definition</a></span></li><li><span><a href="#BNN-Class" data-toc-modified-id="BNN-Class-8.2"><span class="toc-item-num">8.2&nbsp;&nbsp;</span>BNN Class</a></span></li><li><span><a href="#BNN_1-Parameters" data-toc-modified-id="BNN_1-Parameters-8.3"><span class="toc-item-num">8.3&nbsp;&nbsp;</span>BNN_1 Parameters</a></span></li><li><span><a href="#BNN_1-Simulation" data-toc-modified-id="BNN_1-Simulation-8.4"><span class="toc-item-num">8.4&nbsp;&nbsp;</span>BNN_1 Simulation</a></span></li><li><span><a href="#BNN_2-Parameters" data-toc-modified-id="BNN_2-Parameters-8.5"><span class="toc-item-num">8.5&nbsp;&nbsp;</span>BNN_2 Parameters</a></span></li><li><span><a href="#BNN_2-simulation" data-toc-modified-id="BNN_2-simulation-8.6"><span class="toc-item-num">8.6&nbsp;&nbsp;</span>BNN_2 simulation</a></span></li></ul></li><li><span><a href="#Two-Layer-Neural-Nets" data-toc-modified-id="Two-Layer-Neural-Nets-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Two Layer Neural Nets</a></span><ul class="toc-item"><li><span><a href="#BNN---TLN-Differences" data-toc-modified-id="BNN---TLN-Differences-9.1"><span class="toc-item-num">9.1&nbsp;&nbsp;</span>BNN - TLN Differences</a></span></li><li><span><a href="#Two-Layer-Neural-Net-Definition" data-toc-modified-id="Two-Layer-Neural-Net-Definition-9.2"><span class="toc-item-num">9.2&nbsp;&nbsp;</span>Two Layer Neural Net Definition</a></span></li><li><span><a href="#TLN_1-Parameters" data-toc-modified-id="TLN_1-Parameters-9.3"><span class="toc-item-num">9.3&nbsp;&nbsp;</span>TLN_1 Parameters</a></span></li><li><span><a href="#TLN-Demonstration" data-toc-modified-id="TLN-Demonstration-9.4"><span class="toc-item-num">9.4&nbsp;&nbsp;</span>TLN Demonstration</a></span></li><li><span><a href="#TLN_1-Simulation" data-toc-modified-id="TLN_1-Simulation-9.5"><span class="toc-item-num">9.5&nbsp;&nbsp;</span>TLN_1 Simulation</a></span></li><li><span><a href="#TLN_2-Parameters" data-toc-modified-id="TLN_2-Parameters-9.6"><span class="toc-item-num">9.6&nbsp;&nbsp;</span>TLN_2 Parameters</a></span></li><li><span><a href="#TLN_2-Simulation" data-toc-modified-id="TLN_2-Simulation-9.7"><span class="toc-item-num">9.7&nbsp;&nbsp;</span>TLN_2 Simulation</a></span></li></ul></li><li><span><a href="#Experience-Replay-Network" data-toc-modified-id="Experience-Replay-Network-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>Experience Replay Network</a></span><ul class="toc-item"><li><span><a href="#TLN---ERN-Differences" data-toc-modified-id="TLN---ERN-Differences-10.1"><span class="toc-item-num">10.1&nbsp;&nbsp;</span>TLN - ERN Differences</a></span></li><li><span><a href="#Experience-Replay-Class" data-toc-modified-id="Experience-Replay-Class-10.2"><span class="toc-item-num">10.2&nbsp;&nbsp;</span>Experience Replay Class</a></span></li><li><span><a href="#ERN-Class" data-toc-modified-id="ERN-Class-10.3"><span class="toc-item-num">10.3&nbsp;&nbsp;</span>ERN Class</a></span></li><li><span><a href="#ERN_1-Parameters" data-toc-modified-id="ERN_1-Parameters-10.4"><span class="toc-item-num">10.4&nbsp;&nbsp;</span>ERN_1 Parameters</a></span></li><li><span><a href="#ERN-Demonstration" data-toc-modified-id="ERN-Demonstration-10.5"><span class="toc-item-num">10.5&nbsp;&nbsp;</span>ERN Demonstration</a></span></li><li><span><a href="#ERN_1-Simulation" data-toc-modified-id="ERN_1-Simulation-10.6"><span class="toc-item-num">10.6&nbsp;&nbsp;</span>ERN_1 Simulation</a></span></li><li><span><a href="#ERN_2-Parameters" data-toc-modified-id="ERN_2-Parameters-10.7"><span class="toc-item-num">10.7&nbsp;&nbsp;</span>ERN_2 Parameters</a></span></li><li><span><a href="#ERN_2-Simulation" data-toc-modified-id="ERN_2-Simulation-10.8"><span class="toc-item-num">10.8&nbsp;&nbsp;</span>ERN_2 Simulation</a></span></li></ul></li><li><span><a href="#Deep-Q-Network" data-toc-modified-id="Deep-Q-Network-11"><span class="toc-item-num">11&nbsp;&nbsp;</span>Deep Q-Network</a></span><ul class="toc-item"><li><span><a href="#ERN---DQN-Differences" data-toc-modified-id="ERN---DQN-Differences-11.1"><span class="toc-item-num">11.1&nbsp;&nbsp;</span>ERN - DQN Differences</a></span></li><li><span><a href="#DQN-Class" data-toc-modified-id="DQN-Class-11.2"><span class="toc-item-num">11.2&nbsp;&nbsp;</span>DQN Class</a></span></li><li><span><a href="#DQN-1-Parameters" data-toc-modified-id="DQN-1-Parameters-11.3"><span class="toc-item-num">11.3&nbsp;&nbsp;</span>DQN-1 Parameters</a></span></li><li><span><a href="#DQN-Demonstration" data-toc-modified-id="DQN-Demonstration-11.4"><span class="toc-item-num">11.4&nbsp;&nbsp;</span>DQN Demonstration</a></span></li><li><span><a href="#DQN-1-Simulation" data-toc-modified-id="DQN-1-Simulation-11.5"><span class="toc-item-num">11.5&nbsp;&nbsp;</span>DQN-1 Simulation</a></span></li></ul></li><li><span><a href="#Double-DQN-Network" data-toc-modified-id="Double-DQN-Network-12"><span class="toc-item-num">12&nbsp;&nbsp;</span>Double DQN Network</a></span><ul class="toc-item"><li><span><a href="#DoubleDQN-Class" data-toc-modified-id="DoubleDQN-Class-12.1"><span class="toc-item-num">12.1&nbsp;&nbsp;</span>DoubleDQN Class</a></span></li><li><span><a href="#DoubleDQN-1-Parameters" data-toc-modified-id="DoubleDQN-1-Parameters-12.2"><span class="toc-item-num">12.2&nbsp;&nbsp;</span>DoubleDQN-1 Parameters</a></span></li><li><span><a href="#DoubleDQN-1-Simulation" data-toc-modified-id="DoubleDQN-1-Simulation-12.3"><span class="toc-item-num">12.3&nbsp;&nbsp;</span>DoubleDQN-1 Simulation</a></span></li><li><span><a href="#DoubleDQN_2" data-toc-modified-id="DoubleDQN_2-12.4"><span class="toc-item-num">12.4&nbsp;&nbsp;</span>DoubleDQN_2</a></span></li><li><span><a href="#DoubleDQN_3" data-toc-modified-id="DoubleDQN_3-12.5"><span class="toc-item-num">12.5&nbsp;&nbsp;</span>DoubleDQN_3</a></span></li><li><span><a href="#DoubleDQN_4" data-toc-modified-id="DoubleDQN_4-12.6"><span class="toc-item-num">12.6&nbsp;&nbsp;</span>DoubleDQN_4</a></span></li></ul></li><li><span><a href="#DuelingDQN-Nework" data-toc-modified-id="DuelingDQN-Nework-13"><span class="toc-item-num">13&nbsp;&nbsp;</span>DuelingDQN Nework</a></span><ul class="toc-item"><li><span><a href="#Three-Layer-Advantage-and-Value-Network-Class" data-toc-modified-id="Three-Layer-Advantage-and-Value-Network-Class-13.1"><span class="toc-item-num">13.1&nbsp;&nbsp;</span>Three Layer Advantage and Value Network Class</a></span></li><li><span><a href="#DuelingDQN-Class" data-toc-modified-id="DuelingDQN-Class-13.2"><span class="toc-item-num">13.2&nbsp;&nbsp;</span>DuelingDQN Class</a></span></li><li><span><a href="#DuelingDQN-1-Parameters" data-toc-modified-id="DuelingDQN-1-Parameters-13.3"><span class="toc-item-num">13.3&nbsp;&nbsp;</span>DuelingDQN-1 Parameters</a></span></li><li><span><a href="#DuelingDQN-1-Simulation" data-toc-modified-id="DuelingDQN-1-Simulation-13.4"><span class="toc-item-num">13.4&nbsp;&nbsp;</span>DuelingDQN-1 Simulation</a></span></li></ul></li></ul></div>

# %% [markdown]
# ## Introduction

# %% [markdown]
# <strong>The purpose of this notebook is to compare the performance of different neural net architectures, building each of the networks inside of a modular class structure. Episodic performance will be accumulated and later predicted through supervised learning models. This presentation will focus on the code and algorithmic architecture of various models, rather than the mathematics used in the analysis.</strong>

# %% [markdown]
# ## Sources

# %% [markdown]
# 1. Robert Alvarez's 2019 Pytorch Presentation at ODSC: https://github.com/robert-alvarez/pytorch_tutorial
# 1. Code Development Atamis's Udemy Course: https://www.udemy.com/reinforcement-learning-with-pytorch/
# 1. Deep Mind's Papers: https://storage.googleapis.com/deepmind-media/dqn/DQNNaturePaper.pdf and https://storage.googleapis.com/deepmind-media/dqn/DQNNaturePaper.pdf
# 1. Reinforcement Learning 2018, Sutton & Barto http://incompleteideas.net/book/RLbook2018.pdf
# 1. UCL Course on RL: http://www0.cs.ucl.ac.uk/staff/d.silver/web/Teaching.html

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Library Imports

# %%
import pandas as pd
import numpy as np
import random

import torch
import torch.nn as nn
import torch.optim as optim
from torch.autograd import Variable

from time import time
from time import sleep
import gym
import math

from matplotlib import animation
import matplotlib.pyplot as plt
from IPython.display import display

import seaborn as sns
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-503aa13a0266> in <module>
#      17 from IPython.display import display
#      18
# ---> 19 import seaborn as sns
#      20 get_ipython().run_line_magic('matplotlib', 'inline')
#
# ModuleNotFoundError: No module named 'seaborn'

# %% [markdown]
# ### Cuda Support

# %%
# if gpu is to be used
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
Tensor = torch.Tensor
LongTensor = torch.LongTensor

# %% [markdown]
# ## CartPole v1 Environment

# %% [markdown]
# <img src="./800px-Cart-pendulum.svg.png">

# %% [markdown]
# ### Human Demonstration

# %%
c
# Out:
# taking action 0
# [ 0.026228   -0.00090252  0.01576555 -0.01364998]
# taking action 0
# [ 0.02620995 -0.19624698  0.01549255  0.28396518]
# taking action 0
# [ 0.02228501 -0.39158643  0.02117185  0.58149382]
# taking action 0
# [ 0.01445329 -0.58699854  0.03280173  0.88077034]
# taking action 0
# [ 0.00271332 -0.78255036  0.05041714  1.18358228]
# taking action 0
# [-0.01293769 -0.97828889  0.07408878  1.49163335]
# taking action 0
# [-0.03250347 -1.17423027  0.10392145  1.8065013 ]
# taking action 0
# [-0.05598808 -1.37034721  0.14005148  2.12958758]
# taking action 0
# [-0.08339502 -1.56655414  0.18264323  2.462057  ]
# timesteps 9 reward 9.00

# %% [markdown]
# # CartPole-v1 Enviornment

# %%
env = gym.make('CartPole-v1')
inputs = env.observation_space.shape[0]
outputs = env.action_space.n

print("Input Space:\t{}\nOutput Space:\t{}".format(inputs, outputs))
score_to_solve = 450
# Out:
# Input Space:	4
# Output Space:	2

# %% [markdown]
# ### Action/Input Space
#
# |Num|Action|
# |-|-|
# |0|Push cart to the left|
# |1|Push cart to the right|

# %% [markdown]
# ### Observation/Output Space
#
#
# |Num|Observation|Min|Max|
# |-|---------------------|-|-|
# |0|Cart Position|-4.8|4.8|
# |1|Cart Velocity|-Inf|Inf|
# |2|Pole Angle|-24 deg|24 deg|
# |3|Pole Velocity At Tip|-Inf|Inf|

# %% [markdown]
# ## Functions

# %% [markdown]
# ### Report Function

# %%
def report(report_interval,
           episode,
           start_time,
           steps_total,
           epsilon,
           frames_total,
           solved):
    
    if episode % report_interval == 0 and episode != 0:
        print("""\t\t\t *** Episode {} at Total Seconds {:2f}***
                 Average Reward for last {} steps: {:2f}
                 Average Reward for all steps: {:2f}
                 Epsilon: {}, Frames Total :{}
                 Solved {} Times
              """.format(episode,
                   (time() - start_time),
                   str(report_interval),
                   sum(steps_total[-report_interval:])/report_interval,
                   sum(steps_total)/len(steps_total),
                   epsilon,
                   frames_total,
                   solved))

# %% [markdown]
# ### Agent Factory

# %%
class Agent(object):
  
    def factory(type, object):
        if type == "Random":
            return Random_Agent(type, object)
        elif type == "BNN":
            return BNN(type, object)
        elif type == "TLN":
            return TLN(type, object)
        elif type == "ERN":
            return ERN(type, object)
        elif type == "ULN":
            return ULN(type, object)
        elif type == "DQN":
            return DQN(type, object)
        elif type == "DoubleDQN":
            return DoubleDQN(type, object)
        elif type == "DuelingDQN":
            return DuelingDQN(type, object)
        
    factory = staticmethod(factory)

# %% [markdown]
# ### Simulation Function

# %%
def simulation(num_episodes,
               agent,
               label,
               record,
               report_interval,
               extra_name  = "",
               mem = False,
               show = False):
    
    #Simulation Initialization
    actor = Agent.factory(agent, label)
    start_time = time()
    solved, frames_total = 0, 0
    steps_total = []
    
    if extra_name != "": extra_name = "_" + extra_name
    
    #The recorded dictionary for the simulation
    shadow_run = {}
    
    #Loop through different episodes
    for episode in range(num_episodes):

        # Episode Initializations
        state = env.reset()
        epi_name = actor.name + extra_name + "_"+ str(episode).zfill(4)
        shadow_run[epi_name] = {} 
        
        #A fancy way to make lists
        blanks = [-1 for i in range(500)]
        
        #Input for episode
        actions, steps = blanks, blanks
        
        #Outputs for episodes
        cart_position, cart_velocity = blanks for i in range(2)]
        pole_angle, pole_velocity  = [blanks for i in range(2)]
        
        step = 0
                
        while True:
            #This allows us to watch the model in action
            if show == True: rendered = env.render(mode = 'rgb_array')

            
            #Calculate E-greedy Rate for Exploration vs. Exploitation tradeoff
            epsilon = actor.calculate_epsilon(frames_total)

            #Actor acts
            action = actor.select_action(state, epsilon)

            #Record States
            new_state, reward, done, info = env.step(action)

            #Optimize
            #Memory Push check
            
            if mem == True:
                memory.push(state, action, new_state, reward, done)
                actor.optimize()
            else:
                actor.optimize(state, action, new_state, reward, done)

            #Store Inputs for step
            actions[step] = action
            
            ###
            #**DO THIS**
            #On update, make a class called Information to clean syntax
            ###
            
            #Unpack Output for step
            cart_position[step] = new_state[0]
            cart_velocity[step] = new_state[1]
            pole_angle[step]    = new_state[2]
            pole_velocity[step] = new_state[3]         

            if done:
                steps_total.append(step)
                
                ###
                #**DO THIS**
                #On update, clean up the following syntax
                #Also, consider adding number values to the information
                ###
                
                #Below is an overpacked syntax to add a column for each part
                #.zfill pads zeros in the front of the string
                
                for i in range(500):
                    D = shadow_run[epi_name]
                    D["action_{}".format(str(i).zfill(3))]        = actions[i]
                    D["cart_position_{}".format(str(i).zfill(3))] = cart_position[i]
                    D["cart_velocity_{}".format(str(i).zfill(3))] = cart_velocity[i]
                    D["pole_angle_{}".format(str(i).zfill(3))]    = pole_angle[i]
                    D["pole_velocity_{}".format(str(i).zfill(3))] = pole_velocity[i]                                     
                
                D["steps_total"] = step
                shadow_run[epi_name] = D
                #Not needed for this environment
                #shadow_run[episode]["information"] = information

                if step >= score_to_solve: solved += 1

                report(report_interval, episode, start_time, steps_total, epsilon, frames_total, solved)

                break

            step += 1
            frames_total += 1
            state = new_state
        
    #Clean up after Episodes
    record[actor.name + extra_name] = shadow_run    
    env.close()
    env.env.close()
    
    #Plot Results
    plot_x = np.linspace(0,num_episodes,num = num_episodes)
    
    def moving_average(x, w):
        return np.convolve(x, np.ones(w), 'valid') / w
    
    moving_25 = np.append(24*[0], moving_average(np.array(steps_total), 25))
    
    
    fig1, ax = plt.subplots(nrows=1, ncols=2, figsize=(10, 5));
    ax[0].set_title('Performance Plot');
    ax[0].scatter(plot_x,
                  steps_total,
                  c='b',
                  #s = 5,
                  marker = "x",
                  label = "Performance Values");
#     ax[0].plot(plot_x,
#                steps_total,
#                label = "Performance Values",
#                linewidth = .5)
    ax[0].plot(plot_x, 
               moving_25,
               c = "orange",
               label = "25 Session Moving Average",
               linewidth=3.0)
    ax[0].legend(loc="center right", bbox_to_anchor=(-.1, 0.5))
    
    
    ax[1].set_title("Kernel Density Estimation of Performance");
    sns.kdeplot(np.array(steps_total), shade = True, bw=0.5, ax = ax[1])

    return record

# %% [markdown]
# ## Random Agent

# %% [markdown]
# ### Random_Agent Class

# %%
class Random_Agent(Agent):
    def __init__(self, Agent, label):
        self.name = label
        
    #Randomly chooses an action
    def select_action(self,state,epsilon):
        action = env.action_space.sample()
        return action
    
    #No epsilon decision is needed
    def calculate_epsilon(self,steps_done):
        return 0    
    
    #No optimization
    def optimize(self, state, action, new_state, reward, done):
        return 0

# %% [markdown]
# ### Random Demonstration

# %%
#_ = simulation(50, "Random", "Random_Agent", {}, 100, show = True)

# %% [markdown]
# ### Random Simulation

# %%
record = simulation(1000, "Random", "Random_Agent", {}, 200)
# Out:
# 			 *** Episode 200 at Total Seconds 0.344740***
#                  Average Reward for last 200 steps: 23.050000
#                  Average Reward for all steps: 23.049751
#                  Epsilon: 0, Frames Total :4633
#                  Solved 0 Times
#
# 			 *** Episode 400 at Total Seconds 0.653891***
#                  Average Reward for last 200 steps: 22.505000
#                  Average Reward for all steps: 22.778055
#                  Epsilon: 0, Frames Total :9134
#                  Solved 0 Times
#
# 			 *** Episode 600 at Total Seconds 0.927873***
#                  Average Reward for last 200 steps: 21.795000
#                  Average Reward for all steps: 22.450915
#                  Epsilon: 0, Frames Total :13493
#                  Solved 0 Times
#
# 			 *** Episode 800 at Total Seconds 1.210906***
#                  Average Reward for last 200 steps: 20.160000
#                  Average Reward for all steps: 21.878901
#                  Epsilon: 0, Frames Total :17525
#                  Solved 0 Times

# %%
len(record["Random_Agent"].keys())
# Out:
# 1000

# %%
pd.DataFrame.from_dict(record["Random_Agent"]).T.columns
# Out:
# Index(['action_000', 'action_001', 'action_002', 'action_003', 'action_004',
#        'action_005', 'action_006', 'action_007', 'action_008', 'action_009',
#        ...
#        'pole_velocity_490', 'pole_velocity_491', 'pole_velocity_492',
#        'pole_velocity_493', 'pole_velocity_494', 'pole_velocity_495',
#        'pole_velocity_496', 'pole_velocity_497', 'pole_velocity_498',
#        'pole_velocity_499'],
#       dtype='object', length=2500)

# %%
pd.DataFrame.from_dict(record["Random_Agent"]).T.head()
# Out:
#                    action_000  action_001  action_002  action_003  action_004  \
# Random_Agent_0000   -0.346376   -0.061988    0.220142    0.501870    0.199972
# Random_Agent_0001    0.276735   -0.027415   -0.329887   -0.632521   -0.937139
# Random_Agent_0002   -0.301599   -0.024322    0.250946    0.526058    0.218296
# Random_Agent_0003   -0.322751   -0.626037   -0.346449   -0.655432   -0.382283
# Random_Agent_0004    0.242089   -0.056442   -0.353473   -0.065563   -0.365131
#
#                    action_005  action_006  action_007  action_008  action_009  \
# Random_Agent_0000   -0.098853   -0.396441   -0.109377   -0.410021   -0.711329
# Random_Agent_0001   -1.245509   -0.975583   -1.296536   -1.622766   -1.376953
# Random_Agent_0002    0.498543    0.195257    0.480174    0.766357    1.055622
# Random_Agent_0003   -0.113572    0.152525   -0.165199    0.101166   -0.216632
# Random_Agent_0004   -0.665098   -0.967286   -0.688744   -0.416657   -0.149249
#
#                    ...  pole_velocity_490  pole_velocity_491  \
# Random_Agent_0000  ...               -1.0               -1.0
# Random_Agent_0001  ...               -1.0               -1.0
# Random_Agent_0002  ...               -1.0               -1.0
# Random_Agent_0003  ...               -1.0               -1.0
# Random_Agent_0004  ...               -1.0               -1.0
#
#                    pole_velocity_492  pole_velocity_493  pole_velocity_494  \
# Random_Agent_0000               -1.0               -1.0               -1.0
# Random_Agent_0001               -1.0               -1.0               -1.0
# Random_Agent_0002               -1.0               -1.0               -1.0
# Random_Agent_0003               -1.0               -1.0               -1.0
# Random_Agent_0004               -1.0               -1.0               -1.0
#
#                    pole_velocity_495  pole_velocity_496  pole_velocity_497  \
# Random_Agent_0000               -1.0               -1.0               -1.0
# Random_Agent_0001               -1.0               -1.0               -1.0
# Random_Agent_0002               -1.0               -1.0               -1.0
# Random_Agent_0003               -1.0               -1.0               -1.0
# Random_Agent_0004               -1.0               -1.0               -1.0
#
#                    pole_velocity_498  pole_velocity_499
# Random_Agent_0000               -1.0               -1.0
# Random_Agent_0001               -1.0               -1.0
# Random_Agent_0002               -1.0               -1.0
# Random_Agent_0003               -1.0               -1.0
# Random_Agent_0004               -1.0               -1.0
#
# [5 rows x 2500 columns]

# %% [markdown]
# ## Reinforcement Learning Introduction

# %% [markdown]
# ### Work Piece Indicator

# %%
# %%HTML
# <video width="640" height="480" controls>
#   <source src="./WPI.mp4" type="video/mp4">
# </video>
# Out:
# <video width="640" height="480" controls>
#   <source src="./WPI.mp4" type="video/mp4">
# </video>

# %% [markdown]
# ### Reinforcement Learning in Cartpole
# <br><br>
# <img src="./WPI.png">

# %% [markdown]
# ### Markov Decision Process
# <br><br>
# <img src="./MDP.png">
# <div style="text-align: right">Source: Wikipedia </div>

# %% [markdown]
# ### Deterministic vs Stochastic
# <br><br>
# Some environments have fixed, finite set of states. These environments are called <strong>Deterministic</strong>. Since the combination of states is along a continuous interval, the following analysis will assume CartPole as a <strong>Stochastic</strong> environment, meaning that it is virtually impossible to know everything about the environment.

# %% [markdown]
# ### Q Learning
# <br>
# While the mathematics of Q learning equations are outside of the scope of this presentation, for completeness, they are presented here. <br><br>
# $${\displaystyle Q^{new}(s_{t},a_{t})\leftarrow (1-\alpha )\cdot \underbrace {Q(s_{t},a_{t})} _{\text{old value}}+\underbrace {\alpha } _{\text{learning rate}}\cdot \overbrace {{\bigg (}\underbrace {r_{t}} _{\text{reward}}+\underbrace {\gamma } _{\text{discount factor}}\cdot \underbrace {\max _{a}Q(s_{t+1},a)} _{\text{estimate of optimal future value}}{\bigg )}} ^{\text{learned value}}}$$
# <br>
# For more information, please check out http://cs231n.stanford.edu

# %% [markdown]
# ## One Layer Neural Nets

# %% [markdown]
# ### One Layer Neural Net Definition

# %%
#Basic One Layer Network
class NeuralNetwork_1(nn.Module):
    
    def __init__(self):
        #super () Allows us to avoid calling base class
        super().__init__()
        self.linear1 = nn.Linear(number_of_inputs,number_of_outputs)
        
    def forward(self, x):
        output = self.linear1(x)
        return output

# %% [markdown]
# ### BNN Class

# %%
class BNN(object):
    
    def __init__(self, Agent, label):
        #Calling Network to Cuda, if available
        self.nn = NeuralNetwork_1().to(device)
        self.name = label

        self.loss_func = nn.MSELoss()
        #self.loss_func = nn.SmoothL1Loss()
        
        self.optimizer = optim.Adam(params=self.nn.parameters(), lr=learning_rate)
        #self.optimizer = optim.RMSprop(params=mynn.parameters(), lr=learning_rate)
    
    def calculate_epsilon(self, steps_done):
        #http://home.deib.polimi.it/restelli/MyWebSite/pdf/rl5.pdf
        #Exploitation vs Exploration algorithm
        epsilon = egreedy_final + (egreedy - egreedy_final) * \
                  math.exp(-1. * steps_done / egreedy_decay )
        return epsilon
    
    def select_action(self,state,epsilon):
        
        random_for_egreedy = torch.rand(1)[0]
        
        #If random > epsilon, then will not attempt random action
        if random_for_egreedy > epsilon:      
            with torch.no_grad():
                state = Tensor(state).to(device)
                action_from_nn = self.nn(state)
                action = torch.max(action_from_nn,0)[1]
                action = action.item()
                
        #Otherwise random action is attempted and recorded
        else:
            action = env.action_space.sample()
        
        return action
    
    def optimize(self, state, action, new_state, reward, done):
        #Backwards propigation to train network
        state = Tensor(state).to(device)
        new_state = Tensor(new_state).to(device)
        
        reward = Tensor([reward]).to(device)
        
        if done:
            #Prevents Divergence
            target_value = reward
        else:
            #Bellman Equations
            new_state_values = self.nn(new_state).detach() #Using detach so we don't update the network
            max_new_state_values = torch.max(new_state_values)
            target_value = reward + gamma * max_new_state_values
        
        #The is where the network calculates the predictions
        predicted_value = self.nn(state)[action]
        
        #The learing between the loss and actual
        loss = self.loss_func(predicted_value, target_value)
    
        #Backwards propigate through the netowork
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

# %% [markdown]
# ### BNN_1 Parameters

# %%
#Step Size
learning_rate = 0.1

#Discount Factor
gamma = 0.995

#Exploration vs Explotation trade off
egreedy = 0.9
egreedy_final = 0.02
egreedy_decay = 1000

#These lines are useful if I decide to change environments
number_of_inputs = env.observation_space.shape[0]
number_of_outputs = env.action_space.n

# %% [markdown]
# ### BNN_1 Simulation

# %%
record = simulation(1000, "BNN", "BNN_1",record, 100)
# Out:
# 			 *** Episode 100 at Total Seconds 1.241301***
#                  Average Reward for last 100 steps: 19.350000
#                  Average Reward for all steps: 19.237624
#                  Epsilon: 0.14608066587596544, Frames Total :1943
#                  Solved 0 Times
#
# 			 *** Episode 200 at Total Seconds 2.182077***
#                  Average Reward for last 100 steps: 15.540000
#                  Average Reward for all steps: 17.398010
#                  Epsilon: 0.04665353820518493, Frames Total :3497
#                  Solved 0 Times
#
# 			 *** Episode 300 at Total Seconds 3.281474***
#                  Average Reward for last 100 steps: 18.540000
#                  Average Reward for all steps: 17.777409
#                  Epsilon: 0.024174196595092835, Frames Total :5351
#                  Solved 0 Times
#
# 			 *** Episode 400 at Total Seconds 4.734802***
#                  Average Reward for last 100 steps: 25.730000
#                  Average Reward for all steps: 19.760599
#                  Epsilon: 0.02031851742607103, Frames Total :7924
#                  Solved 0 Times
#
# 			 *** Episode 500 at Total Seconds 5.808077***
#                  Average Reward for last 100 steps: 17.470000
#                  Average Reward for all steps: 19.303393
#                  Epsilon: 0.020055516328598002, Frames Total :9671
#                  Solved 0 Times
#
# 			 *** Episode 600 at Total Seconds 7.188585***
#                  Average Reward for last 100 steps: 23.210000
#                  Average Reward for all steps: 19.953411
#                  Epsilon: 0.02000545033560923, Frames Total :11992
#                  Solved 0 Times
#
# 			 *** Episode 700 at Total Seconds 8.524716***
#                  Average Reward for last 100 steps: 23.360000
#                  Average Reward for all steps: 20.439372
#                  Epsilon: 0.02000052712223438, Frames Total :14328
#                  Solved 0 Times
#
# 			 *** Episode 800 at Total Seconds 9.868398***
#                  Average Reward for last 100 steps: 23.060000
#                  Average Reward for all steps: 20.766542
#                  Epsilon: 0.020000052532523103, Frames Total :16634
#                  Solved 0 Times
#
# 			 *** Episode 900 at Total Seconds 11.243387***
#                  Average Reward for last 100 steps: 23.990000
#                  Average Reward for all steps: 21.124306
#                  Epsilon: 0.020000004770411004, Frames Total :19033
#                  Solved 0 Times

# %%
record.keys()
# Out:
# dict_keys(['Random_Agent', 'BNN_1'])

# %%
len(record["BNN_1"].keys())
# Out:
# 1000

# %% [markdown]
# ### BNN_2 Parameters

# %%
#Tinker with Gamma Rate
gamma = 0.85

# %% [markdown]
# ### BNN_2 simulation

# %%
record = simulation(1000, "BNN","BNN_2", record, 100)
# Out:
# 			 *** Episode 100 at Total Seconds 1.437555***
#                  Average Reward for last 100 steps: 24.180000
#                  Average Reward for all steps: 24.108911
#                  Epsilon: 0.09708601740229073, Frames Total :2435
#                  Solved 0 Times
#
# 			 *** Episode 200 at Total Seconds 2.778050***
#                  Average Reward for last 100 steps: 24.800000
#                  Average Reward for all steps: 24.452736
#                  Epsilon: 0.026455431745323974, Frames Total :4915
#                  Solved 0 Times
#
# 			 *** Episode 300 at Total Seconds 4.288380***
#                  Average Reward for last 100 steps: 27.520000
#                  Average Reward for all steps: 25.471761
#                  Epsilon: 0.020411857405569077, Frames Total :7667
#                  Solved 0 Times
#
# 			 *** Episode 400 at Total Seconds 5.756705***
#                  Average Reward for last 100 steps: 26.880000
#                  Average Reward for all steps: 25.822943
#                  Epsilon: 0.020028013238064232, Frames Total :10355
#                  Solved 0 Times
#
# 			 *** Episode 500 at Total Seconds 7.130537***
#                  Average Reward for last 100 steps: 24.360000
#                  Average Reward for all steps: 25.530938
#                  Epsilon: 0.020002451443871944, Frames Total :12791
#                  Solved 0 Times
#
# 			 *** Episode 600 at Total Seconds 8.710634***
#                  Average Reward for last 100 steps: 28.770000
#                  Average Reward for all steps: 26.069884
#                  Epsilon: 0.020000138024673885, Frames Total :15668
#                  Solved 0 Times
#
# 			 *** Episode 700 at Total Seconds 10.056720***
#                  Average Reward for last 100 steps: 23.240000
#                  Average Reward for all steps: 25.666191
#                  Epsilon: 0.020000013510031254, Frames Total :17992
#                  Solved 0 Times
#
# 			 *** Episode 800 at Total Seconds 11.215796***
#                  Average Reward for last 100 steps: 20.080000
#                  Average Reward for all steps: 24.968789
#                  Epsilon: 0.02000000181381519, Frames Total :20000
#                  Solved 0 Times
#
# 			 *** Episode 900 at Total Seconds 12.278722***
#                  Average Reward for last 100 steps: 16.830000
#                  Average Reward for all steps: 24.065483
#                  Epsilon: 0.020000000337035324, Frames Total :21683
#                  Solved 0 Times

# %%
record.keys()
# Out:
# dict_keys(['Random_Agent', 'BNN_1', 'BNN_2'])

# %% [markdown]
# ## Two Layer Neural Nets

# %% [markdown]
# ### BNN - TLN Differences

# %% [markdown]
# <strong>The only major difference between these two networks is the addition of an extra linear layer in the neural net</strong>

# %% [markdown]
# ### Two Layer Neural Net Definition

# %%
class NeuralNetwork_2(nn.Module):
    def __init__(self):
        super(NeuralNetwork_2, self).__init__()
        self.linear1 = nn.Linear(number_of_inputs,hidden_layer)
        self.linear2 = nn.Linear(hidden_layer,number_of_outputs)

        self.activation = nn.Tanh()
        #self.activation = nn.ReLU()
        
        
    def forward(self, x):
        output1 = self.linear1(x)
        #Adding activation function between layers
        output1 = self.activation(output1)
        output2 = self.linear2(output1)
        
        return output2

# %%
class TLN(object):
    
    def __init__(self,Agent, label):
        self.nn = NeuralNetwork_2().to(device)
        self.name = label

        self.loss_func = nn.MSELoss()
        #self.loss_func = nn.SmoothL1Loss()
        
        self.optimizer = optim.Adam(params=self.nn.parameters(), lr=learning_rate)
        #self.optimizer = optim.RMSprop(params=mynn.parameters(), lr=learning_rate)
    
    def calculate_epsilon(self, steps_done):
        epsilon = egreedy_final + (egreedy - egreedy_final) * \
                  math.exp(-1. * steps_done / egreedy_decay )
        return epsilon
    
    def select_action(self,state,epsilon):
        
        random_for_egreedy = torch.rand(1)[0]
        
        if random_for_egreedy > epsilon:      
            
            with torch.no_grad():
                
                state = Tensor(state).to(device)
                action_from_nn = self.nn(state)
                action = torch.max(action_from_nn,0)[1]
                action = action.item()        
        else:
            action = env.action_space.sample()
        
        return action
    
    def optimize(self, state, action, new_state, reward, done):
        
        state = Tensor(state).to(device)
        new_state = Tensor(new_state).to(device)
        
        reward = Tensor([reward]).to(device)
        
        if done:
            target_value = reward
        else:
            new_state_values = self.nn(new_state).detach()
            max_new_state_values = torch.max(new_state_values)
            target_value = reward + gamma * max_new_state_values
        
        predicted_value = self.nn(state)[action]
        
        loss = self.loss_func(predicted_value, target_value)
    
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

# %% [markdown]
# ### TLN_1 Parameters

# %%
#Reset Params
#Step Size
learning_rate = 0.1

#Discount Factor
gamma = 0.995

#Exploration vs Explotation trade off
egreedy = 0.9
egreedy_final = 0.02
egreedy_decay = 1000

#Need to add a hidden layer in the neural net
hidden_layer = 64

#These lines are useful if I decide to change environments
number_of_inputs = env.observation_space.shape[0]
number_of_outputs = env.action_space.n

# %% [markdown]
# ### TLN Demonstration

# %%
#_ = simulation(100, "TLN","TLN_1", record, 100, show = True)

# %% [markdown]
# ### TLN_1 Simulation

# %%
record = simulation(1000, "TLN","TLN_1", record, 100)
# Out:
# 			 *** Episode 100 at Total Seconds 3.243328***
#                  Average Reward for last 100 steps: 39.660000
#                  Average Reward for all steps: 39.405941
#                  Epsilon: 0.036443362617204836, Frames Total :3980
#                  Solved 0 Times
#
# 			 *** Episode 200 at Total Seconds 6.668300***
#                  Average Reward for last 100 steps: 45.880000
#                  Average Reward for all steps: 42.626866
#                  Epsilon: 0.020167281360215086, Frames Total :8568
#                  Solved 0 Times
#
# 			 *** Episode 300 at Total Seconds 8.420191***
#                  Average Reward for last 100 steps: 21.410000
#                  Average Reward for all steps: 35.578073
#                  Epsilon: 0.02001966179055185, Frames Total :10709
#                  Solved 0 Times
#
# 			 *** Episode 400 at Total Seconds 15.500869***
#                  Average Reward for last 100 steps: 98.750000
#                  Average Reward for all steps: 51.331671
#                  Epsilon: 0.020000001011498066, Frames Total :20584
#                  Solved 4 Times
#
# 			 *** Episode 500 at Total Seconds 24.216267***
#                  Average Reward for last 100 steps: 119.990000
#                  Average Reward for all steps: 65.035928
#                  Epsilon: 0.02000000000000622, Frames Total :32583
#                  Solved 8 Times
#
# 			 *** Episode 600 at Total Seconds 39.460935***
#                  Average Reward for last 100 steps: 209.800000
#                  Average Reward for all steps: 89.123128
#                  Epsilon: 0.02, Frames Total :53563
#                  Solved 29 Times
#
# 			 *** Episode 700 at Total Seconds 47.706767***
#                  Average Reward for last 100 steps: 109.850000
#                  Average Reward for all steps: 92.079886
#                  Epsilon: 0.02, Frames Total :64548
#                  Solved 30 Times
#
# 			 *** Episode 800 at Total Seconds 53.483557***
#                  Average Reward for last 100 steps: 76.840000
#                  Average Reward for all steps: 90.177278
#                  Epsilon: 0.02, Frames Total :72232
#                  Solved 33 Times
#
# 			 *** Episode 900 at Total Seconds 67.380929***
#                  Average Reward for last 100 steps: 188.460000
#                  Average Reward for all steps: 101.085461
#                  Epsilon: 0.02, Frames Total :91078
#                  Solved 47 Times

# %% [markdown]
# ### TLN_2 Parameters

# %%
#Changing the hidden layer by a factor of 4
hidden_layer = 256

# %% [markdown]
# ### TLN_2 Simulation

# %%
record = simulation(1000, "TLN","TLN_2", record, 100)
# Out:
# 			 *** Episode 100 at Total Seconds 2.912784***
#                  Average Reward for last 100 steps: 42.020000
#                  Average Reward for all steps: 41.712871
#                  Epsilon: 0.03302566845797493, Frames Total :4213
#                  Solved 0 Times
#
# 			 *** Episode 200 at Total Seconds 5.288216***
#                  Average Reward for last 100 steps: 32.820000
#                  Average Reward for all steps: 37.288557
#                  Epsilon: 0.020489153911039382, Frames Total :7495
#                  Solved 0 Times
#
# 			 *** Episode 300 at Total Seconds 6.790395***
#                  Average Reward for last 100 steps: 20.220000
#                  Average Reward for all steps: 31.617940
#                  Epsilon: 0.020064759291376966, Frames Total :9517
#                  Solved 0 Times
#
# 			 *** Episode 400 at Total Seconds 7.896368***
#                  Average Reward for last 100 steps: 11.320000
#                  Average Reward for all steps: 26.556110
#                  Epsilon: 0.020020877607778476, Frames Total :10649
#                  Solved 0 Times
#
# 			 *** Episode 500 at Total Seconds 9.235024***
#                  Average Reward for last 100 steps: 13.350000
#                  Average Reward for all steps: 23.920160
#                  Epsilon: 0.02000549411317087, Frames Total :11984
#                  Solved 0 Times
#
# 			 *** Episode 600 at Total Seconds 10.150502***
#                  Average Reward for last 100 steps: 9.870000
#                  Average Reward for all steps: 21.582363
#                  Epsilon: 0.020002047618041183, Frames Total :12971
#                  Solved 0 Times
#
# 			 *** Episode 700 at Total Seconds 11.951821***
#                  Average Reward for last 100 steps: 26.000000
#                  Average Reward for all steps: 22.212553
#                  Epsilon: 0.020000152083918737, Frames Total :15571
#                  Solved 0 Times
#
# 			 *** Episode 800 at Total Seconds 13.190632***
#                  Average Reward for last 100 steps: 15.230000
#                  Average Reward for all steps: 21.340824
#                  Epsilon: 0.020000033162922693, Frames Total :17094
#                  Solved 0 Times
#
# 			 *** Episode 900 at Total Seconds 14.957958***
#                  Average Reward for last 100 steps: 23.790000
#                  Average Reward for all steps: 21.612653
#                  Epsilon: 0.02000000307231843, Frames Total :19473
#                  Solved 0 Times

# %% [markdown]
# ## Experience Replay Network

# %% [markdown]
# ### TLN - ERN Differences
#
# <br>
# <strong>According to the paper <span style="text-decoration:underline">Playing Atari with Deep Reinforcement Learning</span>, two main problems arise from simple neural nets in RL problems. First, there is a delay between action and rewards; these problems are thus "particularly daunting when compared to the direct association between inputs and targets found in supervised learning." Second, "most deep
# learning algorithms assume the data samples to be independent, while in reinforcement learning one
# typically encounters sequences of highly correlated states." In other words, the data distributions are non stationary.<br><br>
# Deep Mind's solution to this problem was to use: "an experience replay mechanism which randomly samples previous transitions, and thereby smooths the training distribution over many past behaviors." These samples are taken in batches, not sequentially.</strong>
#
# <img src="./DQN.png">
#
# <br>
# <strong>In terms of our Pytorch Algorithm, This will involve two major improvements:
# 1. The addition of the Experience Replay Class
# 1. Pushing all memory inside of tensors</strong>

# %% [markdown]
# ### Experience Replay Class

# %%
class ExperienceReplay(object):
    def __init__(self, capacity):
        self.capacity = capacity
        self.memory = []
        self.position = 0
     
    #Now Training is batches to avoid the clustering and oversampling
    #Of past training
    def push(self, state, action, new_state, reward, done):
        transition = (state, action, new_state, reward, done)
        
        #Checks to see if memory ready to be filled
        if self.position >= len(self.memory):
            self.memory.append(transition)
        else:
            self.memory[self.position] = transition
        
        self.position = ( self.position + 1 ) % self.capacity
        
        
    def sample(self, batch_size):
        #aggregates elements based on iterables, here it is making
        #batches of experiences
        return zip(*random.sample(self.memory, batch_size))
        
    
    #Verify Memory size
    def __len__(self):
        return len(self.memory)

# %% [markdown]
# ### ERN Class

# %%
class ERN(object):
    def __init__(self, Agent, label):
        self.nn = NeuralNetwork_2().to(device)
        self.name = label
        
        self.loss_func = nn.MSELoss()
        #self.loss_func = nn.SmoothL1Loss()
        
        self.optimizer = optim.Adam(params=self.nn.parameters(), lr=learning_rate)
        #self.optimizer = optim.RMSprop(params=mynn.parameters(), lr=learning_rate)
        
    def select_action(self,state,epsilon):
        
        random_for_egreedy = torch.rand(1)[0]
        
        if random_for_egreedy > epsilon:      
            
            with torch.no_grad():
                
                state = Tensor(state).to(device)
                action_from_nn = self.nn(state)
                action = torch.max(action_from_nn,0)[1]
                action = action.item()        
        else:
            action = env.action_space.sample()
        
        return action
    
    def calculate_epsilon(self, steps_done):
        epsilon = egreedy_final + (egreedy - egreedy_final) * \
                  math.exp(-1. * steps_done / egreedy_decay )
        return epsilon
    
    def optimize(self):
        
        if (len(memory) < batch_size):
            return
        
        state, action, new_state, reward, done = memory.sample(batch_size)
        
        state = Tensor(state).to(device)
        new_state = Tensor(new_state).to(device)
        reward = Tensor(reward).to(device)
        action = LongTensor(action).to(device)
        done = Tensor(done).to(device)

        new_state_values = self.nn(new_state).detach()
        max_new_state_values = torch.max(new_state_values, 1)[0]
        target_value = reward + ( 1 - done ) * gamma * max_new_state_values
  
        predicted_value = self.nn(state).gather(1, action.unsqueeze(1)).squeeze(1)
        
        loss = self.loss_func(predicted_value, target_value)
    
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

# %% [markdown]
# ### ERN_1 Parameters

# %%
#Reset Params
#Step Size
learning_rate = 0.1

#Discount Factor
gamma = 0.995

#Exploration vs Explotation trade off
egreedy = 0.9
egreedy_final = 0.02
egreedy_decay = 1000

#Reset
hidden_layer = 64

#New Parameters added, memory size and batch elements
replay_mem_size = 50000
batch_size = 32

memory = ExperienceReplay(replay_mem_size)

# %% [markdown]
# ### ERN Demonstration

# %%
#_ = simulation(25, "ERN","ERN_1", record, 100, mem = True, show = True)

# %% [markdown]
# ### ERN_1 Simulation

# %%
record = simulation(1000, "ERN","ERN_1", record, 100, mem = True)
# Out:
# 			 *** Episode 100 at Total Seconds 19.969759***
#                  Average Reward for last 100 steps: 224.980000
#                  Average Reward for all steps: 223.128713
#                  Epsilon: 0.020000000143622416, Frames Total :22536
#                  Solved 18 Times
#
# 			 *** Episode 200 at Total Seconds 48.278988***
#                  Average Reward for last 100 steps: 304.150000
#                  Average Reward for all steps: 263.437811
#                  Epsilon: 0.02, Frames Total :52951
#                  Solved 53 Times
#
# 			 *** Episode 300 at Total Seconds 80.042168***
#                  Average Reward for last 100 steps: 314.490000
#                  Average Reward for all steps: 280.398671
#                  Epsilon: 0.02, Frames Total :84400
#                  Solved 89 Times
#
# 			 *** Episode 400 at Total Seconds 109.997316***
#                  Average Reward for last 100 steps: 295.440000
#                  Average Reward for all steps: 284.149626
#                  Epsilon: 0.02, Frames Total :113944
#                  Solved 125 Times
#
# 			 *** Episode 500 at Total Seconds 132.020514***
#                  Average Reward for last 100 steps: 211.630000
#                  Average Reward for all steps: 269.674651
#                  Epsilon: 0.02, Frames Total :135107
#                  Solved 139 Times
#
# 			 *** Episode 600 at Total Seconds 143.629879***
#                  Average Reward for last 100 steps: 109.360000
#                  Average Reward for all steps: 243.000000
#                  Epsilon: 0.02, Frames Total :146043
#                  Solved 142 Times
#
# 			 *** Episode 700 at Total Seconds 151.437917***
#                  Average Reward for last 100 steps: 78.630000
#                  Average Reward for all steps: 219.552068
#                  Epsilon: 0.02, Frames Total :153906
#                  Solved 142 Times
#
# 			 *** Episode 800 at Total Seconds 161.090307***
#                  Average Reward for last 100 steps: 83.720000
#                  Average Reward for all steps: 202.594257
#                  Epsilon: 0.02, Frames Total :162278
#                  Solved 142 Times
#
# 			 *** Episode 900 at Total Seconds 169.665357***
#                  Average Reward for last 100 steps: 76.180000
#                  Average Reward for all steps: 188.563818
#                  Epsilon: 0.02, Frames Total :169896
#                  Solved 142 Times

# %% [markdown]
# ### ERN_2 Parameters

# %%
#Try a different egreedy value
egreedy = 0.9
egreedy_final = 0.0001
egreedy_decay = 1000

memory = ExperienceReplay(replay_mem_size)

# %% [markdown]
# ### ERN_2 Simulation

# %%
record = simulation(1000, "ERN","ERN_2", record, 100, mem = True)
# Out:
# 			 *** Episode 100 at Total Seconds 28.825795***
#                  Average Reward for last 100 steps: 305.640000
#                  Average Reward for all steps: 302.702970
#                  Epsilon: 0.00010000000004747982, Frames Total :30573
#                  Solved 39 Times
#
# 			 *** Episode 200 at Total Seconds 61.445600***
#                  Average Reward for last 100 steps: 296.150000
#                  Average Reward for all steps: 299.442786
#                  Epsilon: 0.0001, Frames Total :60188
#                  Solved 76 Times
#
# 			 *** Episode 300 at Total Seconds 88.413155***
#                  Average Reward for last 100 steps: 277.780000
#                  Average Reward for all steps: 292.245847
#                  Epsilon: 0.0001, Frames Total :87966
#                  Solved 110 Times
#
# 			 *** Episode 400 at Total Seconds 116.781602***
#                  Average Reward for last 100 steps: 297.600000
#                  Average Reward for all steps: 293.581047
#                  Epsilon: 0.0001, Frames Total :117726
#                  Solved 139 Times
#
# 			 *** Episode 500 at Total Seconds 136.695503***
#                  Average Reward for last 100 steps: 179.440000
#                  Average Reward for all steps: 270.798403
#                  Epsilon: 0.0001, Frames Total :135670
#                  Solved 150 Times
#
# 			 *** Episode 600 at Total Seconds 150.823293***
#                  Average Reward for last 100 steps: 116.540000
#                  Average Reward for all steps: 245.131448
#                  Epsilon: 0.0001, Frames Total :147324
#                  Solved 158 Times
#
# 			 *** Episode 700 at Total Seconds 167.299788***
#                  Average Reward for last 100 steps: 156.100000
#                  Average Reward for all steps: 232.430813
#                  Epsilon: 0.0001, Frames Total :162934
#                  Solved 160 Times
#
# 			 *** Episode 800 at Total Seconds 181.497844***
#                  Average Reward for last 100 steps: 147.050000
#                  Average Reward for all steps: 221.771536
#                  Epsilon: 0.0001, Frames Total :177639
#                  Solved 166 Times
#
# 			 *** Episode 900 at Total Seconds 195.666562***
#                  Average Reward for last 100 steps: 152.110000
#                  Average Reward for all steps: 214.039956
#                  Epsilon: 0.0001, Frames Total :192850
#                  Solved 172 Times

# %% [markdown]
# ## Deep Q-Network

# %% [markdown]
# ### ERN - DQN Differences
#
# <img src="./DQNNet.png">
# <div style="text-align: right">Source: Atamai AI</div><br><br>
# <strong>The main update here is adding that we have split the updating work, approaching a supervised learning technique</strong>

# %% [markdown]
# ### DQN Class

# %%
class DQN(object):
    def __init__(self, Agent, label):
        self.name = label
        
        
        self.nn = NeuralNetwork_2().to(device)
        
        #This is a big difference, now we have a target network that is
        #Responsible for updating
        self.target_nn = NeuralNetwork_2().to(device)

        self.loss_func = nn.MSELoss()
        
        self.optimizer = optim.Adam(params=self.nn.parameters(), lr=learning_rate)
        
        self.update_target_counter = 0
        
    def select_action(self,state,epsilon):
        
        random_for_egreedy = torch.rand(1)[0]
        
        if random_for_egreedy > epsilon:      
            
            with torch.no_grad():
                
                state = Tensor(state).to(device)
                action_from_nn = self.nn(state)
                action = torch.max(action_from_nn,0)[1]
                action = action.item()        
        else:
            action = env.action_space.sample()
        
        return action
    
    def calculate_epsilon(self, steps_done):
        epsilon = egreedy_final + (egreedy - egreedy_final) * \
                  math.exp(-1. * steps_done / egreedy_decay )
        return epsilon
    
    def optimize(self):
        
        if (len(memory) < batch_size):
            return
        
        state, action, new_state, reward, done = memory.sample(batch_size)
        
        state = Tensor(state).to(device)
        new_state = Tensor(new_state).to(device)
        reward = Tensor(reward).to(device)
        action = LongTensor(action).to(device)
        done = Tensor(done).to(device)

        #The New states are updated here, use detach to control updates
        new_state_values = self.target_nn(new_state).detach()
        max_new_state_values = torch.max(new_state_values, 1)[0]
        target_value = reward + ( 1 - done ) * gamma * max_new_state_values
  
        predicted_value = self.nn(state).gather(1, action.unsqueeze(1)).squeeze(1)
        
        loss = self.loss_func(predicted_value, target_value)
    
        self.optimizer.zero_grad()
        loss.backward()
        
        #This is also an addition from https://storage.googleapis.com/deepmind-media/dqn/DQNNaturePaper.pdf
        if clip_error:
            for param in self.nn.parameters():
                param.grad.data.clamp_(-1,1)
        
        self.optimizer.step()
        
        if self.update_target_counter % update_target_frequency == 0:
            self.target_nn.load_state_dict(self.nn.state_dict())
        
        #Counter to control how often the updates occurr
        self.update_target_counter += 1

# %% [markdown]
# ### DQN-1 Parameters

# %%
learning_rate = 0.01
gamma = 0.9999

hidden_layer = 128

replay_mem_size = 500000
batch_size = 64

#This is the New Parameter to update the action network
update_target_frequency = 250

egreedy = 0.9
egreedy_final = 0.01
egreedy_decay = 500

clip_error = False

# %% [markdown]
# ### DQN Demonstration

# %%
#_ = simulation(100, "DQN","DQN_1", record, 100, mem = True, show = True)

# %% [markdown]
# ### DQN-1 Simulation

# %%
record = simulation(1000, "DQN","DQN_1", record, 100, mem = True)
# Out:
# 			 *** Episode 100 at Total Seconds 12.138270***
#                  Average Reward for last 100 steps: 102.880000
#                  Average Reward for all steps: 101.970297
#                  Epsilon: 0.010000001008770257, Frames Total :10299
#                  Solved 2 Times
#
# 			 *** Episode 200 at Total Seconds 36.658792***
#                  Average Reward for last 100 steps: 210.320000
#                  Average Reward for all steps: 155.875622
#                  Epsilon: 0.01, Frames Total :31331
#                  Solved 16 Times
#
# 			 *** Episode 300 at Total Seconds 69.379328***
#                  Average Reward for last 100 steps: 280.400000
#                  Average Reward for all steps: 197.245847
#                  Epsilon: 0.01, Frames Total :59371
#                  Solved 41 Times
#
# 			 *** Episode 400 at Total Seconds 104.863111***
#                  Average Reward for last 100 steps: 302.280000
#                  Average Reward for all steps: 223.438903
#                  Epsilon: 0.01, Frames Total :89599
#                  Solved 83 Times
#
# 			 *** Episode 500 at Total Seconds 163.459124***
#                  Average Reward for last 100 steps: 459.300000
#                  Average Reward for all steps: 270.516966
#                  Epsilon: 0.01, Frames Total :135529
#                  Solved 164 Times
#
# 			 *** Episode 600 at Total Seconds 222.120881***
#                  Average Reward for last 100 steps: 475.530000
#                  Average Reward for all steps: 304.628952
#                  Epsilon: 0.01, Frames Total :183082
#                  Solved 255 Times
#
# 			 *** Episode 700 at Total Seconds 284.892168***
#                  Average Reward for last 100 steps: 459.570000
#                  Average Reward for all steps: 326.731812
#                  Epsilon: 0.01, Frames Total :229039
#                  Solved 334 Times
#
# 			 *** Episode 800 at Total Seconds 342.402274***
#                  Average Reward for last 100 steps: 437.880000
#                  Average Reward for all steps: 340.607990
#                  Epsilon: 0.01, Frames Total :272827
#                  Solved 410 Times
#
# 			 *** Episode 900 at Total Seconds 406.370678***
#                  Average Reward for last 100 steps: 450.480000
#                  Average Reward for all steps: 352.802442
#                  Epsilon: 0.01, Frames Total :317875
#                  Solved 488 Times

# %%
record.keys()
# Out:
# dict_keys(['Random_Agent', 'BNN_1', 'BNN_2', 'TLN_1', 'TLN_2', 'ERN_1', 'ERN_2', 'DQN_1'])

# %% [markdown]
# ## Double DQN Network

# %% [markdown]
# ### DoubleDQN Class

# %%
class DoubleDQN(object):
    def __init__(self, Agent, label):
        self.name = label
        
        self.nn = NeuralNetwork_2().to(device)
        self.target_nn = NeuralNetwork_2().to(device)

        self.loss_func = nn.MSELoss()
        
        self.optimizer = optim.Adam(params=self.nn.parameters(), lr=learning_rate)
        
        self.update_target_counter = 0
        
    def select_action(self,state,epsilon):
        
        random_for_egreedy = torch.rand(1)[0]
        
        if random_for_egreedy > epsilon:      
            
            with torch.no_grad():
                
                state = Tensor(state).to(device)
                action_from_nn = self.nn(state)
                action = torch.max(action_from_nn,0)[1]
                action = action.item()        
        else:
            action = env.action_space.sample()
        
        return action
    
    def calculate_epsilon(self, steps_done):
        epsilon = egreedy_final + (egreedy - egreedy_final) * \
                  math.exp(-1. * steps_done / egreedy_decay )
        return epsilon
    
    def optimize(self):
        
        if (len(memory) < batch_size):
            return
        
        state, action, new_state, reward, done = memory.sample(batch_size)
        
        state = Tensor(state).to(device)
        new_state = Tensor(new_state).to(device)
        reward = Tensor(reward).to(device)
        action = LongTensor(action).to(device)
        done = Tensor(done).to(device)

        #The big implementation, here we are looking at the correct indexes and then 
        #Running those indices through the analysis. 
        if double_dqn:
            new_state_indexes = self.nn(new_state).detach()
            max_new_state_indexes = torch.max(new_state_indexes, 1)[1]  
            
            new_state_values = self.target_nn(new_state).detach()
            
            #Squeeze and Unsqueeze ensure the dimensions fit
            max_new_state_values = new_state_values.gather(1, max_new_state_indexes.unsqueeze(1)).squeeze(1)
        else:
            new_state_values = self.target_nn(new_state).detach()
            max_new_state_values = torch.max(new_state_values, 1)[0]
        
        
        target_value = reward + ( 1 - done ) * gamma * max_new_state_values
  
        predicted_value = self.nn(state).gather(1, action.unsqueeze(1)).squeeze(1)
        
        loss = self.loss_func(predicted_value, target_value)
    
        self.optimizer.zero_grad()
        loss.backward()
        
        if clip_error:
            for param in self.nn.parameters():
                param.grad.data.clamp_(-1,1)
        
        self.optimizer.step()
        
        if self.update_target_counter % update_target_frequency == 0:
            self.target_nn.load_state_dict(self.nn.state_dict())
        
        self.update_target_counter += 1

# %% [markdown]
# ### DoubleDQN-1 Parameters

# %%
learning_rate = 0.01

gamma = 0.999

hidden_layer = 128

replay_mem_size = 500000
batch_size = 64

update_target_frequency = 500

double_dqn = True

egreedy = 0.9
egreedy_final = 0.001
egreedy_decay = 1000

clip_error = False

# %% [markdown]
# ### DoubleDQN-1 Simulation

# %%
record = simulation(1000, "DoubleDQN","DoubleDQN_1", record, 100, mem = True)
# Out:
# 			 *** Episode 100 at Total Seconds 26.989038***
#                  Average Reward for last 100 steps: 181.780000
#                  Average Reward for all steps: 180.108911
#                  Epsilon: 0.001000011311202343, Frames Total :18191
#                  Solved 28 Times
#
# 			 *** Episode 200 at Total Seconds 75.819762***
#                  Average Reward for last 100 steps: 348.990000
#                  Average Reward for all steps: 264.129353
#                  Epsilon: 0.001, Frames Total :53090
#                  Solved 78 Times
#
# 			 *** Episode 300 at Total Seconds 107.314597***
#                  Average Reward for last 100 steps: 198.480000
#                  Average Reward for all steps: 242.318937
#                  Epsilon: 0.001, Frames Total :72938
#                  Solved 85 Times
#
# 			 *** Episode 400 at Total Seconds 166.973456***
#                  Average Reward for last 100 steps: 359.350000
#                  Average Reward for all steps: 271.503741
#                  Epsilon: 0.001, Frames Total :108873
#                  Solved 139 Times
#
# 			 *** Episode 500 at Total Seconds 241.496365***
#                  Average Reward for last 100 steps: 463.020000
#                  Average Reward for all steps: 309.730539
#                  Epsilon: 0.001, Frames Total :155175
#                  Solved 226 Times
#
# 			 *** Episode 600 at Total Seconds 311.205284***
#                  Average Reward for last 100 steps: 470.100000
#                  Average Reward for all steps: 336.414309
#                  Epsilon: 0.001, Frames Total :202185
#                  Solved 312 Times
#
# 			 *** Episode 700 at Total Seconds 362.521722***
#                  Average Reward for last 100 steps: 383.780000
#                  Average Reward for all steps: 343.171184
#                  Epsilon: 0.001, Frames Total :240563
#                  Solved 370 Times
#
# 			 *** Episode 800 at Total Seconds 427.609138***
#                  Average Reward for last 100 steps: 469.990000
#                  Average Reward for all steps: 359.003745
#                  Epsilon: 0.001, Frames Total :287562
#                  Solved 459 Times
#
# 			 *** Episode 900 at Total Seconds 480.475100***
#                  Average Reward for last 100 steps: 418.880000
#                  Average Reward for all steps: 365.649279
#                  Epsilon: 0.001, Frames Total :329450
#                  Solved 527 Times

# %% [markdown]
# ### DoubleDQN_2

# %%
learning_rate = 0.001
gamma = 0.9999

hidden_layer = 128

replay_mem_size = 500000
batch_size = 64

update_target_frequency = 100

egreedy = 0.9
egreedy_final = 0.01
egreedy_decay = 500

clip_error = True

record = simulation(1000, "DoubleDQN","DoubleDQN_2", record, 100, mem = True)
# Out:
# 			 *** Episode 100 at Total Seconds 26.730533***
#                  Average Reward for last 100 steps: 170.930000
#                  Average Reward for all steps: 169.376238
#                  Epsilon: 0.010000000000001232, Frames Total :17107
#                  Solved 16 Times
#
# 			 *** Episode 200 at Total Seconds 90.078670***
#                  Average Reward for last 100 steps: 449.110000
#                  Average Reward for all steps: 308.547264
#                  Epsilon: 0.01, Frames Total :62018
#                  Solved 87 Times
#
# 			 *** Episode 300 at Total Seconds 135.446004***
#                  Average Reward for last 100 steps: 338.560000
#                  Average Reward for all steps: 318.518272
#                  Epsilon: 0.01, Frames Total :95874
#                  Solved 127 Times
#
# 			 *** Episode 400 at Total Seconds 180.654374***
#                  Average Reward for last 100 steps: 338.720000
#                  Average Reward for all steps: 323.556110
#                  Epsilon: 0.01, Frames Total :129746
#                  Solved 156 Times
#
# 			 *** Episode 500 at Total Seconds 216.938405***
#                  Average Reward for last 100 steps: 231.330000
#                  Average Reward for all steps: 305.147705
#                  Epsilon: 0.01, Frames Total :152879
#                  Solved 161 Times
#
# 			 *** Episode 600 at Total Seconds 242.360207***
#                  Average Reward for last 100 steps: 179.320000
#                  Average Reward for all steps: 284.211314
#                  Epsilon: 0.01, Frames Total :170811
#                  Solved 165 Times
#
# 			 *** Episode 700 at Total Seconds 252.938754***
#                  Average Reward for last 100 steps: 83.410000
#                  Average Reward for all steps: 255.566334
#                  Epsilon: 0.01, Frames Total :179152
#                  Solved 168 Times
#
# 			 *** Episode 800 at Total Seconds 254.511513***
#                  Average Reward for last 100 steps: 11.000000
#                  Average Reward for all steps: 225.033708
#                  Epsilon: 0.01, Frames Total :180252
#                  Solved 168 Times
#
# 			 *** Episode 900 at Total Seconds 255.792040***
#                  Average Reward for last 100 steps: 9.510000
#                  Average Reward for all steps: 201.113208
#                  Epsilon: 0.01, Frames Total :181203
#                  Solved 168 Times

# %% [markdown]
# ### DoubleDQN_3

# %%
learning_rate = 0.01
gamma = 0.9999

hidden_layer = 256

replay_mem_size = 500000
batch_size = 64

update_target_frequency = 256

egreedy = 0.9
egreedy_final = 0.01
egreedy_decay = 500

clip_error = False

record = simulation(1000, "DoubleDQN","DoubleDQN_3", record, 100, mem = True)
# Out:
# 			 *** Episode 100 at Total Seconds 14.613512***
#                  Average Reward for last 100 steps: 104.570000
#                  Average Reward for all steps: 103.851485
#                  Epsilon: 0.010000000689859049, Frames Total :10489
#                  Solved 0 Times
#
# 			 *** Episode 200 at Total Seconds 33.034241***
#                  Average Reward for last 100 steps: 134.270000
#                  Average Reward for all steps: 118.985075
#                  Epsilon: 0.01, Frames Total :23916
#                  Solved 1 Times
#
# 			 *** Episode 300 at Total Seconds 71.080515***
#                  Average Reward for last 100 steps: 279.350000
#                  Average Reward for all steps: 172.262458
#                  Epsilon: 0.01, Frames Total :51851
#                  Solved 28 Times
#
# 			 *** Episode 400 at Total Seconds 124.768598***
#                  Average Reward for last 100 steps: 393.220000
#                  Average Reward for all steps: 227.364090
#                  Epsilon: 0.01, Frames Total :91173
#                  Solved 95 Times
#
# 			 *** Episode 500 at Total Seconds 178.434984***
#                  Average Reward for last 100 steps: 392.790000
#                  Average Reward for all steps: 260.383234
#                  Epsilon: 0.01, Frames Total :130452
#                  Solved 156 Times
#
# 			 *** Episode 600 at Total Seconds 236.733370***
#                  Average Reward for last 100 steps: 429.080000
#                  Average Reward for all steps: 288.452579
#                  Epsilon: 0.01, Frames Total :173360
#                  Solved 234 Times
#
# 			 *** Episode 700 at Total Seconds 306.675371***
#                  Average Reward for last 100 steps: 438.700000
#                  Average Reward for all steps: 309.885877
#                  Epsilon: 0.01, Frames Total :217230
#                  Solved 313 Times
#
# 			 *** Episode 800 at Total Seconds 380.356464***
#                  Average Reward for last 100 steps: 470.470000
#                  Average Reward for all steps: 329.933833
#                  Epsilon: 0.01, Frames Total :264277
#                  Solved 399 Times
#
# 			 *** Episode 900 at Total Seconds 445.721442***
#                  Average Reward for last 100 steps: 479.720000
#                  Average Reward for all steps: 346.558269
#                  Epsilon: 0.01, Frames Total :312249
#                  Solved 490 Times

# %% [markdown]
# ### DoubleDQN_4

# %%
learning_rate = 0.025
gamma = 0.9995

hidden_layer = 128

replay_mem_size = 500000
batch_size = 64

update_target_frequency = 250

egreedy = 0.9
egreedy_final = 0.01
egreedy_decay = 1000

clip_error = True

record = simulation(1000, "DoubleDQN","DoubleDQN_4", record, 100, mem = True)
# Out:
# 			 *** Episode 100 at Total Seconds 26.820965***
#                  Average Reward for last 100 steps: 204.050000
#                  Average Reward for all steps: 202.118812
#                  Epsilon: 0.01000000121255781, Frames Total :20414
#                  Solved 16 Times
#
# 			 *** Episode 200 at Total Seconds 52.619918***
#                  Average Reward for last 100 steps: 197.500000
#                  Average Reward for all steps: 199.820896
#                  Epsilon: 0.010000000000000004, Frames Total :40164
#                  Solved 22 Times
#
# 			 *** Episode 300 at Total Seconds 79.612657***
#                  Average Reward for last 100 steps: 203.950000
#                  Average Reward for all steps: 201.192691
#                  Epsilon: 0.01, Frames Total :60559
#                  Solved 41 Times
#
# 			 *** Episode 400 at Total Seconds 99.289184***
#                  Average Reward for last 100 steps: 143.570000
#                  Average Reward for all steps: 186.822943
#                  Epsilon: 0.01, Frames Total :74916
#                  Solved 47 Times
#
# 			 *** Episode 500 at Total Seconds 114.815078***
#                  Average Reward for last 100 steps: 116.810000
#                  Average Reward for all steps: 172.848303
#                  Epsilon: 0.01, Frames Total :86597
#                  Solved 50 Times
#
# 			 *** Episode 600 at Total Seconds 127.045529***
#                  Average Reward for last 100 steps: 91.140000
#                  Average Reward for all steps: 159.252912
#                  Epsilon: 0.01, Frames Total :95711
#                  Solved 57 Times
#
# 			 *** Episode 700 at Total Seconds 138.850945***
#                  Average Reward for last 100 steps: 87.860000
#                  Average Reward for all steps: 149.068474
#                  Epsilon: 0.01, Frames Total :104497
#                  Solved 58 Times
#
# 			 *** Episode 800 at Total Seconds 156.678040***
#                  Average Reward for last 100 steps: 132.750000
#                  Average Reward for all steps: 147.031211
#                  Epsilon: 0.01, Frames Total :117772
#                  Solved 61 Times
#
# 			 *** Episode 900 at Total Seconds 169.933641***
#                  Average Reward for last 100 steps: 97.950000
#                  Average Reward for all steps: 141.583796
#                  Epsilon: 0.01, Frames Total :127567
#                  Solved 63 Times

# %% [markdown]
# ## DuelingDQN Nework

# %% [markdown]
# ### Three Layer Advantage and Value Network Class

# %%
class NeuralNetwork_AandV(nn.Module):
    def __init__(self):
        super(NeuralNetwork_AandV, self).__init__()
        self.linear1 = nn.Linear(number_of_inputs,hidden_layer)
        
        self.advantage = nn.Linear(hidden_layer,hidden_layer)
        self.advantage2 = nn.Linear(hidden_layer, number_of_outputs)
        
        self.value = nn.Linear(hidden_layer,hidden_layer)
        self.value2 = nn.Linear(hidden_layer,1)

        self.activation = nn.Tanh()
        #self.activation = nn.ReLU()
        
        
    def forward(self, x):
        output1 = self.linear1(x)
        output1 = self.activation(output1)
        
        output_advantage = self.advantage(output1)
        output_advantage = self.activation(output_advantage)
        output_advantage = self.advantage2(output_advantage)
        
        output_value = self.value(output1)
        output_value = self.activation(output_value)
        output_value = self.value2(output_value)
        
        output_final = output_value + output_advantage - output_advantage.mean()

        return output_final

# %% [markdown]
# ### DuelingDQN Class

# %%
class DuelingDQN(object):
    def __init__(self, Agent, label):
        self.name = label
        
        #The only real change is rework the networks
        self.nn = NeuralNetwork_AandV().to(device)
        self.target_nn = NeuralNetwork_AandV().to(device)

        self.loss_func = nn.MSELoss()
        
        self.optimizer = optim.Adam(params=self.nn.parameters(), lr=learning_rate)
        
        self.update_target_counter = 0
        
    def select_action(self,state,epsilon):
        
        random_for_egreedy = torch.rand(1)[0]
        
        if random_for_egreedy > epsilon:      
            
            with torch.no_grad():
                
                state = Tensor(state).to(device)
                action_from_nn = self.nn(state)
                action = torch.max(action_from_nn,0)[1]
                action = action.item()        
        else:
            action = env.action_space.sample()
        
        return action
    
    def calculate_epsilon(self, steps_done):
        epsilon = egreedy_final + (egreedy - egreedy_final) * \
                  math.exp(-1. * steps_done / egreedy_decay )
        return epsilon
    
    def optimize(self):
        
        if (len(memory) < batch_size):
            return
        
        state, action, new_state, reward, done = memory.sample(batch_size)
        
        state = Tensor(state).to(device)
        new_state = Tensor(new_state).to(device)
        reward = Tensor(reward).to(device)
        action = LongTensor(action).to(device)
        done = Tensor(done).to(device)
    
        new_state_indexes = self.nn(new_state).detach()
        max_new_state_indexes = torch.max(new_state_indexes, 1)[1]  

        new_state_values = self.target_nn(new_state).detach()
        max_new_state_values = new_state_values.gather(1, max_new_state_indexes.unsqueeze(1)).squeeze(1)
        
        
        target_value = reward + ( 1 - done ) * gamma * max_new_state_values
  
        predicted_value = self.nn(state).gather(1, action.unsqueeze(1)).squeeze(1)
        
        loss = self.loss_func(predicted_value, target_value)
    
        self.optimizer.zero_grad()
        loss.backward()
        
        if clip_error:
            for param in self.nn.parameters():
                param.grad.data.clamp_(-1,1)
        
        self.optimizer.step()
        
        if self.update_target_counter % update_target_frequency == 0:
            self.target_nn.load_state_dict(self.nn.state_dict())
        
        self.update_target_counter += 1

# %% [markdown]
# ### DuelingDQN-1 Parameters

# %%
#Same as Above

# %% [markdown]
# ### DuelingDQN-1 Simulation

# %%
record = simulation(1000, "DuelingDQN","DuelingDQN_1", record, 100, mem = True)
# Out:
# 			 *** Episode 100 at Total Seconds 7.668877***
#                  Average Reward for last 100 steps: 25.940000
#                  Average Reward for all steps: 25.891089
#                  Epsilon: 0.07511933193942416, Frames Total :2615
#                  Solved 0 Times
#
# 			 *** Episode 200 at Total Seconds 40.610564***
#                  Average Reward for last 100 steps: 113.420000
#                  Average Reward for all steps: 69.437811
#                  Epsilon: 0.01000077257726307, Frames Total :13957
#                  Solved 3 Times
#
# 			 *** Episode 300 at Total Seconds 69.356116***
#                  Average Reward for last 100 steps: 118.450000
#                  Average Reward for all steps: 85.720930
#                  Epsilon: 0.010000000005542731, Frames Total :25802
#                  Solved 7 Times
#
# 			 *** Episode 400 at Total Seconds 80.265023***
#                  Average Reward for last 100 steps: 42.800000
#                  Average Reward for all steps: 75.017456
#                  Epsilon: 0.010000000000076727, Frames Total :30082
#                  Solved 7 Times
#
# 			 *** Episode 500 at Total Seconds 93.279487***
#                  Average Reward for last 100 steps: 51.030000
#                  Average Reward for all steps: 70.229541
#                  Epsilon: 0.010000000000000467, Frames Total :35185
#                  Solved 7 Times
#
# 			 *** Episode 600 at Total Seconds 104.847918***
#                  Average Reward for last 100 steps: 44.930000
#                  Average Reward for all steps: 66.019967
#                  Epsilon: 0.010000000000000005, Frames Total :39678
#                  Solved 7 Times
#
# 			 *** Episode 700 at Total Seconds 118.189701***
#                  Average Reward for last 100 steps: 43.080000
#                  Average Reward for all steps: 62.747504
#                  Epsilon: 0.01, Frames Total :43986
#                  Solved 7 Times
#
# 			 *** Episode 800 at Total Seconds 124.332852***
#                  Average Reward for last 100 steps: 22.950000
#                  Average Reward for all steps: 57.779026
#                  Epsilon: 0.01, Frames Total :46281
#                  Solved 7 Times
#
# 			 *** Episode 900 at Total Seconds 129.849881***
#                  Average Reward for last 100 steps: 20.590000
#                  Average Reward for all steps: 53.651498
#                  Epsilon: 0.01, Frames Total :48340
#                  Solved 7 Times
